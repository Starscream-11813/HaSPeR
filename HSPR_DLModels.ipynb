# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(1))
print(torch.cuda.current_device())
# Out:
# True
# NVIDIA GeForce RTX 3090
# 0

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
! pip install split-folders[full]
# Out:
# Collecting split-folders[full]
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Collecting tqdm
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, split-folders
# Successfully installed split-folders-0.5.1 tqdm-4.64.1

# %%
! pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (0.14.1)
# Requirement already satisfied: torch==1.13.1 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torchvision) (1.13.1)
# Requirement already satisfied: typing-extensions in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torchvision) (4.4.0)
# Requirement already satisfied: requests in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torchvision) (2.28.2)
# Requirement already satisfied: numpy in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torchvision) (1.24.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torch==1.13.1->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torch==1.13.1->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torch==1.13.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torch==1.13.1->torchvision) (11.7.99)
# Requirement already satisfied: setuptools in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->torchvision) (67.4.0)
# Requirement already satisfied: wheel in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->torchvision) (0.38.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from requests->torchvision) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from requests->torchvision) (3.0.1)

# %%
! pip install transformers accelerate torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 240.8 kB/s eta 0:00:0000:0100:01
# Collecting accelerate
#   Downloading accelerate-0.16.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 kB 351.4 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: torch in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (1.13.1)
# Requirement already satisfied: torchvision in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (0.14.1)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu117/torchaudio-0.13.1%2Bcu117-cp38-cp38-linux_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 820.1 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm>=4.27 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: requests in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from transformers) (2.28.2)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
# Requirement already satisfied: numpy>=1.17 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from transformers) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from transformers) (23.0)
# Collecting filelock
#   Using cached filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Using cached huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
# Collecting regex!=2019.12.17
#   Using cached regex-2022.10.31-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (772 kB)
# Requirement already satisfied: psutil in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from accelerate) (5.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torch) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torch) (4.4.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: setuptools in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (67.4.0)
# Requirement already satisfied: wheel in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.38.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from requests->transformers) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, regex, pyyaml, filelock, huggingface-hub, transformers, torchaudio, accelerate
# Successfully installed accelerate-0.16.0 filelock-3.9.0 huggingface-hub-0.12.1 pyyaml-6.0 regex-2022.10.31 tokenizers-0.13.2 torchaudio-0.13.1+cu117 transformers-4.26.1

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import splitfolders
import torch.nn.functional as F
import cv2
from PIL import Image

# %%
class ThresholdTransform(object):
  def __init__(self, thr_255):
    self.thr = thr_255 / 255.  # input threshold for [0..255] gray level, convert to [0..1]

  def __call__(self, x):
    return (x > self.thr).to(x.dtype)  # do not change the data type

# %%
dilation_kernel = np.ones((3, 3), dtype=np.uint8)
erosion_kernel = Image.fromarray(np.ones((3, 3), dtype=np.uint8))
class Dilation(object):
    def __init__(self, kernel):
        self.kernel = kernel
    
    def __call__(self, image):
        image = np.array(image)  # Convert PIL image to NumPy array
        image = image.astype(np.uint8)  # Convert to 8-bit unsigned integer
        dilated_image = cv2.dilate(image, self.kernel, iterations=1)
        return torch.from_numpy(dilated_image).float()

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((320,240)),
#         transforms.ColorJitter(brightness=.5, hue=.3),
        transforms.RandomApply(transforms=[transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5))], p=0.25),
        transforms.RandomPerspective(distortion_scale=0.6, p=0.25),
        transforms.RandomApply(transforms=[transforms.ColorJitter(brightness=.5, hue=.3),
                                           # transforms.RandomInvert(),
                                           transforms.RandomAffine(30,translate=(0.1,0.1),
                                                                   shear=(-15,15))], p=0.25),
        transforms.Grayscale(num_output_channels=3),
#         transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(0.25),
#         transforms.RandomRotation(30),
        transforms.ToTensor(),
        ThresholdTransform(thr_255=90),
        Dilation(kernel=dilation_kernel),
#         cv2.dilate()
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((320,240)),
        transforms.Grayscale(num_output_channels=3),
        # transforms.Resize(256),
#         transforms.CenterCrop(224),
        transforms.ToTensor(),
        ThresholdTransform(thr_255=90),
        Dilation(kernel=dilation_kernel),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}
data_dir = "/home/dlpc01/Rifat/CSE 4836 Pattern Recognition Lab/data2"
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=8,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") #SELECT GPU FROM HERE

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    plt.axis('off')
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))
for i in inputs:
    print(i.shape)
# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# torch.Size([3, 320, 240])
# torch.Size([3, 320, 240])
# torch.Size([3, 320, 240])
# torch.Size([3, 320, 240])
# torch.Size([3, 320, 240])
# torch.Size([3, 320, 240])
# torch.Size([3, 320, 240])
# torch.Size([3, 320, 240])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 11)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=5, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.5103 Acc: 0.8566
# val Loss: 1.0422 Acc: 0.6920
#
# Epoch 1/24
# ----------
# train Loss: 0.0991 Acc: 0.9763
# val Loss: 0.8113 Acc: 0.7996
#
# Epoch 2/24
# ----------
# train Loss: 0.0504 Acc: 0.9887
# val Loss: 0.6914 Acc: 0.8167
#
# Epoch 3/24
# ----------
# train Loss: 0.0360 Acc: 0.9935
# val Loss: 0.8671 Acc: 0.8121
#
# Epoch 4/24
# ----------
# train Loss: 0.0294 Acc: 0.9954
# val Loss: 0.5197 Acc: 0.8534
#
# Epoch 5/24
# ----------
# train Loss: 0.0180 Acc: 0.9965
# val Loss: 0.5819 Acc: 0.8424
#
# Epoch 6/24
# ----------
# train Loss: 0.0201 Acc: 0.9963
# val Loss: 0.5408 Acc: 0.8520
#
# Epoch 7/24
# ----------
# train Loss: 0.0173 Acc: 0.9954
# val Loss: 0.5541 Acc: 0.8507
#
# Epoch 8/24
# ----------
# train Loss: 0.0120 Acc: 0.9983
# val Loss: 0.6750 Acc: 0.8330
#
# Epoch 9/24
# ----------
# train Loss: 0.0183 Acc: 0.9954
# val Loss: 0.5832 Acc: 0.8440
#
# Epoch 10/24
# ----------
# train Loss: 0.0147 Acc: 0.9972
# val Loss: 0.6691 Acc: 0.8405
#
# Epoch 11/24
# ----------
# train Loss: 0.0154 Acc: 0.9972
# val Loss: 0.5915 Acc: 0.8523
#
# Epoch 12/24
# ----------
# train Loss: 0.0146 Acc: 0.9965
# val Loss: 0.6221 Acc: 0.8421
#
# Epoch 13/24
# ----------
# train Loss: 0.0153 Acc: 0.9967
# val Loss: 0.6430 Acc: 0.8394
#
# Epoch 14/24
# ----------
# train Loss: 0.0131 Acc: 0.9978
# val Loss: 0.5651 Acc: 0.8539
#
# Epoch 15/24
# ----------
# train Loss: 0.0171 Acc: 0.9959
# val Loss: 0.6358 Acc: 0.8453
#
# Epoch 16/24
# ----------
# train Loss: 0.0161 Acc: 0.9970
# val Loss: 0.6190 Acc: 0.8448
#
# Epoch 17/24
# ----------
# train Loss: 0.0177 Acc: 0.9961
# val Loss: 0.6349 Acc: 0.8435
#
# Epoch 18/24
# ----------
# train Loss: 0.0167 Acc: 0.9959
# val Loss: 0.6014 Acc: 0.8408
#
# Epoch 19/24
# ----------
# train Loss: 0.0152 Acc: 0.9967
# val Loss: 0.5742 Acc: 0.8475
#
# Epoch 20/24
# ----------
# train Loss: 0.0146 Acc: 0.9976
# val Loss: 0.6682 Acc: 0.8480
#
# Epoch 21/24
# ----------
# train Loss: 0.0142 Acc: 0.9974
# val Loss: 0.6118 Acc: 0.8413
#
# Epoch 22/24
# ----------
# train Loss: 0.0172 Acc: 0.9967
# val Loss: 0.5973 Acc: 0.8491
#
# Epoch 23/24
# ----------
# train Loss: 0.0134 Acc: 0.9976
# val Loss: 0.6707 Acc: 0.8328
#
# Epoch 24/24
# ----------
# train Loss: 0.0150 Acc: 0.9963
# val Loss: 0.6052 Acc: 0.8507
#
# Training complete in 15m 5s
# Best val Acc: 0.853893

# %%
torch.cuda.empty_cache()

# %%
visualize_model(model_ft)

# %%
def train_model2(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ft2 = models.vit_b_16(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs2 = model_ft2.heads.head.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft2.fc = nn.Linear(num_ftrs2, 11)

model_ft2 = model_ft2.to(device)

criterion2 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft2 = optim.SGD(model_ft2.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler2 = lr_scheduler.StepLR(optimizer_ft2, step_size=5, gamma=0.1)

# %%
model_ft2 = train_model2(model_ft2, criterion2, optimizer_ft2, exp_lr_scheduler2, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 2.0599 Acc: 0.3194
# val Loss: 2.1546 Acc: 0.3080
#
# Epoch 1/24
# ----------
# train Loss: 1.2448 Acc: 0.5814
# val Loss: 2.2376 Acc: 0.3722
#
# Epoch 2/24
# ----------
# train Loss: 0.9737 Acc: 0.6635
# val Loss: 2.1971 Acc: 0.3420
#
# Epoch 3/24
# ----------
# train Loss: 0.7991 Acc: 0.7363
# val Loss: 1.8894 Acc: 0.3958
#
# Epoch 4/24
# ----------
# train Loss: 0.7037 Acc: 0.7554
# val Loss: 2.1103 Acc: 0.4691
#
# Epoch 5/24
# ----------
# train Loss: 0.4939 Acc: 0.8384
# val Loss: 1.9111 Acc: 0.5050
#
# Epoch 6/24
# ----------
# train Loss: 0.4308 Acc: 0.8538
# val Loss: 1.8844 Acc: 0.5186
#
# Epoch 7/24
# ----------
# train Loss: 0.3721 Acc: 0.8803
# val Loss: 1.9048 Acc: 0.5082
#
# Epoch 8/24
# ----------
# train Loss: 0.3673 Acc: 0.8844
# val Loss: 1.9045 Acc: 0.5170
#
# Epoch 9/24
# ----------
# train Loss: 0.3414 Acc: 0.8851
# val Loss: 1.8920 Acc: 0.5432
#
# Epoch 10/24
# ----------
# train Loss: 0.3259 Acc: 0.8944
# val Loss: 1.8919 Acc: 0.5454
#
# Epoch 11/24
# ----------
# train Loss: 0.3136 Acc: 0.9020
# val Loss: 1.8833 Acc: 0.5405
#
# Epoch 12/24
# ----------
# train Loss: 0.3229 Acc: 0.9003
# val Loss: 1.8782 Acc: 0.5478
#
# Epoch 13/24
# ----------
# train Loss: 0.3079 Acc: 0.9018
# val Loss: 1.8694 Acc: 0.5510
#
# Epoch 14/24
# ----------
# train Loss: 0.3135 Acc: 0.9005
# val Loss: 1.8644 Acc: 0.5486
#
# Epoch 15/24
# ----------
# train Loss: 0.3157 Acc: 0.9027
# val Loss: 1.8672 Acc: 0.5488
#
# Epoch 16/24
# ----------
# train Loss: 0.3138 Acc: 0.9009
# val Loss: 1.8693 Acc: 0.5502
#
# Epoch 17/24
# ----------
# train Loss: 0.3198 Acc: 0.8968
# val Loss: 1.8707 Acc: 0.5504
#
# Epoch 18/24
# ----------
# train Loss: 0.3203 Acc: 0.8953
# val Loss: 1.8723 Acc: 0.5507
#
# Epoch 19/24
# ----------
# train Loss: 0.3074 Acc: 0.9005
# val Loss: 1.8749 Acc: 0.5520
#
# Epoch 20/24
# ----------
# train Loss: 0.3120 Acc: 0.8970
# val Loss: 1.8752 Acc: 0.5520
#
# Epoch 21/24
# ----------
# train Loss: 0.3252 Acc: 0.8953
# val Loss: 1.8752 Acc: 0.5520
#
# Epoch 22/24
# ----------
# train Loss: 0.3228 Acc: 0.8979
# val Loss: 1.8753 Acc: 0.5518
#
# Epoch 23/24
# ----------
# train Loss: 0.3251 Acc: 0.8983
# val Loss: 1.8752 Acc: 0.5520
#
# Epoch 24/24
# ----------
# train Loss: 0.3225 Acc: 0.8949
# val Loss: 1.8752 Acc: 0.5520
#
# Training complete in 26m 17s
# Best val Acc: 0.552047

# %%
def visualize_model2(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model2(model_ft2)

# %%
def train_model3(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ft3 = models.googlenet(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs3 = model_ft3.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft3.fc = nn.Linear(num_ftrs3, 11)

model_ft3 = model_ft3.to(device)

criterion3 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft3 = optim.SGD(model_ft3.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler3 = lr_scheduler.StepLR(optimizer_ft3, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=GoogLeNet_Weights.IMAGENET1K_V1`. You can also use `weights=GoogLeNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ft3 = train_model3(model_ft3, criterion3, optimizer_ft3, exp_lr_scheduler3, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.9384 Acc: 0.7691
# val Loss: 1.0520 Acc: 0.6489
#
# Epoch 1/24
# ----------
# train Loss: 0.1737 Acc: 0.9663
# val Loss: 0.8570 Acc: 0.7332
#
# Epoch 2/24
# ----------
# train Loss: 0.0950 Acc: 0.9813
# val Loss: 0.6571 Acc: 0.8100
#
# Epoch 3/24
# ----------
# train Loss: 0.0646 Acc: 0.9870
# val Loss: 0.6849 Acc: 0.8108
#
# Epoch 4/24
# ----------
# train Loss: 0.0486 Acc: 0.9894
# val Loss: 0.8347 Acc: 0.7918
#
# Epoch 5/24
# ----------
# train Loss: 0.0429 Acc: 0.9907
# val Loss: 0.8151 Acc: 0.7980
#
# Epoch 6/24
# ----------
# train Loss: 0.0280 Acc: 0.9941
# val Loss: 0.8601 Acc: 0.8044
#
# Epoch 7/24
# ----------
# train Loss: 0.0328 Acc: 0.9930
# val Loss: 0.7987 Acc: 0.8049
#
# Epoch 8/24
# ----------
# train Loss: 0.0253 Acc: 0.9963
# val Loss: 0.7945 Acc: 0.8089
#
# Epoch 9/24
# ----------
# train Loss: 0.0315 Acc: 0.9948
# val Loss: 0.7599 Acc: 0.8103
#
# Epoch 10/24
# ----------
# train Loss: 0.0315 Acc: 0.9946
# val Loss: 0.7585 Acc: 0.8079
#
# Epoch 11/24
# ----------
# train Loss: 0.0268 Acc: 0.9952
# val Loss: 0.8302 Acc: 0.8044
#
# Epoch 12/24
# ----------
# train Loss: 0.0296 Acc: 0.9948
# val Loss: 0.8129 Acc: 0.8044
#
# Epoch 13/24
# ----------
# train Loss: 0.0315 Acc: 0.9935
# val Loss: 0.7925 Acc: 0.8089
#
# Epoch 14/24
# ----------
# train Loss: 0.0259 Acc: 0.9965
# val Loss: 0.7929 Acc: 0.8055
#
# Epoch 15/24
# ----------
# train Loss: 0.0276 Acc: 0.9948
# val Loss: 0.8010 Acc: 0.8076
#
# Epoch 16/24
# ----------
# train Loss: 0.0259 Acc: 0.9957
# val Loss: 0.7417 Acc: 0.8113
#
# Epoch 17/24
# ----------
# train Loss: 0.0335 Acc: 0.9939
# val Loss: 0.7004 Acc: 0.8156
#
# Epoch 18/24
# ----------
# train Loss: 0.0268 Acc: 0.9959
# val Loss: 0.7633 Acc: 0.8087
#
# Epoch 19/24
# ----------
# train Loss: 0.0261 Acc: 0.9957
# val Loss: 0.8304 Acc: 0.8028
#
# Epoch 20/24
# ----------
# train Loss: 0.0266 Acc: 0.9950
# val Loss: 0.7515 Acc: 0.8095
#
# Epoch 21/24
# ----------
# train Loss: 0.0293 Acc: 0.9946
# val Loss: 0.7371 Acc: 0.8121
#
# Epoch 22/24
# ----------
# train Loss: 0.0319 Acc: 0.9952
# val Loss: 0.8330 Acc: 0.8020
#
# Epoch 23/24
# ----------
# train Loss: 0.0290 Acc: 0.9944
# val Loss: 0.7101 Acc: 0.8108
#
# Epoch 24/24
# ----------
# train Loss: 0.0251 Acc: 0.9950
# val Loss: 0.7403 Acc: 0.8097
#
# Training complete in 15m 11s
# Best val Acc: 0.815628

# %%
def visualize_model3(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
#             inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model3(model_ft3)

# %%
def train_model4(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ft4 = models.maxvit_t(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs4 = model_ft4.classifier[3].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft4.fc = nn.Linear(num_ftrs4, 11)

model_ft4 = model_ft4.to(device)

criterion4 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft4 = optim.SGD(model_ft4.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler4 = lr_scheduler.StepLR(optimizer_ft4, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MaxVit_T_Weights.IMAGENET1K_V1`. You can also use `weights=MaxVit_T_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
model_ft4 = train_model4(model_ft4, criterion4, optimizer_ft4, exp_lr_scheduler4, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.9587 Acc: 0.7575
# val Loss: 1.0620 Acc: 0.6805
#
# Epoch 1/24
# ----------
# train Loss: 0.1182 Acc: 0.9707
# val Loss: 1.2508 Acc: 0.7022
#
# Epoch 2/24
# ----------
# train Loss: 0.0724 Acc: 0.9800
# val Loss: 1.0546 Acc: 0.7337
#
# Epoch 3/24
# ----------
# train Loss: 0.0411 Acc: 0.9878
# val Loss: 0.6964 Acc: 0.8210
#
# Epoch 4/24
# ----------
# train Loss: 0.0388 Acc: 0.9902
# val Loss: 0.5100 Acc: 0.8657
#
# Epoch 5/24
# ----------
# train Loss: 0.0247 Acc: 0.9933
# val Loss: 0.7427 Acc: 0.8199
#
# Epoch 6/24
# ----------
# train Loss: 0.0235 Acc: 0.9930
# val Loss: 0.7490 Acc: 0.8234
#
# Epoch 7/24
# ----------
# train Loss: 0.0202 Acc: 0.9950
# val Loss: 0.7202 Acc: 0.8237
#
# Epoch 8/24
# ----------
# train Loss: 0.0211 Acc: 0.9939
# val Loss: 0.6305 Acc: 0.8405
#
# Epoch 9/24
# ----------
# train Loss: 0.0184 Acc: 0.9950
# val Loss: 0.6326 Acc: 0.8368
#
# Epoch 10/24
# ----------
# train Loss: 0.0201 Acc: 0.9954
# val Loss: 0.5417 Acc: 0.8766
#
# Epoch 11/24
# ----------
# train Loss: 0.0171 Acc: 0.9961
# val Loss: 0.7398 Acc: 0.8188
#
# Epoch 12/24
# ----------
# train Loss: 0.0186 Acc: 0.9965
# val Loss: 1.0231 Acc: 0.7637
#
# Epoch 13/24
# ----------
# train Loss: 0.0174 Acc: 0.9950
# val Loss: 0.7203 Acc: 0.8443
#
# Epoch 14/24
# ----------
# train Loss: 0.0181 Acc: 0.9950
# val Loss: 0.6309 Acc: 0.8461
#
# Epoch 15/24
# ----------
# train Loss: 0.0160 Acc: 0.9963
# val Loss: 0.7463 Acc: 0.8097
#
# Epoch 16/24
# ----------
# train Loss: 0.0153 Acc: 0.9967
# val Loss: 0.6681 Acc: 0.8381
#
# Epoch 17/24
# ----------
# train Loss: 0.0204 Acc: 0.9952
# val Loss: 0.4279 Acc: 0.8873
#
# Epoch 18/24
# ----------
# train Loss: 0.0172 Acc: 0.9972
# val Loss: 0.7051 Acc: 0.8427
#
# Epoch 19/24
# ----------
# train Loss: 0.0140 Acc: 0.9967
# val Loss: 0.6780 Acc: 0.8448
#
# Epoch 20/24
# ----------
# train Loss: 0.0197 Acc: 0.9948
# val Loss: 0.5175 Acc: 0.8627
#
# Epoch 21/24
# ----------
# train Loss: 0.0207 Acc: 0.9930
# val Loss: 0.6966 Acc: 0.8349
#
# Epoch 22/24
# ----------
# train Loss: 0.0175 Acc: 0.9952
# val Loss: 0.8508 Acc: 0.7870
#
# Epoch 23/24
# ----------
# train Loss: 0.0181 Acc: 0.9965
# val Loss: 0.7823 Acc: 0.8202
#
# Epoch 24/24
# ----------
# train Loss: 0.0192 Acc: 0.9954
# val Loss: 0.7703 Acc: 0.8178
#
# Training complete in 23m 39s
# Best val Acc: 0.887343

# %%
print(model_ft4.classifier[3])
# Out:
# Linear(in_features=512, out_features=512, bias=True)

# %%
print(model_ft2)
# Out:
# VisionTransformer(
#   (conv_proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#   (encoder): Encoder(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (layers): Sequential(
#       (encoder_layer_0): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_1): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_2): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_3): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_4): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_5): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_6): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_7): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_8): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_9): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_10): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_11): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   )
#   (heads): Sequential(
#     (head): Linear(in_features=768, out_features=1000, bias=True)
#   )
#   (fc): Linear(in_features=768, out_features=11, bias=True)
# )

# %%
def visualize_model4(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model4(model_ft4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 visualize_model4(model_ft4)
#
# Cell In[52], line 20, in visualize_model4(model, num_images)
#      18 ax = plt.subplot(num_images//2, 2, images_so_far)
#      19 ax.axis('off')
# ---> 20 ax.set_title('predicted: {}'.format(class_names[preds[j]]))
#      21 imshow(inputs.cpu().data[j])
#      23 if images_so_far == num_images:
#
# IndexError: list index out of range

# %%
def train_model5(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ft5 = models.vgg16(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs5 = model_ft5.classifier[6].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft5.fc = nn.Linear(num_ftrs5, 11)

model_ft5 = model_ft5.to(device)

criterion5 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft5 = optim.SGD(model_ft5.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler5 = lr_scheduler.StepLR(optimizer_ft5, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ft5 = train_model5(model_ft5, criterion5, optimizer_ft5, exp_lr_scheduler5, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.6571 Acc: 0.8247
# val Loss: 1.6387 Acc: 0.6246
#
# Epoch 1/24
# ----------
# train Loss: 0.1231 Acc: 0.9629
# val Loss: 1.0294 Acc: 0.7774
#
# Epoch 2/24
# ----------
# train Loss: 0.0634 Acc: 0.9807
# val Loss: 1.4090 Acc: 0.7271
#
# Epoch 3/24
# ----------
# train Loss: 0.0510 Acc: 0.9850
# val Loss: 0.9906 Acc: 0.8041
#
# Epoch 4/24
# ----------
# train Loss: 0.0374 Acc: 0.9907
# val Loss: 1.1417 Acc: 0.7707
#
# Epoch 5/24
# ----------
# train Loss: 0.0209 Acc: 0.9944
# val Loss: 0.9829 Acc: 0.8057
#
# Epoch 6/24
# ----------
# train Loss: 0.0118 Acc: 0.9972
# val Loss: 0.9632 Acc: 0.8113
#
# Epoch 7/24
# ----------
# train Loss: 0.0095 Acc: 0.9970
# val Loss: 0.9589 Acc: 0.8121
#
# Epoch 8/24
# ----------
# train Loss: 0.0140 Acc: 0.9954
# val Loss: 0.9719 Acc: 0.8140
#
# Epoch 9/24
# ----------
# train Loss: 0.0058 Acc: 0.9985
# val Loss: 1.0065 Acc: 0.8164
#
# Epoch 10/24
# ----------
# train Loss: 0.0077 Acc: 0.9983
# val Loss: 1.0048 Acc: 0.8178
#
# Epoch 11/24
# ----------
# train Loss: 0.0123 Acc: 0.9954
# val Loss: 1.0036 Acc: 0.8172
#
# Epoch 12/24
# ----------
# train Loss: 0.0131 Acc: 0.9950
# val Loss: 1.0002 Acc: 0.8175
#
# Epoch 13/24
# ----------
# train Loss: 0.0081 Acc: 0.9974
# val Loss: 1.0030 Acc: 0.8172
#
# Epoch 14/24
# ----------
# train Loss: 0.0062 Acc: 0.9985
# val Loss: 0.9973 Acc: 0.8172
#
# Epoch 15/24
# ----------
# train Loss: 0.0061 Acc: 0.9989
# val Loss: 0.9966 Acc: 0.8172
#
# Epoch 16/24
# ----------
# train Loss: 0.0058 Acc: 0.9983
# val Loss: 0.9965 Acc: 0.8172
#
# Epoch 17/24
# ----------
# train Loss: 0.0100 Acc: 0.9967
# val Loss: 0.9968 Acc: 0.8175
#
# Epoch 18/24
# ----------
# train Loss: 0.0069 Acc: 0.9978
# val Loss: 0.9961 Acc: 0.8175
#
# Epoch 19/24
# ----------
# train Loss: 0.0071 Acc: 0.9978
# val Loss: 0.9960 Acc: 0.8175
#
# Epoch 20/24
# ----------
# train Loss: 0.0093 Acc: 0.9974
# val Loss: 0.9960 Acc: 0.8175
#
# Epoch 21/24
# ----------
# train Loss: 0.0089 Acc: 0.9974
# val Loss: 0.9959 Acc: 0.8178
#
# Epoch 22/24
# ----------
# train Loss: 0.0058 Acc: 0.9985
# val Loss: 0.9959 Acc: 0.8175
#
# Epoch 23/24
# ----------
# train Loss: 0.0056 Acc: 0.9980
# val Loss: 0.9959 Acc: 0.8175
#
# Epoch 24/24
# ----------
# train Loss: 0.0066 Acc: 0.9976
# val Loss: 0.9959 Acc: 0.8175
#
# Training complete in 23m 30s
# Best val Acc: 0.817768

# %%
print(model_ft5)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
#   (fc): Linear(in_features=4096, out_features=11, bias=True)
# )

# %%
def visualize_model5(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
#             inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model5(model_ft5)

# %%
def train_model6(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ft6 = models.swin_v2_b(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs6 = model_ft6.head.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft6.fc = nn.Linear(num_ftrs6, 11)

model_ft6 = model_ft6.to(device)

criterion6 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft6 = optim.SGD(model_ft6.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler6 = lr_scheduler.StepLR(optimizer_ft6, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Swin_V2_B_Weights.IMAGENET1K_V1`. You can also use `weights=Swin_V2_B_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
print(model_ft6)
# Out:
# SwinTransformer(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#       (1): Permute()
#       (2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): Sequential(
#       (0): SwinTransformerBlockV2(
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=128, out_features=384, bias=True)
#           (proj): Linear(in_features=128, out_features=128, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=4, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=128, out_features=512, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=512, out_features=128, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): SwinTransformerBlockV2(
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=128, out_features=384, bias=True)
#           (proj): Linear(in_features=128, out_features=128, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=4, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.021739130434782608, mode=row)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=128, out_features=512, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=512, out_features=128, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): PatchMergingV2(
#       (reduction): Linear(in_features=512, out_features=256, bias=False)
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (3): Sequential(
#       (0): SwinTransformerBlockV2(
#         (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=256, out_features=768, bias=True)
#           (proj): Linear(in_features=256, out_features=256, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=8, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.043478260869565216, mode=row)
#         (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=1024, out_features=256, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): SwinTransformerBlockV2(
#         (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=256, out_features=768, bias=True)
#           (proj): Linear(in_features=256, out_features=256, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=8, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06521739130434782, mode=row)
#         (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=1024, out_features=256, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (4): PatchMergingV2(
#       (reduction): Linear(in_features=1024, out_features=512, bias=False)
#       (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (5): Sequential(
#       (0): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08695652173913043, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10869565217391304, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13043478260869565, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15217391304347827, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (4): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17391304347826086, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (5): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1956521739130435, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (6): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.21739130434782608, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (7): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.2391304347826087, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (8): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.2608695652173913, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (9): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.2826086956521739, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (10): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.30434782608695654, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (11): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.32608695652173914, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (12): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.34782608695652173, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (13): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.3695652173913043, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (14): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.391304347826087, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (15): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.41304347826086957, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (16): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.43478260869565216, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (17): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.45652173913043476, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (6): PatchMergingV2(
#       (reduction): Linear(in_features=2048, out_features=1024, bias=False)
#       (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (7): Sequential(
#       (0): SwinTransformerBlockV2(
#         (norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=32, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.4782608695652174, mode=row)
#         (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=1024, out_features=4096, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=4096, out_features=1024, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): SwinTransformerBlockV2(
#         (norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=32, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.5, mode=row)
#         (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=1024, out_features=4096, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=4096, out_features=1024, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (permute): Permute()
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (head): Linear(in_features=1024, out_features=1000, bias=True)
#   (fc): Linear(in_features=1024, out_features=11, bias=True)
# )

# %%
model_ft6 = train_model6(model_ft6, criterion6, optimizer_ft6, exp_lr_scheduler6, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 1.2498 Acc: 0.6361
# val Loss: 1.1412 Acc: 0.6821
#
# Epoch 1/24
# ----------
# train Loss: 0.1560 Acc: 0.9507
# val Loss: 0.9635 Acc: 0.7391
#
# Epoch 2/24
# ----------
# train Loss: 0.0766 Acc: 0.9765
# val Loss: 0.9210 Acc: 0.7725
#
# Epoch 3/24
# ----------
# train Loss: 0.0486 Acc: 0.9846
# val Loss: 0.9828 Acc: 0.7972
#
# Epoch 4/24
# ----------
# train Loss: 0.0325 Acc: 0.9883
# val Loss: 0.8723 Acc: 0.8282
#
# Epoch 5/24
# ----------
# train Loss: 0.0212 Acc: 0.9924
# val Loss: 0.8695 Acc: 0.8247
#
# Epoch 6/24
# ----------
# train Loss: 0.0151 Acc: 0.9963
# val Loss: 0.8638 Acc: 0.8282
#
# Epoch 7/24
# ----------
# train Loss: 0.0126 Acc: 0.9961
# val Loss: 0.8739 Acc: 0.8274
#
# Epoch 8/24
# ----------
# train Loss: 0.0179 Acc: 0.9948
# val Loss: 0.8614 Acc: 0.8309
#
# Epoch 9/24
# ----------
# train Loss: 0.0131 Acc: 0.9957
# val Loss: 0.8716 Acc: 0.8306
#
# Epoch 10/24
# ----------
# train Loss: 0.0154 Acc: 0.9957
# val Loss: 0.8650 Acc: 0.8303
#
# Epoch 11/24
# ----------
# train Loss: 0.0112 Acc: 0.9963
# val Loss: 0.8642 Acc: 0.8309
#
# Epoch 12/24
# ----------
# train Loss: 0.0102 Acc: 0.9970
# val Loss: 0.8518 Acc: 0.8314
#
# Epoch 13/24
# ----------
# train Loss: 0.0111 Acc: 0.9961
# val Loss: 0.8438 Acc: 0.8328
#
# Epoch 14/24
# ----------
# train Loss: 0.0114 Acc: 0.9967
# val Loss: 0.8393 Acc: 0.8333
#
# Epoch 15/24
# ----------
# train Loss: 0.0113 Acc: 0.9970
# val Loss: 0.8385 Acc: 0.8336
#
# Epoch 16/24
# ----------
# train Loss: 0.0100 Acc: 0.9961
# val Loss: 0.8381 Acc: 0.8338
#
# Epoch 17/24
# ----------
# train Loss: 0.0115 Acc: 0.9967
# val Loss: 0.8377 Acc: 0.8338
#
# Epoch 18/24
# ----------
# train Loss: 0.0111 Acc: 0.9965
# val Loss: 0.8369 Acc: 0.8338
#
# Epoch 19/24
# ----------
# train Loss: 0.0109 Acc: 0.9976
# val Loss: 0.8370 Acc: 0.8341
#
# Epoch 20/24
# ----------
# train Loss: 0.0119 Acc: 0.9970
# val Loss: 0.8369 Acc: 0.8341
#
# Epoch 21/24
# ----------
# train Loss: 0.0137 Acc: 0.9961
# val Loss: 0.8369 Acc: 0.8341
#
# Epoch 22/24
# ----------
# train Loss: 0.0079 Acc: 0.9983
# val Loss: 0.8368 Acc: 0.8341
#
# Epoch 23/24
# ----------
# train Loss: 0.0097 Acc: 0.9972
# val Loss: 0.8368 Acc: 0.8341
#
# Epoch 24/24
# ----------
# train Loss: 0.0132 Acc: 0.9959
# val Loss: 0.8368 Acc: 0.8341
#
# Training complete in 36m 26s
# Best val Acc: 0.834092

# %%
def visualize_model6(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model6(model_ft6)

# %%
def train_model7(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ft7 = models.convnext_large(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs7 = model_ft7.classifier[2].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft7.fc = nn.Linear(num_ftrs7, 11)

model_ft7 = model_ft7.to(device)

criterion7 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft7 = optim.SGD(model_ft7.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler7 = lr_scheduler.StepLR(optimizer_ft7, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ConvNeXt_Large_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Large_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
print(model_ft7)
# Out:
# ConvNeXt(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 192, kernel_size=(4, 4), stride=(4, 4))
#       (1): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#     )
#     (1): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.014285714285714285, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.02857142857142857, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(192, 384, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (3): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.04285714285714286, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.05714285714285714, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.07142857142857142, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): LayerNorm2d((384,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(384, 768, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (5): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.08571428571428572, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.11428571428571428, mode=row)
#       )
#       (3): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.12857142857142856, mode=row)
#       )
#       (4): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.14285714285714285, mode=row)
#       )
#       (5): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.15714285714285714, mode=row)
#       )
#       (6): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.17142857142857143, mode=row)
#       )
#       (7): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.18571428571428572, mode=row)
#       )
#       (8): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2, mode=row)
#       )
#       (9): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.21428571428571427, mode=row)
#       )
#       (10): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.22857142857142856, mode=row)
#       )
#       (11): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.24285714285714285, mode=row)
#       )
#       (12): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2571428571428571, mode=row)
#       )
#       (13): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2714285714285714, mode=row)
#       )
#       (14): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2857142857142857, mode=row)
#       )
#       (15): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.3, mode=row)
#       )
#       (16): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.3142857142857143, mode=row)
#       )
#       (17): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.32857142857142857, mode=row)
#       )
#       (18): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.34285714285714286, mode=row)
#       )
#       (19): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.35714285714285715, mode=row)
#       )
#       (20): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.37142857142857144, mode=row)
#       )
#       (21): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.38571428571428573, mode=row)
#       )
#       (22): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4, mode=row)
#       )
#       (23): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4142857142857143, mode=row)
#       )
#       (24): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.42857142857142855, mode=row)
#       )
#       (25): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.44285714285714284, mode=row)
#       )
#       (26): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.45714285714285713, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(768, 1536, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (7): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1536, 1536, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1536)
#           (1): Permute()
#           (2): LayerNorm((1536,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1536, out_features=6144, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=6144, out_features=1536, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4714285714285714, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1536, 1536, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1536)
#           (1): Permute()
#           (2): LayerNorm((1536,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1536, out_features=6144, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=6144, out_features=1536, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4857142857142857, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1536, 1536, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1536)
#           (1): Permute()
#           (2): LayerNorm((1536,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1536, out_features=6144, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=6144, out_features=1536, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5, mode=row)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): LayerNorm2d((1536,), eps=1e-06, elementwise_affine=True)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=1536, out_features=1000, bias=True)
#   )
#   (fc): Linear(in_features=1536, out_features=11, bias=True)
# )

# %%
model_ft7 = train_model7(model_ft7, criterion7, optimizer_ft7, exp_lr_scheduler7, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 1.5936 Acc: 0.5103
# val Loss: 1.3155 Acc: 0.5951
#
# Epoch 1/24
# ----------
# train Loss: 0.1372 Acc: 0.9672
# val Loss: 1.1464 Acc: 0.6888
#
# Epoch 2/24
# ----------
# train Loss: 0.0627 Acc: 0.9846
# val Loss: 0.9491 Acc: 0.7822
#
# Epoch 3/24
# ----------
# train Loss: 0.0386 Acc: 0.9920
# val Loss: 0.7157 Acc: 0.8303
#
# Epoch 4/24
# ----------
# train Loss: 0.0316 Acc: 0.9920
# val Loss: 0.7536 Acc: 0.8194
#
# Epoch 5/24
# ----------
# train Loss: 0.0151 Acc: 0.9974
# val Loss: 0.7418 Acc: 0.8360
#
# Epoch 6/24
# ----------
# train Loss: 0.0140 Acc: 0.9978
# val Loss: 0.7313 Acc: 0.8373
#
# Epoch 7/24
# ----------
# train Loss: 0.0140 Acc: 0.9967
# val Loss: 0.7674 Acc: 0.8354
#
# Epoch 8/24
# ----------
# train Loss: 0.0132 Acc: 0.9967
# val Loss: 0.7735 Acc: 0.8333
#
# Epoch 9/24
# ----------
# train Loss: 0.0118 Acc: 0.9978
# val Loss: 0.7050 Acc: 0.8448
#
# Epoch 10/24
# ----------
# train Loss: 0.0111 Acc: 0.9980
# val Loss: 0.7095 Acc: 0.8437
#
# Epoch 11/24
# ----------
# train Loss: 0.0108 Acc: 0.9983
# val Loss: 0.7105 Acc: 0.8435
#
# Epoch 12/24
# ----------
# train Loss: 0.0107 Acc: 0.9987
# val Loss: 0.7149 Acc: 0.8429
#
# Epoch 13/24
# ----------
# train Loss: 0.0122 Acc: 0.9980
# val Loss: 0.7171 Acc: 0.8419
#
# Epoch 14/24
# ----------
# train Loss: 0.0102 Acc: 0.9980
# val Loss: 0.7220 Acc: 0.8427
#
# Epoch 15/24
# ----------
# train Loss: 0.0094 Acc: 0.9983
# val Loss: 0.7221 Acc: 0.8427
#
# Epoch 16/24
# ----------
# train Loss: 0.0126 Acc: 0.9976
# val Loss: 0.7225 Acc: 0.8424
#
# Epoch 17/24
# ----------
# train Loss: 0.0101 Acc: 0.9987
# val Loss: 0.7224 Acc: 0.8424
#
# Epoch 18/24
# ----------
# train Loss: 0.0107 Acc: 0.9983
# val Loss: 0.7226 Acc: 0.8424
#
# Epoch 19/24
# ----------
# train Loss: 0.0103 Acc: 0.9976
# val Loss: 0.7232 Acc: 0.8424
#
# Epoch 20/24
# ----------
# train Loss: 0.0093 Acc: 0.9985
# val Loss: 0.7232 Acc: 0.8424
#
# Epoch 21/24
# ----------
# train Loss: 0.0131 Acc: 0.9970
# val Loss: 0.7233 Acc: 0.8424
#
# Epoch 22/24
# ----------
# train Loss: 0.0111 Acc: 0.9978
# val Loss: 0.7233 Acc: 0.8424
#
# Epoch 23/24
# ----------
# train Loss: 0.0112 Acc: 0.9980
# val Loss: 0.7233 Acc: 0.8424
#
# Epoch 24/24
# ----------
# train Loss: 0.0113 Acc: 0.9978
# val Loss: 0.7233 Acc: 0.8424
#
# Training complete in 93m 32s
# Best val Acc: 0.844795

# %%
def visualize_model7(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
#             inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model7(model_ft7)

# %%
def train_model8(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(299,299), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
#                     outputs, aux_logits, __ = model(inputs)
                    outputs = model(inputs)
#                     print(outputs.logits)
#                     break
#                     print(len(outputs),outputs)
                    if len(outputs) == 2:
                        _, preds = torch.max(outputs[0], 1)
                        loss = criterion(outputs[0], labels)
                    else:
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)
#                     loss1 = criterion(outputs[0], labels)
#                     loss2 = criterion(outputs[1], labels)
#                     loss = loss1 + 0.4*loss2

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model8(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = F.interpolate(inputs, size=(299,299), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            if len(outputs) == 2:
                _, preds = torch.max(outputs[0], 1)
            else:
                _, preds = torch.max(outputs, 1)
            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft8 = models.inception_v3(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs8 = model_ft8.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft8.fc = nn.Linear(num_ftrs8, 11)

model_ft8 = model_ft8.to(device)

criterion8 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft8 = optim.SGD(model_ft8.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler8 = lr_scheduler.StepLR(optimizer_ft8, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ft8 = train_model8(model_ft8, criterion8, optimizer_ft8, exp_lr_scheduler8, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.6283 Acc: 0.8373
# val Loss: 0.8019 Acc: 0.7843
#
# Epoch 1/24
# ----------
# train Loss: 0.1067 Acc: 0.9744
# val Loss: 0.8535 Acc: 0.7897
#
# Epoch 2/24
# ----------
# train Loss: 0.0576 Acc: 0.9883
# val Loss: 0.5777 Acc: 0.8630
#
# Epoch 3/24
# ----------
# train Loss: 0.0514 Acc: 0.9891
# val Loss: 0.6458 Acc: 0.8373
#
# Epoch 4/24
# ----------
# train Loss: 0.0312 Acc: 0.9941
# val Loss: 0.6962 Acc: 0.8472
#
# Epoch 5/24
# ----------
# train Loss: 0.0181 Acc: 0.9957
# val Loss: 0.7630 Acc: 0.8469
#
# Epoch 6/24
# ----------
# train Loss: 0.0224 Acc: 0.9946
# val Loss: 0.7125 Acc: 0.8630
#
# Epoch 7/24
# ----------
# train Loss: 0.0188 Acc: 0.9965
# val Loss: 0.7769 Acc: 0.8571
#
# Epoch 8/24
# ----------
# train Loss: 0.0162 Acc: 0.9972
# val Loss: 0.6889 Acc: 0.8609
#
# Epoch 9/24
# ----------
# train Loss: 0.0141 Acc: 0.9974
# val Loss: 0.6947 Acc: 0.8646
#
# Epoch 10/24
# ----------
# train Loss: 0.0161 Acc: 0.9972
# val Loss: 0.7046 Acc: 0.8622
#
# Epoch 11/24
# ----------
# train Loss: 0.0140 Acc: 0.9978
# val Loss: 0.6291 Acc: 0.8705
#
# Epoch 12/24
# ----------
# train Loss: 0.0167 Acc: 0.9961
# val Loss: 0.7260 Acc: 0.8590
#
# Epoch 13/24
# ----------
# train Loss: 0.0146 Acc: 0.9976
# val Loss: 0.6490 Acc: 0.8691
#
# Epoch 14/24
# ----------
# train Loss: 0.0144 Acc: 0.9972
# val Loss: 0.7784 Acc: 0.8563
#
# Epoch 15/24
# ----------
# train Loss: 0.0126 Acc: 0.9985
# val Loss: 0.7095 Acc: 0.8633
#
# Epoch 16/24
# ----------
# train Loss: 0.0145 Acc: 0.9980
# val Loss: 0.6451 Acc: 0.8683
#
# Epoch 17/24
# ----------
# train Loss: 0.0117 Acc: 0.9983
# val Loss: 0.7769 Acc: 0.8539
#
# Epoch 18/24
# ----------
# train Loss: 0.0151 Acc: 0.9970
# val Loss: 0.6946 Acc: 0.8625
#
# Epoch 19/24
# ----------
# train Loss: 0.0132 Acc: 0.9978
# val Loss: 0.6996 Acc: 0.8641
#
# Epoch 20/24
# ----------
# train Loss: 0.0107 Acc: 0.9987
# val Loss: 0.6953 Acc: 0.8649
#
# Epoch 21/24
# ----------
# train Loss: 0.0142 Acc: 0.9980
# val Loss: 0.7109 Acc: 0.8617
#
# Epoch 22/24
# ----------
# train Loss: 0.0197 Acc: 0.9972
# val Loss: 0.6638 Acc: 0.8675
#
# Epoch 23/24
# ----------
# train Loss: 0.0125 Acc: 0.9976
# val Loss: 0.7416 Acc: 0.8598
#
# Epoch 24/24
# ----------
# train Loss: 0.0134 Acc: 0.9983
# val Loss: 0.7129 Acc: 0.8600
#
# Training complete in 17m 47s
# Best val Acc: 0.870484

# %%
visualize_model8(model_ft8)

# %%
def train_model9(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model9(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
#             inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft9 = models.mobilenet_v3_large(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs9 = model_ft9.classifier[3].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft9.fc = nn.Linear(num_ftrs9, 11)

model_ft9 = model_ft9.to(device)

criterion9 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft9 = optim.SGD(model_ft9.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler9 = lr_scheduler.StepLR(optimizer_ft9, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Large_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Large_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
print(model_ft9)
# Out:
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (13): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (14): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (15): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (16): Conv2dNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=960, out_features=1280, bias=True)
#     (1): Hardswish()
#     (2): Dropout(p=0.2, inplace=True)
#     (3): Linear(in_features=1280, out_features=1000, bias=True)
#   )
#   (fc): Linear(in_features=1280, out_features=11, bias=True)
# )

# %%
model_ft9 = train_model9(model_ft9, criterion9, optimizer_ft9, exp_lr_scheduler9, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.7631 Acc: 0.8332
# val Loss: 1.1512 Acc: 0.6639
#
# Epoch 1/24
# ----------
# train Loss: 0.1083 Acc: 0.9689
# val Loss: 0.8710 Acc: 0.7822
#
# Epoch 2/24
# ----------
# train Loss: 0.0664 Acc: 0.9815
# val Loss: 0.8633 Acc: 0.8194
#
# Epoch 3/24
# ----------
# train Loss: 0.0481 Acc: 0.9859
# val Loss: 0.8224 Acc: 0.8325
#
# Epoch 4/24
# ----------
# train Loss: 0.0360 Acc: 0.9904
# val Loss: 1.0391 Acc: 0.8164
#
# Epoch 5/24
# ----------
# train Loss: 0.0320 Acc: 0.9894
# val Loss: 0.8959 Acc: 0.8239
#
# Epoch 6/24
# ----------
# train Loss: 0.0245 Acc: 0.9930
# val Loss: 0.8871 Acc: 0.8287
#
# Epoch 7/24
# ----------
# train Loss: 0.0233 Acc: 0.9924
# val Loss: 0.8859 Acc: 0.8354
#
# Epoch 8/24
# ----------
# train Loss: 0.0222 Acc: 0.9935
# val Loss: 0.8735 Acc: 0.8352
#
# Epoch 9/24
# ----------
# train Loss: 0.0204 Acc: 0.9937
# val Loss: 0.8771 Acc: 0.8336
#
# Epoch 10/24
# ----------
# train Loss: 0.0204 Acc: 0.9944
# val Loss: 0.8773 Acc: 0.8344
#
# Epoch 11/24
# ----------
# train Loss: 0.0225 Acc: 0.9939
# val Loss: 0.9054 Acc: 0.8322
#
# Epoch 12/24
# ----------
# train Loss: 0.0155 Acc: 0.9950
# val Loss: 0.8888 Acc: 0.8320
#
# Epoch 13/24
# ----------
# train Loss: 0.0219 Acc: 0.9939
# val Loss: 0.8705 Acc: 0.8354
#
# Epoch 14/24
# ----------
# train Loss: 0.0186 Acc: 0.9946
# val Loss: 0.8589 Acc: 0.8360
#
# Epoch 15/24
# ----------
# train Loss: 0.0231 Acc: 0.9935
# val Loss: 0.8623 Acc: 0.8373
#
# Epoch 16/24
# ----------
# train Loss: 0.0215 Acc: 0.9933
# val Loss: 0.8916 Acc: 0.8322
#
# Epoch 17/24
# ----------
# train Loss: 0.0219 Acc: 0.9933
# val Loss: 0.8858 Acc: 0.8357
#
# Epoch 18/24
# ----------
# train Loss: 0.0186 Acc: 0.9952
# val Loss: 0.8888 Acc: 0.8349
#
# Epoch 19/24
# ----------
# train Loss: 0.0219 Acc: 0.9939
# val Loss: 0.8808 Acc: 0.8360
#
# Epoch 20/24
# ----------
# train Loss: 0.0206 Acc: 0.9946
# val Loss: 0.8611 Acc: 0.8352
#
# Epoch 21/24
# ----------
# train Loss: 0.0218 Acc: 0.9935
# val Loss: 0.8949 Acc: 0.8357
#
# Epoch 22/24
# ----------
# train Loss: 0.0259 Acc: 0.9924
# val Loss: 0.8934 Acc: 0.8354
#
# Epoch 23/24
# ----------
# train Loss: 0.0236 Acc: 0.9933
# val Loss: 0.9191 Acc: 0.8330
#
# Epoch 24/24
# ----------
# train Loss: 0.0196 Acc: 0.9946
# val Loss: 0.9003 Acc: 0.8322
#
# Training complete in 15m 25s
# Best val Acc: 0.837303

# %%
visualize_model9(model_ft9)

# %%
def train_model10(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model10(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft10 = models.mobilenet_v3_large(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs10 = model_ft10.classifier[3].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft10.fc = nn.Linear(num_ftrs10, 11)

model_ft10 = model_ft10.to(device)

criterion10 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft10 = optim.SGD(model_ft10.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler10 = lr_scheduler.StepLR(optimizer_ft10, step_size=5, gamma=0.1)

# %%
print(model_ft10)
# Out:
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (13): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (14): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (15): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (16): Conv2dNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=960, out_features=1280, bias=True)
#     (1): Hardswish()
#     (2): Dropout(p=0.2, inplace=True)
#     (3): Linear(in_features=1280, out_features=1000, bias=True)
#   )
#   (fc): Linear(in_features=1280, out_features=11, bias=True)
# )

# %%
model_ft10 = train_model10(model_ft10, criterion10, optimizer_ft10, exp_lr_scheduler10, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.7833 Acc: 0.8349
# val Loss: 1.0335 Acc: 0.7073
#
# Epoch 1/24
# ----------
# train Loss: 0.1221 Acc: 0.9670
# val Loss: 1.0671 Acc: 0.7699
#
# Epoch 2/24
# ----------
# train Loss: 0.0559 Acc: 0.9846
# val Loss: 0.7558 Acc: 0.8041
#
# Epoch 3/24
# ----------
# train Loss: 0.0540 Acc: 0.9833
# val Loss: 0.9490 Acc: 0.8084
#
# Epoch 4/24
# ----------
# train Loss: 0.0358 Acc: 0.9891
# val Loss: 1.0229 Acc: 0.8105
#
# Epoch 5/24
# ----------
# train Loss: 0.0283 Acc: 0.9911
# val Loss: 1.0195 Acc: 0.8229
#
# Epoch 6/24
# ----------
# train Loss: 0.0192 Acc: 0.9944
# val Loss: 0.9544 Acc: 0.8328
#
# Epoch 7/24
# ----------
# train Loss: 0.0234 Acc: 0.9928
# val Loss: 0.9088 Acc: 0.8440
#
# Epoch 8/24
# ----------
# train Loss: 0.0244 Acc: 0.9935
# val Loss: 0.8621 Acc: 0.8461
#
# Epoch 9/24
# ----------
# train Loss: 0.0208 Acc: 0.9937
# val Loss: 0.8980 Acc: 0.8448
#
# Epoch 10/24
# ----------
# train Loss: 0.0277 Acc: 0.9933
# val Loss: 0.9155 Acc: 0.8400
#
# Epoch 11/24
# ----------
# train Loss: 0.0179 Acc: 0.9959
# val Loss: 0.9052 Acc: 0.8429
#
# Epoch 12/24
# ----------
# train Loss: 0.0208 Acc: 0.9935
# val Loss: 0.9149 Acc: 0.8410
#
# Epoch 13/24
# ----------
# train Loss: 0.0194 Acc: 0.9950
# val Loss: 0.9309 Acc: 0.8392
#
# Epoch 14/24
# ----------
# train Loss: 0.0207 Acc: 0.9941
# val Loss: 0.8947 Acc: 0.8443
#
# Epoch 15/24
# ----------
# train Loss: 0.0149 Acc: 0.9961
# val Loss: 0.9033 Acc: 0.8421
#
# Epoch 16/24
# ----------
# train Loss: 0.0173 Acc: 0.9952
# val Loss: 0.9218 Acc: 0.8410
#
# Epoch 17/24
# ----------
# train Loss: 0.0191 Acc: 0.9941
# val Loss: 0.9101 Acc: 0.8443
#
# Epoch 18/24
# ----------
# train Loss: 0.0179 Acc: 0.9948
# val Loss: 0.8873 Acc: 0.8461
#
# Epoch 19/24
# ----------
# train Loss: 0.0246 Acc: 0.9922
# val Loss: 0.9146 Acc: 0.8421
#
# Epoch 20/24
# ----------
# train Loss: 0.0179 Acc: 0.9954
# val Loss: 0.9134 Acc: 0.8443
#
# Epoch 21/24
# ----------
# train Loss: 0.0215 Acc: 0.9941
# val Loss: 0.9205 Acc: 0.8410
#
# Epoch 22/24
# ----------
# train Loss: 0.0220 Acc: 0.9933
# val Loss: 0.8947 Acc: 0.8445
#
# Epoch 23/24
# ----------
# train Loss: 0.0153 Acc: 0.9948
# val Loss: 0.9143 Acc: 0.8437
#
# Epoch 24/24
# ----------
# train Loss: 0.0209 Acc: 0.9946
# val Loss: 0.9085 Acc: 0.8437
#
# Training complete in 15m 53s
# Best val Acc: 0.846133

# %%
visualize_model9(model_ft10)

# %%
def train_model11(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model11(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft11 = models.mnasnet1_3(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs11 = model_ft11.classifier[1].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft11.fc = nn.Linear(num_ftrs11, 11)

model_ft11 = model_ft11.to(device)

criterion11 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft11 = optim.SGD(model_ft11.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler11 = lr_scheduler.StepLR(optimizer_ft11, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MNASNet1_3_Weights.IMAGENET1K_V1`. You can also use `weights=MNASNet1_3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
print(model_ft11)
# Out:
# MNASNet(
#   (layers): Sequential(
#     (0): Conv2d(3, 40, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(40, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#     (4): BatchNorm2d(40, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(40, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (7): BatchNorm2d(24, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#     (8): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#           (4): BatchNorm2d(72, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(72, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(32, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (1): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(32, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(32, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (2): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(32, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(32, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(32, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(96, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(56, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (1): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(56, 168, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(168, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(168, 168, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=168, bias=False)
#           (4): BatchNorm2d(168, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(168, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(56, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (2): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(56, 168, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(168, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(168, 168, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=168, bias=False)
#           (4): BatchNorm2d(168, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(168, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(56, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(336, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(336, 336, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=336, bias=False)
#           (4): BatchNorm2d(336, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(336, 104, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(104, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (1): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(104, 624, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(624, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(624, 624, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=624, bias=False)
#           (4): BatchNorm2d(624, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(624, 104, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(104, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (2): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(104, 624, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(624, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(624, 624, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=624, bias=False)
#           (4): BatchNorm2d(624, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(624, 104, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(104, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(104, 624, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(624, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(624, 624, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=624, bias=False)
#           (4): BatchNorm2d(624, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(624, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(128, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (1): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#           (4): BatchNorm2d(768, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(128, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(768, 768, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=768, bias=False)
#           (4): BatchNorm2d(768, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(768, 248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(248, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (1): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(248, 1488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1488, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1488, 1488, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1488, bias=False)
#           (4): BatchNorm2d(1488, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(1488, 248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(248, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (2): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(248, 1488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1488, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1488, 1488, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1488, bias=False)
#           (4): BatchNorm2d(1488, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(1488, 248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(248, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (3): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(248, 1488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1488, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1488, 1488, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1488, bias=False)
#           (4): BatchNorm2d(1488, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(1488, 248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(248, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (13): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(248, 1488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1488, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1488, 1488, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1488, bias=False)
#           (4): BatchNorm2d(1488, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(1488, 416, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(416, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (14): Conv2d(416, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (15): BatchNorm2d(1280, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
#   (fc): Linear(in_features=1280, out_features=11, bias=True)
# )

# %%
model_ft11 = train_model11(model_ft11, criterion11, optimizer_ft11, exp_lr_scheduler11, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 1.0887 Acc: 0.7806
# val Loss: 3.9609 Acc: 0.2815
#
# Epoch 1/24
# ----------
# train Loss: 0.1378 Acc: 0.9642
# val Loss: 2.7851 Acc: 0.4244
#
# Epoch 2/24
# ----------
# train Loss: 0.0896 Acc: 0.9733
# val Loss: 2.1843 Acc: 0.5277
#
# Epoch 3/24
# ----------
# train Loss: 0.0569 Acc: 0.9844
# val Loss: 1.4622 Acc: 0.6535
#
# Epoch 4/24
# ----------
# train Loss: 0.0498 Acc: 0.9887
# val Loss: 2.1301 Acc: 0.5502
#
# Epoch 5/24
# ----------
# train Loss: 0.0326 Acc: 0.9928
# val Loss: 1.5906 Acc: 0.6238
#
# Epoch 6/24
# ----------
# train Loss: 0.0309 Acc: 0.9917
# val Loss: 1.1394 Acc: 0.6998
#
# Epoch 7/24
# ----------
# train Loss: 0.0349 Acc: 0.9913
# val Loss: 1.0229 Acc: 0.7434
#
# Epoch 8/24
# ----------
# train Loss: 0.0268 Acc: 0.9928
# val Loss: 1.0389 Acc: 0.7672
#
# Epoch 9/24
# ----------
# train Loss: 0.0278 Acc: 0.9933
# val Loss: 1.0455 Acc: 0.7832
#
# Epoch 10/24
# ----------
# train Loss: 0.0258 Acc: 0.9935
# val Loss: 1.0148 Acc: 0.7905
#
# Epoch 11/24
# ----------
# train Loss: 0.0310 Acc: 0.9928
# val Loss: 0.9957 Acc: 0.7998
#
# Epoch 12/24
# ----------
# train Loss: 0.0303 Acc: 0.9933
# val Loss: 0.9892 Acc: 0.8025
#
# Epoch 13/24
# ----------
# train Loss: 0.0293 Acc: 0.9930
# val Loss: 0.9869 Acc: 0.8033
#
# Epoch 14/24
# ----------
# train Loss: 0.0300 Acc: 0.9926
# val Loss: 0.9847 Acc: 0.8047
#
# Epoch 15/24
# ----------
# train Loss: 0.0253 Acc: 0.9954
# val Loss: 0.9817 Acc: 0.8055
#
# Epoch 16/24
# ----------
# train Loss: 0.0315 Acc: 0.9915
# val Loss: 0.9745 Acc: 0.8052
#
# Epoch 17/24
# ----------
# train Loss: 0.0335 Acc: 0.9920
# val Loss: 0.9685 Acc: 0.8041
#
# Epoch 18/24
# ----------
# train Loss: 0.0202 Acc: 0.9965
# val Loss: 0.9661 Acc: 0.8044
#
# Epoch 19/24
# ----------
# train Loss: 0.0301 Acc: 0.9922
# val Loss: 0.9652 Acc: 0.8039
#
# Epoch 20/24
# ----------
# train Loss: 0.0281 Acc: 0.9941
# val Loss: 0.9642 Acc: 0.8036
#
# Epoch 21/24
# ----------
# train Loss: 0.0256 Acc: 0.9928
# val Loss: 0.9642 Acc: 0.8033
#
# Epoch 22/24
# ----------
# train Loss: 0.0226 Acc: 0.9954
# val Loss: 0.9637 Acc: 0.8044
#
# Epoch 23/24
# ----------
# train Loss: 0.0261 Acc: 0.9944
# val Loss: 0.9624 Acc: 0.8055
#
# Epoch 24/24
# ----------
# train Loss: 0.0268 Acc: 0.9935
# val Loss: 0.9601 Acc: 0.8052
#
# Training complete in 15m 56s
# Best val Acc: 0.805459

# %%
visualize_model11(model_ft11)

# %%
def train_model12(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model12(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
#             inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft12 = models.densenet201(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs12 = model_ft12.classifier.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft12.fc = nn.Linear(num_ftrs12, 11)

model_ft12 = model_ft12.to(device)

criterion12 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft12 = optim.SGD(model_ft12.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler12 = lr_scheduler.StepLR(optimizer_ft12, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet201_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet201_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
print(model_ft12)
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer25): _DenseLayer(
#         (norm1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer26): _DenseLayer(
#         (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer27): _DenseLayer(
#         (norm1): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1088, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer28): _DenseLayer(
#         (norm1): BatchNorm2d(1120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1120, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer29): _DenseLayer(
#         (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer30): _DenseLayer(
#         (norm1): BatchNorm2d(1184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1184, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer31): _DenseLayer(
#         (norm1): BatchNorm2d(1216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1216, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer32): _DenseLayer(
#         (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer33): _DenseLayer(
#         (norm1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1280, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer34): _DenseLayer(
#         (norm1): BatchNorm2d(1312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1312, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer35): _DenseLayer(
#         (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer36): _DenseLayer(
#         (norm1): BatchNorm2d(1376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1376, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer37): _DenseLayer(
#         (norm1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1408, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer38): _DenseLayer(
#         (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer39): _DenseLayer(
#         (norm1): BatchNorm2d(1472, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1472, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer40): _DenseLayer(
#         (norm1): BatchNorm2d(1504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1504, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer41): _DenseLayer(
#         (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer42): _DenseLayer(
#         (norm1): BatchNorm2d(1568, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1568, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer43): _DenseLayer(
#         (norm1): BatchNorm2d(1600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1600, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer44): _DenseLayer(
#         (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer45): _DenseLayer(
#         (norm1): BatchNorm2d(1664, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1664, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer46): _DenseLayer(
#         (norm1): BatchNorm2d(1696, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1696, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer47): _DenseLayer(
#         (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer48): _DenseLayer(
#         (norm1): BatchNorm2d(1760, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1760, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1792, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1088, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(1120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1120, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(1184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1184, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(1216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1216, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1280, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(1312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1312, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(1376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1376, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1408, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(1472, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1472, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(1504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1504, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(1568, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1568, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(1600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1600, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer25): _DenseLayer(
#         (norm1): BatchNorm2d(1664, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1664, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer26): _DenseLayer(
#         (norm1): BatchNorm2d(1696, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1696, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer27): _DenseLayer(
#         (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer28): _DenseLayer(
#         (norm1): BatchNorm2d(1760, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1760, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer29): _DenseLayer(
#         (norm1): BatchNorm2d(1792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1792, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer30): _DenseLayer(
#         (norm1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1824, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer31): _DenseLayer(
#         (norm1): BatchNorm2d(1856, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1856, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer32): _DenseLayer(
#         (norm1): BatchNorm2d(1888, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1888, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=1920, out_features=1000, bias=True)
#   (fc): Linear(in_features=1920, out_features=11, bias=True)
# )

# %%
model_ft12 = train_model12(model_ft12, criterion12, optimizer_ft12, exp_lr_scheduler12, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.4573 Acc: 0.9007
# val Loss: 1.0544 Acc: 0.7680
#
# Epoch 1/24
# ----------
# train Loss: 0.0489 Acc: 0.9872
# val Loss: 0.7791 Acc: 0.8336
#
# Epoch 2/24
# ----------
# train Loss: 0.0335 Acc: 0.9909
# val Loss: 0.9582 Acc: 0.8052
#
# Epoch 3/24
# ----------
# train Loss: 0.0238 Acc: 0.9928
# val Loss: 0.7434 Acc: 0.8475
#
# Epoch 4/24
# ----------
# train Loss: 0.0201 Acc: 0.9954
# val Loss: 0.8269 Acc: 0.8394
#
# Epoch 5/24
# ----------
# train Loss: 0.0122 Acc: 0.9976
# val Loss: 0.7840 Acc: 0.8453
#
# Epoch 6/24
# ----------
# train Loss: 0.0093 Acc: 0.9976
# val Loss: 0.8104 Acc: 0.8427
#
# Epoch 7/24
# ----------
# train Loss: 0.0075 Acc: 0.9987
# val Loss: 0.8244 Acc: 0.8419
#
# Epoch 8/24
# ----------
# train Loss: 0.0108 Acc: 0.9967
# val Loss: 0.7269 Acc: 0.8654
#
# Epoch 9/24
# ----------
# train Loss: 0.0102 Acc: 0.9972
# val Loss: 0.6857 Acc: 0.8777
#
# Epoch 10/24
# ----------
# train Loss: 0.0064 Acc: 0.9987
# val Loss: 0.7546 Acc: 0.8635
#
# Epoch 11/24
# ----------
# train Loss: 0.0111 Acc: 0.9974
# val Loss: 0.7547 Acc: 0.8600
#
# Epoch 12/24
# ----------
# train Loss: 0.0061 Acc: 0.9991
# val Loss: 0.7302 Acc: 0.8649
#
# Epoch 13/24
# ----------
# train Loss: 0.0060 Acc: 0.9993
# val Loss: 0.7275 Acc: 0.8625
#
# Epoch 14/24
# ----------
# train Loss: 0.0053 Acc: 0.9989
# val Loss: 0.6521 Acc: 0.8772
#
# Epoch 15/24
# ----------
# train Loss: 0.0075 Acc: 0.9980
# val Loss: 0.7613 Acc: 0.8609
#
# Epoch 16/24
# ----------
# train Loss: 0.0076 Acc: 0.9983
# val Loss: 0.7477 Acc: 0.8641
#
# Epoch 17/24
# ----------
# train Loss: 0.0047 Acc: 0.9993
# val Loss: 0.6857 Acc: 0.8748
#
# Epoch 18/24
# ----------
# train Loss: 0.0069 Acc: 0.9987
# val Loss: 0.7259 Acc: 0.8641
#
# Epoch 19/24
# ----------
# train Loss: 0.0069 Acc: 0.9989
# val Loss: 0.7226 Acc: 0.8683
#
# Epoch 20/24
# ----------
# train Loss: 0.0071 Acc: 0.9985
# val Loss: 0.6928 Acc: 0.8716
#
# Epoch 21/24
# ----------
# train Loss: 0.0059 Acc: 0.9991
# val Loss: 0.7233 Acc: 0.8675
#
# Epoch 22/24
# ----------
# train Loss: 0.0081 Acc: 0.9980
# val Loss: 0.6902 Acc: 0.8729
#
# Epoch 23/24
# ----------
# train Loss: 0.0071 Acc: 0.9989
# val Loss: 0.7102 Acc: 0.8681
#
# Epoch 24/24
# ----------
# train Loss: 0.0066 Acc: 0.9985
# val Loss: 0.7634 Acc: 0.8630
#
# Training complete in 24m 8s
# Best val Acc: 0.877709

# %%
def train_model13(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model13(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
#             inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft13 = models.regnet_x_32gf(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrs13 = model_ft13.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft13.fc = nn.Linear(num_ftrs13, 11)

model_ft13 = model_ft13.to(device)

criterion13 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft13 = optim.SGD(model_ft13.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler13 = lr_scheduler.StepLR(optimizer_ft13, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=RegNet_X_32GF_Weights.IMAGENET1K_V1`. You can also use `weights=RegNet_X_32GF_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
print(model_ft13)
# Out:
# RegNet(
#   (stem): SimpleStemIN(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (trunk_output): Sequential(
#     (block1): AnyStage(
#       (block1-0): ResBottleneckBlock(
#         (proj): Conv2dNormActivation(
#           (0): Conv2d(32, 336, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(32, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=2, bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block1-1): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#     )
#     (block2): AnyStage(
#       (block2-0): ResBottleneckBlock(
#         (proj): Conv2dNormActivation(
#           (0): Conv2d(336, 672, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(336, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=4, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block2-1): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block2-2): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block2-3): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block2-4): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block2-5): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block2-6): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#     )
#     (block3): AnyStage(
#       (block3-0): ResBottleneckBlock(
#         (proj): Conv2dNormActivation(
#           (0): Conv2d(672, 1344, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(672, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-1): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-2): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-3): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-4): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-5): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-6): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-7): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-8): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-9): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-10): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-11): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-12): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#     )
#     (block4): AnyStage(
#       (block4-0): ResBottleneckBlock(
#         (proj): Conv2dNormActivation(
#           (0): Conv2d(1344, 2520, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2520, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(1344, 2520, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2520, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(2520, 2520, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=15, bias=False)
#             (1): BatchNorm2d(2520, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(2520, 2520, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2520, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2520, out_features=11, bias=True)
# )

# %%
model_ft13 = train_model13(model_ft13, criterion13, optimizer_ft13, exp_lr_scheduler13, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.5918 Acc: 0.8392
# val Loss: 0.6511 Acc: 0.8044
#
# Epoch 1/24
# ----------
# train Loss: 0.0638 Acc: 0.9850
# val Loss: 0.7747 Acc: 0.7886
#
# Epoch 2/24
# ----------
# train Loss: 0.0344 Acc: 0.9930
# val Loss: 0.7491 Acc: 0.8111
#
# Epoch 3/24
# ----------
# train Loss: 0.0195 Acc: 0.9957
# val Loss: 0.8937 Acc: 0.8108
#
# Epoch 4/24
# ----------
# train Loss: 0.0170 Acc: 0.9967
# val Loss: 0.9077 Acc: 0.8140
#
# Epoch 5/24
# ----------
# train Loss: 0.0137 Acc: 0.9970
# val Loss: 0.7910 Acc: 0.8220
#
# Epoch 6/24
# ----------
# train Loss: 0.0090 Acc: 0.9980
# val Loss: 0.7428 Acc: 0.8314
#
# Epoch 7/24
# ----------
# train Loss: 0.0082 Acc: 0.9980
# val Loss: 0.7210 Acc: 0.8373
#
# Epoch 8/24
# ----------
# train Loss: 0.0082 Acc: 0.9985
# val Loss: 0.7514 Acc: 0.8394
#
# Epoch 9/24
# ----------
# train Loss: 0.0067 Acc: 0.9987
# val Loss: 0.7410 Acc: 0.8424
#
# Epoch 10/24
# ----------
# train Loss: 0.0060 Acc: 0.9989
# val Loss: 0.8106 Acc: 0.8320
#
# Epoch 11/24
# ----------
# train Loss: 0.0050 Acc: 0.9998
# val Loss: 0.7956 Acc: 0.8328
#
# Epoch 12/24
# ----------
# train Loss: 0.0068 Acc: 0.9987
# val Loss: 0.7649 Acc: 0.8416
#
# Epoch 13/24
# ----------
# train Loss: 0.0052 Acc: 0.9993
# val Loss: 0.8298 Acc: 0.8317
#
# Epoch 14/24
# ----------
# train Loss: 0.0070 Acc: 0.9989
# val Loss: 0.8001 Acc: 0.8311
#
# Epoch 15/24
# ----------
# train Loss: 0.0065 Acc: 0.9987
# val Loss: 0.7483 Acc: 0.8413
#
# Epoch 16/24
# ----------
# train Loss: 0.0075 Acc: 0.9987
# val Loss: 0.8960 Acc: 0.8231
#
# Epoch 17/24
# ----------
# train Loss: 0.0067 Acc: 0.9983
# val Loss: 0.7825 Acc: 0.8378
#
# Epoch 18/24
# ----------
# train Loss: 0.0062 Acc: 0.9987
# val Loss: 0.7556 Acc: 0.8386
#
# Epoch 19/24
# ----------
# train Loss: 0.0048 Acc: 0.9996
# val Loss: 0.7504 Acc: 0.8416
#
# Epoch 20/24
# ----------
# train Loss: 0.0064 Acc: 0.9987
# val Loss: 0.7062 Acc: 0.8480
#
# Epoch 21/24
# ----------
# train Loss: 0.0064 Acc: 0.9987
# val Loss: 0.7660 Acc: 0.8365
#
# Epoch 22/24
# ----------
# train Loss: 0.0061 Acc: 0.9991
# val Loss: 0.7471 Acc: 0.8378
#
# Epoch 23/24
# ----------
# train Loss: 0.0064 Acc: 0.9989
# val Loss: 0.7999 Acc: 0.8357
#
# Epoch 24/24
# ----------
# train Loss: 0.0050 Acc: 0.9991
# val Loss: 0.8037 Acc: 0.8381
#
# Training complete in 50m 43s
# Best val Acc: 0.848006

# %%
visualize_model11(model_ft13)

# %%
def train_model14(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model14(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft14 = models.resnet152(pretrained=True)
num_ftrs14 = model_ft14.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft14.fc = nn.Linear(num_ftrs, 11)

model_ft14 = model_ft14.to(device)

criterion14 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft14 = optim.SGD(model_ft14.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_scheduler14 = lr_scheduler.StepLR(optimizer_ft14, step_size=5, gamma=0.1)

# %%
model_ft14 = train_model14(model_ft14, criterion14, optimizer_ft14, exp_lr_scheduler14, num_epochs=25)

# %%
visualize_model14(model_ft14)

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
def train_modelMaxViT(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, topK0preds = torch.topk(outputs, k[0], 1)
                    _, topK1preds = torch.topk(outputs, k[1], 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftMaxViT = models.maxvit_t(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrsMaxViT = model_ftMaxViT.classifier[3].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsMaxViT, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
# model_ftMaxViT.fc = nn.Linear(num_ftrsMaxViT, 11)
model_ftMaxViT.fc = classifier_block

model_ftMaxViT = model_ftMaxViT.to(device)

criterionMaxViT = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftMaxViT = optim.SGD(model_ftMaxViT.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerMaxViT = lr_scheduler.StepLR(optimizer_ftMaxViT, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MaxVit_T_Weights.IMAGENET1K_V1`. You can also use `weights=MaxVit_T_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
print(device)
# Out:
# cuda:1

# %%
model_ftMaxViT = train_modelMaxViT(model_ftMaxViT, criterionMaxViT, optimizer_ftMaxViT, exp_lr_schedulerMaxViT, num_epochs=50)
# Out:
# Epoch 1/49
# ----------
# train Loss: 0.9852, top-2 Acc 0.8371, top-3 Acc 0.8768, Acc: 0.7539
# val Loss: 1.2135, top-2 Acc 0.7985, top-3 Acc 0.8568, Acc: 0.6693
# Time taken for epoch: 1m 5s
# Estimated Time Remaining: 52m 48s
# Epoch 2/49
# ----------
# train Loss: 0.1141, top-2 Acc 0.9902, top-3 Acc 0.9950, Acc: 0.9702
# val Loss: 0.8712, top-2 Acc 0.8956, top-3 Acc 0.9524, Acc: 0.7653
# Time taken for epoch: 1m 4s
# Estimated Time Remaining: 51m 19s
# Epoch 3/49
# ----------
# train Loss: 0.0645, top-2 Acc 0.9939, top-3 Acc 0.9976, Acc: 0.9833
# val Loss: 0.6471, top-2 Acc 0.9144, top-3 Acc 0.9516, Acc: 0.8130
# Time taken for epoch: 1m 3s
# Estimated Time Remaining: 49m 10s
# Epoch 4/49
# ----------
# train Loss: 0.0519, top-2 Acc 0.9965, top-3 Acc 0.9978, Acc: 0.9857
# val Loss: 0.8977, top-2 Acc 0.8384, top-3 Acc 0.9021, Acc: 0.7691
# Time taken for epoch: 1m 4s
# Estimated Time Remaining: 48m 52s
# Epoch 5/49
# ----------
# train Loss: 0.0327, top-2 Acc 0.9976, top-3 Acc 0.9993, Acc: 0.9917
# val Loss: 1.0668, top-2 Acc 0.8135, top-3 Acc 0.8595, Acc: 0.7501
# Time taken for epoch: 1m 3s
# Estimated Time Remaining: 46m 54s
# Epoch 6/49
# ----------
# train Loss: 0.0273, top-2 Acc 0.9983, top-3 Acc 0.9989, Acc: 0.9922
# val Loss: 0.8425, top-2 Acc 0.8742, top-3 Acc 0.9221, Acc: 0.7980
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 51m 34s
# Epoch 7/49
# ----------
# train Loss: 0.0234, top-2 Acc 0.9989, top-3 Acc 0.9993, Acc: 0.9944
# val Loss: 0.9142, top-2 Acc 0.8402, top-3 Acc 0.8807, Acc: 0.7771
# Time taken for epoch: 1m 6s
# Estimated Time Remaining: 47m 15s
# Epoch 8/49
# ----------
# train Loss: 0.0207, top-2 Acc 0.9989, top-3 Acc 1.0000, Acc: 0.9946
# val Loss: 0.7908, top-2 Acc 0.8812, top-3 Acc 0.9371, Acc: 0.8006
# Time taken for epoch: 1m 3s
# Estimated Time Remaining: 43m 57s
# Epoch 9/49
# ----------
# train Loss: 0.0189, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9954
# val Loss: 1.1742, top-2 Acc 0.8368, top-3 Acc 0.8983, Acc: 0.7851
# Time taken for epoch: 1m 3s
# Estimated Time Remaining: 43m 9s
# Epoch 10/49
# ----------
# train Loss: 0.0137, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9985
# val Loss: 0.7759, top-2 Acc 0.8675, top-3 Acc 0.9189, Acc: 0.8183
# Time taken for epoch: 1m 6s
# Estimated Time Remaining: 43m 47s
# Epoch 11/49
# ----------
# train Loss: 0.0170, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9961
# val Loss: 0.9589, top-2 Acc 0.8812, top-3 Acc 0.9253, Acc: 0.8084
# Time taken for epoch: 1m 4s
# Estimated Time Remaining: 41m 32s
# Epoch 12/49
# ----------
# train Loss: 0.0171, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9967
# val Loss: 0.9867, top-2 Acc 0.8582, top-3 Acc 0.8994, Acc: 0.7843
# Time taken for epoch: 1m 3s
# Estimated Time Remaining: 39m 58s
# Epoch 13/49
# ----------
# train Loss: 0.0156, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9963
# val Loss: 1.0202, top-2 Acc 0.8453, top-3 Acc 0.9029, Acc: 0.7931
# Time taken for epoch: 1m 4s
# Estimated Time Remaining: 39m 27s
# Epoch 14/49
# ----------
# train Loss: 0.0154, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9972
# val Loss: 0.8219, top-2 Acc 0.8881, top-3 Acc 0.9240, Acc: 0.8274
# Time taken for epoch: 1m 5s
# Estimated Time Remaining: 38m 51s
# Epoch 15/49
# ----------
# train Loss: 0.0174, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9948
# val Loss: 0.6990, top-2 Acc 0.8972, top-3 Acc 0.9377, Acc: 0.8437
# Time taken for epoch: 1m 18s
# Estimated Time Remaining: 45m 43s
# Epoch 16/49
# ----------
# train Loss: 0.0143, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9976
# val Loss: 0.7516, top-2 Acc 0.8978, top-3 Acc 0.9583, Acc: 0.8191
# Time taken for epoch: 1m 27s
# Estimated Time Remaining: 49m 11s
# Epoch 17/49
# ----------
# train Loss: 0.0171, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9939
# val Loss: 0.9348, top-2 Acc 0.8467, top-3 Acc 0.9005, Acc: 0.7988
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 51m 38s
# Epoch 18/49
# ----------
# train Loss: 0.0167, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9959
# val Loss: 0.7772, top-2 Acc 0.8911, top-3 Acc 0.9403, Acc: 0.8237
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 52m 20s
# Epoch 19/49
# ----------
# train Loss: 0.0181, top-2 Acc 0.9991, top-3 Acc 1.0000, Acc: 0.9941
# val Loss: 0.8215, top-2 Acc 0.8665, top-3 Acc 0.9162, Acc: 0.8212
# Time taken for epoch: 1m 42s
# Estimated Time Remaining: 52m 35s
# Epoch 20/49
# ----------
# train Loss: 0.0145, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9965
# val Loss: 0.8205, top-2 Acc 0.8772, top-3 Acc 0.9283, Acc: 0.8132
# Time taken for epoch: 1m 42s
# Estimated Time Remaining: 50m 47s
# Epoch 21/49
# ----------
# train Loss: 0.0112, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9980
# val Loss: 0.8358, top-2 Acc 0.8662, top-3 Acc 0.9192, Acc: 0.7993
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 47m 33s
# Epoch 22/49
# ----------
# train Loss: 0.0153, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9959
# val Loss: 1.1635, top-2 Acc 0.8357, top-3 Acc 0.8702, Acc: 0.7626
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 43m 43s
# Epoch 23/49
# ----------
# train Loss: 0.0166, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9954
# val Loss: 1.3242, top-2 Acc 0.8311, top-3 Acc 0.8946, Acc: 0.7493
# Time taken for epoch: 1m 33s
# Estimated Time Remaining: 41m 52s
# Epoch 24/49
# ----------
# train Loss: 0.0190, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9954
# val Loss: 0.6910, top-2 Acc 0.8943, top-3 Acc 0.9454, Acc: 0.8328
# Time taken for epoch: 1m 27s
# Estimated Time Remaining: 37m 51s
# Epoch 25/49
# ----------
# train Loss: 0.0170, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9959
# val Loss: 0.7249, top-2 Acc 0.8986, top-3 Acc 0.9558, Acc: 0.8333
# Time taken for epoch: 1m 35s
# Estimated Time Remaining: 39m 44s
# Epoch 26/49
# ----------
# train Loss: 0.0147, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9965
# val Loss: 0.7454, top-2 Acc 0.8911, top-3 Acc 0.9312, Acc: 0.8421
# Time taken for epoch: 1m 43s
# Estimated Time Remaining: 41m 20s
# Epoch 27/49
# ----------
# train Loss: 0.0193, top-2 Acc 0.9980, top-3 Acc 0.9993, Acc: 0.9950
# val Loss: 0.8453, top-2 Acc 0.8659, top-3 Acc 0.9307, Acc: 0.8073
# Time taken for epoch: 1m 43s
# Estimated Time Remaining: 39m 29s
# Epoch 28/49
# ----------
# train Loss: 0.0191, top-2 Acc 0.9987, top-3 Acc 0.9996, Acc: 0.9954
# val Loss: 0.8899, top-2 Acc 0.8619, top-3 Acc 0.9323, Acc: 0.8154
# Time taken for epoch: 1m 44s
# Estimated Time Remaining: 38m 16s
# Epoch 29/49
# ----------
# train Loss: 0.0210, top-2 Acc 0.9983, top-3 Acc 0.9993, Acc: 0.9941
# val Loss: 0.7209, top-2 Acc 0.8825, top-3 Acc 0.9342, Acc: 0.8357
# Time taken for epoch: 1m 44s
# Estimated Time Remaining: 36m 29s
# Epoch 30/49
# ----------
# train Loss: 0.0152, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.
top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9974
# val Loss: 1.0073, top-2 Acc 0.8413, top-3 Acc 0.8970, Acc: 0.7913
# Time taken for epoch: 1m 44s
# Estimated Time Remaining: 13m 51s
# Epoch 43/49
# ----------
# train Loss: 0.0169, top-2 Acc 0.9985, top-3 Acc 0.9998, Acc: 0.9954
# val Loss: 0.6629, top-2 Acc 0.8919, top-3 Acc 0.9355, Acc: 0.8293
# Time taken for epoch: 1m 42s
# Estimated Time Remaining: 11m 54s
# Epoch 44/49
# ----------
# train Loss: 0.0143, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9961
# val Loss: 1.1572, top-2 Acc 0.8250, top-3 Acc 0.8863, Acc: 0.7862
# Time taken for epoch: 1m 22s
# Estimated Time Remaining: 8m 13s
# Epoch 45/49
# ----------
# train Loss: 0.0159, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9954
# val Loss: 0.9474, top-2 Acc 0.8614, top-3 Acc 0.9344, Acc: 0.7969
# Time taken for epoch: 1m 30s
# Estimated Time Remaining: 7m 29s
# Epoch 46/49
# ----------
# train Loss: 0.0158, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9965
# val Loss: 0.7522, top-2 Acc 0.8820, top-3 Acc 0.9187, Acc: 0.8175
# Time taken for epoch: 1m 41s
# Estimated Time Remaining: 6m 44s
# Epoch 47/49
# ----------
# train Loss: 0.0177, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9948
# val Loss: 1.1738, top-2 Acc 0.8381, top-3 Acc 0.8919, Acc: 0.7736
# Time taken for epoch: 1m 43s
# Estimated Time Remaining: 5m 9s
# Epoch 48/49
# ----------
# train Loss: 0.0205, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9944
# val Loss: 0.9950, top-2 Acc 0.8828, top-3 Acc 0.9331, Acc: 0.8028
# Time taken for epoch: 1m 43s
# Estimated Time Remaining: 3m 26s
# Epoch 49/49
# ----------
# train Loss: 0.0150, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9959
# val Loss: 0.9533, top-2 Acc 0.8600, top-3 Acc 0.9045, Acc: 0.7889
# Time taken for epoch: 1m 42s
# Estimated Time Remaining: 1m 42s
# Epoch 50/49
# ----------
# train Loss: 0.0181, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9959
# val Loss: 0.8369, top-2 Acc 0.8844, top-3 Acc 0.9272, Acc: 0.8130
# Time taken for epoch: 1m 43s
# Estimated Time Remaining: 0m 0s
# Training complete in 74m 28s
# Best val Acc: 0.843725, Best top-2 val Acc: 0.897244, Best overall top-2 Acc: 1.000000, Best top-3 val Acc: 0.937651, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftMaxViT.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_MaxViT_1.pt')

# %%
model_ftMaxViT = train_modelMaxViT(model_ftMaxViT, criterionMaxViT, optimizer_ftMaxViT, exp_lr_schedulerMaxViT, num_epochs=50)
# Out:
# Epoch 1/49
# ----------
# train Loss: 1.0104, top-2 Acc 0.8340, top-3 Acc 0.8773, Acc: 0.7439
# val Loss: 1.2305, top-2 Acc 0.7552, top-3 Acc 0.8491, Acc: 0.6216
# Time taken for epoch: 0m 56s
# Estimated Time Remaining: 45m 51s
# Epoch 2/49
# ----------
# train Loss: 0.1464, top-2 Acc 0.9874, top-3 Acc 0.9939, Acc: 0.9611
# val Loss: 0.9948, top-2 Acc 0.8360, top-3 Acc 0.9082, Acc: 0.7367
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 7m 50s
# Epoch 43/49
# ----------
# train Loss: 0.0246, top-2 Acc 0.9983, top-3 Acc 0.9991, Acc: 0.9922
# val Loss: 0.8390, top-2 Acc 0.8935, top-3 Acc 0.9237, Acc: 0.8220
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 6m 51s
# Epoch 44/49
# ----------
# train Loss: 0.0226, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9937
# val Loss: 0.6391, top-2 Acc 0.9096, top-3 Acc 0.9454, Acc: 0.8384
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 5m 51s
# Epoch 45/49
# ----------
# train Loss: 0.0220, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9935
# val Loss: 0.8731, top-2 Acc 0.8721, top-3 Acc 0.9296, Acc: 0.8031
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 4m 52s
# Epoch 46/49
# ----------
# train Loss: 0.0226, top-2 Acc 0.9985, top-3 Acc 0.9998, Acc: 0.9939
# val Loss: 0.5897, top-2 Acc 0.9286, top-3 Acc 0.9644, Acc: 0.8378
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 3m 54s
# Epoch 47/49
# ----------
# train Loss: 0.0239, top-2 Acc 0.9985, top-3 Acc 0.9996, Acc: 0.9935
# val Loss: 0.8774, top-2 Acc 0.8748, top-3 Acc 0.9184, Acc: 0.7956
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 2m 56s
# Epoch 48/49
# ----------
# train Loss: 0.0242, top-2 Acc 0.9989, top-3 Acc 0.9989, Acc: 0.9944
# val Loss: 0.7650, top-2 Acc 0.8828, top-3 Acc 0.9211, Acc: 0.8226
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 1m 57s
# Epoch 49/49
# ----------
# train Loss: 0.0197, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9954
# val Loss: 0.7434, top-2 Acc 0.8967, top-3 Acc 0.9366, Acc: 0.8116
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 0m 59s
# Epoch 50/49
# ----------
# train Loss: 0.0262, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9930
# val Loss: 0.7943, top-2 Acc 0.8729, top-3 Acc 0.9079, Acc: 0.8097
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 0m 0s
# Training complete in 48m 35s
# Best val Acc: 0.850147, Best top-2 val Acc: 0.911961, Best overall top-2 Acc: 0.999783, Best top-3 val Acc: 0.944608, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftMaxViT.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_MaxViT_1_Aug_CB.pt')

# %%
model = models.maxvit_t(pretrained=True)
loaded_model = torch.load('/home/dlpc01/Rifat/saved_models/HSPR_MaxViT_1.pt')
# print(loaded_model.keys())
model.load_state_dict(loaded_model, strict=False)
model.eval().to(device)
# Out:
# MaxVit(
#   (stem): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#       (2): GELU(approximate='none')
#     )
#     (1): Conv2dNormActivation(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (blocks): ModuleList(
#     (0): MaxVitBlock(
#       (layers): ModuleList(
#         (0): MaxVitLayer(
#           (layers): Sequential(
#             (MBconv): MBConv(
#               (proj): Sequential(
#                 (0): AvgPool2d(kernel_size=3, stride=2, padding=1)
#                 (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (stochastic_depth): Identity()
#               (layers): Sequential(
#                 (pre_norm): BatchNorm2d(64, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                 (conv_a): Conv2dNormActivation(
#                   (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(256, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (conv_b): Conv2dNormActivation(
#                   (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#                   (1): BatchNorm2d(256, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (squeeze_excitation): SqueezeExcitation(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#                   (activation): SiLU()
#                   (scale_activation): Sigmoid()
#                 )
#                 (conv_c): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (window_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): Identity()
#               (departition_swap): Identity()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=64, out_features=192, bias=True)
#                   (merge): Linear(in_features=64, out_features=64, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=64, out_features=256, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=256, out_features=64, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.0, mode=row)
#             )
#             (grid_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): SwapAxes()
#               (departition_swap): SwapAxes()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=64, out_features=192, bias=True)
#                   (merge): Linear(in_features=64, out_features=64, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=64, out_features=256, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=256, out_features=64, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.0, mode=row)
#             )
#           )
#         )
#         (1): MaxVitLayer(
#           (layers): Sequential(
#             (MBconv): MBConv(
#               (proj): Identity()
#               (stochastic_depth): StochasticDepth(p=0.02, mode=row)
#               (layers): Sequential(
#                 (pre_norm): BatchNorm2d(64, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                 (conv_a): Conv2dNormActivation(
#                   (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(256, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (conv_b): Conv2dNormActivation(
#                   (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                   (1): BatchNorm2d(256, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (squeeze_excitation): SqueezeExcitation(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#                   (activation): SiLU()
#                   (scale_activation): Sigmoid()
#                 )
#                 (conv_c): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (window_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): Identity()
#               (departition_swap): Identity()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=64, out_features=192, bias=True)
#                   (merge): Linear(in_features=64, out_features=64, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=64, out_features=256, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=256, out_features=64, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.02, mode=row)
#             )
#             (grid_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): SwapAxes()
#               (departition_swap): SwapAxes()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=64, out_features=192, bias=True)
#                   (merge): Linear(in_features=64, out_features=64, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=64, out_features=256, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=256, out_features=64, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.02, mode=row)
#             )
#           )
#         )
#       )
#     )
#     (1): MaxVitBlock(
#       (layers): ModuleList(
#         (0): MaxVitLayer(
#           (layers): Sequential(
#             (MBconv): MBConv(
#               (proj): Sequential(
#                 (0): AvgPool2d(kernel_size=3, stride=2, padding=1)
#                 (1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (stochastic_depth): StochasticDepth(p=0.04, mode=row)
#               (layers): Sequential(
#                 (pre_norm): BatchNorm2d(64, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                 (conv_a): Conv2dNormActivation(
#                   (0): Conv2d(64, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(512, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (conv_b): Conv2dNormActivation(
#                   (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512, bias=False)
#                   (1): BatchNorm2d(512, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (squeeze_excitation): SqueezeExcitation(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#                   (activation): SiLU()
#                   (scale_activation): Sigmoid()
#                 )
#                 (conv_c): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (window_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): Identity()
#               (departition_swap): Identity()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=128, out_features=384, bias=True)
#                   (merge): Linear(in_features=128, out_features=128, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=128, out_features=512, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=512, out_features=128, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.04, mode=row)
#             )
#             (grid_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): SwapAxes()
#               (departition_swap): SwapAxes()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=128, out_features=384, bias=True)
#                   (merge): Linear(in_features=128, out_features=128, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=128, out_features=512, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=512, out_features=128, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.04, mode=row)
#             )
#           )
#         )
#         (1): MaxVitLayer(
#           (layers): Sequential(
#             (MBconv): MBConv(
#               (proj): Identity()
#               (stochastic_depth): StochasticDepth(p=0.06, mode=row)
#               (layers): Sequential(
#                 (pre_norm): BatchNorm2d(128, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                 (conv_a): Conv2dNormActivation(
#                   (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(512, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (conv_b): Conv2dNormActivation(
#                   (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#                   (1): BatchNorm2d(512, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (squeeze_excitation): SqueezeExcitation(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#                   (activation): SiLU()
#                   (scale_activation): Sigmoid()
#                 )
#                 (conv_c): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (window_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): Identity()
#               (departition_swap): Identity()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=128, out_features=384, bias=True)
#                   (merge): Linear(in_features=128, out_features=128, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=128, out_features=512, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=512, out_features=128, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.06, mode=row)
#             )
#             (grid_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): SwapAxes()
#               (departition_swap): SwapAxes()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=128, out_features=384, bias=True)
#                   (merge): Linear(in_features=128, out_features=128, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=128, out_features=512, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=512, out_features=128, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.06, mode=row)
#             )
#           )
#         )
#       )
#     )
#     (2): MaxVitBlock(
#       (layers): ModuleList(
#         (0): MaxVitLayer(
#           (layers): Sequential(
#             (MBconv): MBConv(
#               (proj): Sequential(
#                 (0): AvgPool2d(kernel_size=3, stride=2, padding=1)
#                 (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (stochastic_depth): StochasticDepth(p=0.08, mode=row)
#               (layers): Sequential(
#                 (pre_norm): BatchNorm2d(128, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                 (conv_a): Conv2dNormActivation(
#                   (0): Conv2d(128, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1024, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (conv_b): Conv2dNormActivation(
#                   (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=1024, bias=False)
#                   (1): BatchNorm2d(1024, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (squeeze_excitation): SqueezeExcitation(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#                   (activation): SiLU()
#                   (scale_activation): Sigmoid()
#                 )
#                 (conv_c): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (window_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): Identity()
#               (departition_swap): Identity()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=256, out_features=768, bias=True)
#                   (merge): Linear(in_features=256, out_features=256, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=256, out_features=1024, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=1024, out_features=256, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.08, mode=row)
#             )
#             (grid_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): SwapAxes()
#               (departition_swap): SwapAxes()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=256, out_features=768, bias=True)
#                   (merge): Linear(in_features=256, out_features=256, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=256, out_features=1024, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=1024, out_features=256, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.08, mode=row)
#             )
#           )
#         )
#         (1): MaxVitLayer(
#           (layers): Sequential(
#             (MBconv): MBConv(
#               (proj): Identity()
#               (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#               (layers): Sequential(
#                 (pre_norm): BatchNorm2d(256, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                 (conv_a): Conv2dNormActivation(
#                   (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1024, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (conv_b): Conv2dNormActivation(
#                   (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#                   (1): BatchNorm2d(1024, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (squeeze_excitation): SqueezeExcitation(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#                   (activation): SiLU()
#                   (scale_activation): Sigmoid()
#                 )
#                 (conv_c): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (window_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): Identity()
#               (departition_swap): Identity()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=256, out_features=768, bias=True)
#                   (merge): Linear(in_features=256, out_features=256, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=256, out_features=1024, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=1024, out_features=256, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.1, mode=row)
#             )
#             (grid_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): SwapAxes()
#               (departition_swap): SwapAxes()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=256, out_features=768, bias=True)
#                   (merge): Linear(in_features=256, out_features=256, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=256, out_features=1024, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=1024, out_features=256, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.1, mode=row)
#             )
#           )
#         )
#         (2): MaxVitLayer(
#           (layers): Sequential(
#             (MBconv): MBConv(
#               (proj): Identity()
#               (stochastic_depth): StochasticDepth(p=0.12, mode=row)
#               (layers): Sequential(
#                 (pre_norm): BatchNorm2d(256, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                 (conv_a): Conv2dNormActivation(
#                   (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1024, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (conv_b): Conv2dNormActivation(
#                   (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#                   (1): BatchNorm2d(1024, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (squeeze_excitation): SqueezeExcitation(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#                   (activation): SiLU()
#                   (scale_activation): Sigmoid()
#                 )
#                 (conv_c): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (window_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): Identity()
#               (departition_swap): Identity()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=256, out_features=768, bias=True)
#                   (merge): Linear(in_features=256, out_features=256, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=256, out_features=1024, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=1024, out_features=256, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.12, mode=row)
#             )
#             (grid_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): SwapAxes()
#               (departition_swap): SwapAxes()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=256, out_features=768, bias=True)
#                   (merge): Linear(in_features=256, out_features=256, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=256, out_features=1024, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=1024, out_features=256, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.12, mode=row)
#             )
#           )
#         )
#         (3): MaxVitLayer(
#           (layers): Sequential(
#             (MBconv): MBConv(
#               (proj): Identity()
#               (stochastic_depth): StochasticDepth(p=0.14, mode=row)
#               (layers): Sequential(
#                 (pre_norm): BatchNorm2d(256, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                 (conv_a): Conv2dNormActivation(
#                   (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1024, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (conv_b): Conv2dNormActivation(
#                   (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#                   (1): BatchNorm2d(1024, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (squeeze_excitation): SqueezeExcitation(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#                   (activation): SiLU()
#                   (scale_activation): Sigmoid()
#                 )
#                 (conv_c): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (window_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): Identity()
#               (departition_swap): Identity()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=256, out_features=768, bias=True)
#                   (merge): Linear(in_features=256, out_features=256, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=256, out_features=1024, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=1024, out_features=256, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.14, mode=row)
#             )
#             (grid_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): SwapAxes()
#               (departition_swap): SwapAxes()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=256, out_features=768, bias=True)
#                   (merge): Linear(in_features=256, out_features=256, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=256, out_features=1024, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=1024, out_features=256, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.14, mode=row)
#             )
#           )
#         )
#         (4): MaxVitLayer(
#           (layers): Sequential(
#             (MBconv): MBConv(
#               (proj): Identity()
#               (stochastic_depth): StochasticDepth(p=0.16, mode=row)
#               (layers): Sequential(
#                 (pre_norm): BatchNorm2d(256, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                 (conv_a): Conv2dNormActivation(
#                   (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1024, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (conv_b): Conv2dNormActivation(
#                   (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#                   (1): BatchNorm2d(1024, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (squeeze_excitation): SqueezeExcitation(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#                   (activation): SiLU()
#                   (scale_activation): Sigmoid()
#                 )
#                 (conv_c): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (window_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): Identity()
#               (departition_swap): Identity()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=256, out_features=768, bias=True)
#                   (merge): Linear(in_features=256, out_features=256, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=256, out_features=1024, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=1024, out_features=256, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.16, mode=row)
#             )
#             (grid_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): SwapAxes()
#               (departition_swap): SwapAxes()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=256, out_features=768, bias=True)
#                   (merge): Linear(in_features=256, out_features=256, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=256, out_features=1024, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=1024, out_features=256, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.16, mode=row)
#             )
#           )
#         )
#       )
#     )
#     (3): MaxVitBlock(
#       (layers): ModuleList(
#         (0): MaxVitLayer(
#           (layers): Sequential(
#             (MBconv): MBConv(
#               (proj): Sequential(
#                 (0): AvgPool2d(kernel_size=3, stride=2, padding=1)
#                 (1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (stochastic_depth): StochasticDepth(p=0.18, mode=row)
#               (layers): Sequential(
#                 (pre_norm): BatchNorm2d(256, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                 (conv_a): Conv2dNormActivation(
#                   (0): Conv2d(256, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(2048, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (conv_b): Conv2dNormActivation(
#                   (0): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=2048, bias=False)
#                   (1): BatchNorm2d(2048, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (squeeze_excitation): SqueezeExcitation(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#                   (activation): SiLU()
#                   (scale_activation): Sigmoid()
#                 )
#                 (conv_c): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (window_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): Identity()
#               (departition_swap): Identity()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=512, out_features=1536, bias=True)
#                   (merge): Linear(in_features=512, out_features=512, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=512, out_features=2048, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=2048, out_features=512, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.18, mode=row)
#             )
#             (grid_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): SwapAxes()
#               (departition_swap): SwapAxes()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=512, out_features=1536, bias=True)
#                   (merge): Linear(in_features=512, out_features=512, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=512, out_features=2048, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=2048, out_features=512, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.18, mode=row)
#             )
#           )
#         )
#         (1): MaxVitLayer(
#           (layers): Sequential(
#             (MBconv): MBConv(
#               (proj): Identity()
#               (stochastic_depth): StochasticDepth(p=0.2, mode=row)
#               (layers): Sequential(
#                 (pre_norm): BatchNorm2d(512, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                 (conv_a): Conv2dNormActivation(
#                   (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(2048, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (conv_b): Conv2dNormActivation(
#                   (0): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048, bias=False)
#                   (1): BatchNorm2d(2048, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#                   (2): GELU(approximate='none')
#                 )
#                 (squeeze_excitation): SqueezeExcitation(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#                   (activation): SiLU()
#                   (scale_activation): Sigmoid()
#                 )
#                 (conv_c): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (window_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): Identity()
#               (departition_swap): Identity()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=512, out_features=1536, bias=True)
#                   (merge): Linear(in_features=512, out_features=512, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=512, out_features=2048, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=2048, out_features=512, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.2, mode=row)
#             )
#             (grid_attention): PartitionAttentionLayer(
#               (partition_op): WindowPartition()
#               (departition_op): WindowDepartition()
#               (partition_swap): SwapAxes()
#               (departition_swap): SwapAxes()
#               (attn_layer): Sequential(
#                 (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (1): RelativePositionalMultiHeadAttention(
#                   (to_qkv): Linear(in_features=512, out_features=1536, bias=True)
#                   (merge): Linear(in_features=512, out_features=512, bias=True)
#                 )
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (mlp_layer): Sequential(
#                 (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (1): Linear(in_features=512, out_features=2048, bias=True)
#                 (2): GELU(approximate='none')
#                 (3): Linear(in_features=2048, out_features=512, bias=True)
#                 (4): Dropout(p=0.0, inplace=False)
#               )
#               (stochastic_dropout): StochasticDepth(p=0.2, mode=row)
#             )
#           )
#         )
#       )
#     )
#   )
#   (classifier): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): Tanh()
#     (5): Linear(in_features=512, out_features=1000, bias=False)
#   )
# )

# %%
# import cv2
# test_image = cv2.imread('/home/dlpc01/Rifat/CSE 4836 Pattern Recognition Lab/data2/val/dogFrames/dog_369.PNG')
# imshow(torch.tensor(test_image))
def visualize_modelMaxViT(model, num_images=6):
    was_training = model.training
    model.eval().to(device)
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('ground truth: {}, predicted: {}'.format(class_names[labels[j]], class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_modelMaxViT(model)

# %%
def train_modelDenseNet201(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, topK0preds = torch.topk(outputs, k[0], 1)
                    _, topK1preds = torch.topk(outputs, k[1], 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftDenseNet201 = models.densenet201(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrsDenseNet201 = model_ftDenseNet201.classifier.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsDenseNet201, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
# model_ftDenseNet201.fc = nn.Linear(num_ftrsDenseNet201, 11)

model_ftDenseNet201 = model_ftDenseNet201.to(device)

criterionDenseNet201 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftDenseNet201 = optim.SGD(model_ftDenseNet201.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerDenseNet201 = lr_scheduler.StepLR(optimizer_ftDenseNet201, step_size=5, gamma=0.1)

# %%
model_ftDenseNet201 = train_modelDenseNet201(model_ftDenseNet201, criterionDenseNet201, optimizer_ftDenseNet201, exp_lr_schedulerDenseNet201, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.4715, top-2 Acc 0.9374, top-3 Acc 0.9531, Acc: 0.8985
# val Loss: 1.0605, top-2 Acc 0.8678, top-3 Acc 0.9066, Acc: 0.7816
# Time taken for epoch: 1m 40s
# Estimated Time Remaining: 81m 60s
# Epoch 2/50
# ----------
# train Loss: 0.0643, top-2 Acc 0.9941, top-3 Acc 0.9967, Acc: 0.9807
# val Loss: 0.6779, top-2 Acc 0.9010, top-3 Acc 0.9221, Acc: 0.8579
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 76m 44s
# Epoch 3/50
# ----------
# train Loss: 0.0322, top-2 Acc 0.9980, top-3 Acc 0.9991, Acc: 0.9915
# val Loss: 1.0007, top-2 Acc 0.8962, top-3 Acc 0.9208, Acc: 0.7988
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 75m 20s
# Epoch 4/50
# ----------
# train Loss: 0.0217, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9939
# val Loss: 0.8096, top-2 Acc 0.9023, top-3 Acc 0.9205, Acc: 0.8480
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 75m 40s
# Epoch 5/50
# ----------
# train Loss: 0.0172, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9961
# val Loss: 0.8985, top-2 Acc 0.8879, top-3 Acc 0.9176, Acc: 0.8287
# Time taken for epoch: 1m 43s
# Estimated Time Remaining: 77m 18s
# Epoch 6/50
# ----------
# train Loss: 0.0150, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9963
# val Loss: 0.8201, top-2 Acc 0.8997, top-3 Acc 0.9227, Acc: 0.8397
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 71m 40s
# Epoch 7/50
# ----------
# train Loss: 0.0102, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9974
# val Loss: 0.8278, top-2 Acc 0.8978, top-3 Acc 0.9232, Acc: 0.8389
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 68m 47s
# Epoch 8/50
# ----------
# train Loss: 0.0107, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9974
# val Loss: 0.8095, top-2 Acc 0.9018, top-3 Acc 0.9277, Acc: 0.8467
# Time taken for epoch: 1m 35s
# Estimated Time Remaining: 66m 24s
# Epoch 9/50
# ----------
# train Loss: 0.0075, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9989
# val Loss: 0.7789, top-2 Acc 0.9138, top-3 Acc 0.9326, Acc: 0.8518
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 66m 12s
# Epoch 10/50
# ----------
# train Loss: 0.0075, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9983
# val Loss: 0.9054, top-2 Acc 0.8916, top-3 Acc 0.9170, Acc: 0.8384
# Time taken for epoch: 1m 35s
# Estimated Time Remaining: 63m 40s
# Epoch 11/50
# ----------
# train Loss: 0.0097, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9985
# val Loss: 0.8396, top-2 Acc 0.9002, top-3 Acc 0.9205, Acc: 0.8451
# Time taken for epoch: 1m 35s
# Estimated Time Remaining: 61m 31s
# Epoch 12/50
# ----------
# train Loss: 0.0101, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9976
# val Loss: 0.8509, top-2 Acc 0.9015, top-3 Acc 0.9269, Acc: 0.8424
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 61m 54s
# Epoch 13/50
# ----------
# train Loss: 0.0103, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9970
# val Loss: 0.9125, top-2 Acc 0.8892, top-3 Acc 0.9178, Acc: 0.8376
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 59m 30s
# Epoch 14/50
# ----------
# train Loss: 0.0101, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9974
# val Loss: 0.8275, top-2 Acc 0.9026, top-3 Acc 0.9256, Acc: 0.8483
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 57m 42s
# Epoch 15/50
# ----------
# train Loss: 0.0081, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9980
# val Loss: 0.8761, top-2 Acc 0.9005, top-3 Acc 0.9208, Acc: 0.8451
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 56m 39s
# Epoch 16/50
# ----------
# train Loss: 0.0065, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9989
# val Loss: 0.8967, top-2 Acc 0.8932, top-3 Acc 0.9216, Acc: 0.8368
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 54m 25s
# Epoch 17/50
# ----------
# train Loss: 0.0079, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9970
# val Loss: 0.8594, top-2 Acc 0.8954, top-3 Acc 0.9141, Acc: 0.8443
# Time taken for epoch: 1m 35s
# Estimated Time Remaining: 52m 6s
# Epoch 18/50
# ----------
# train Loss: 0.0151, top-2 Acc 0.9989, top-3 Acc 0.9991, Acc: 0.9967
# val Loss: 0.7965, top-2 Acc 0.9088, top-3 Acc 0.9326, Acc: 0.8491
# Time taken for epoch: 1m 27s
# Estimated Time Remaining: 46m 8s
# Epoch 19/50
# ----------
# train Loss: 0.0100, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9972
# val Loss: 0.7858, top-2 Acc 0.9098, top-3 Acc 0.9310, Acc: 0.8488
# Time taken for epoch: 1m 18s
# Estimated Time Remaining: 40m 4s
# Epoch 20/50
# ----------
# train Loss: 0.0064, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9987
# val Loss: 0.8816, top-2 Acc 0.9010, top-3 Acc 0.9267, Acc: 0.8400
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 46m 51s
# Epoch 21/50
# ----------
# train Loss: 0.0071, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9978
# val Loss: 0.8254, top-2 Acc 0.9058, top-3 Acc 0.9331, Acc: 0.8435
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 46m 32s
# Epoch 22/50
# ----------
# train Loss: 0.0079, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9980
# val Loss: 0.8322, top-2 Acc 0.9058, top-3 Acc 0.9256, Acc: 0.8405
# Time taken for epoch: 1m 35s
# Estimated Time Remaining: 44m 26s
# Epoch 23/50
# ----------
# train Loss: 0.0086, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9978
# val Loss: 0.8226, top-2 Acc 0.8997, top-3 Acc 0.9272, Acc: 0.8461
# Time taken for epoch: 1m 35s
# Estimated Time Remaining: 42m 56s
# Epoch 24/50
# ----------
# train Loss: 0.0075, top-2 Acc 1.0000, top-3 Acc 1.0000, Acc: 0.9985
# val Loss: 0.8066, top-2 Acc 0.8983, top-3 Acc 0.9219, Acc: 0.8472
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 42m 8s
# Epoch 25/50
# ----------
# train Loss: 0.0080, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9980
# val Loss: 0.8478, top-2 Acc 0.9015, top-3 Acc 0.9275, Acc: 0.8480
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 40m 9s
# Epoch 26/50
# ----------
# train Loss: 0.0088, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9976
# val Loss: 0.8885, top-2 Acc 0.8972, top-3 Acc 0.9213, Acc: 0.8368
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 39m 17s
# Epoch 27/50
# ----------
# train Loss: 0.0073, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9983
# val Loss: 0.9328, top-2 Acc 0.8903, top-3 Acc 0.9133, Acc: 0.8397
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 37m 4s
# Epoch 28/50
# ----------
# train Loss: 0.0059, top-2 Acc 1.0000, top-3 Acc 1.0000, Acc: 0.9993
# val Loss: 0.9219, top-2 Acc 0.8975, top-3 Acc 0.9170, Acc: 0.8400
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 36m 21s
# Epoch 29/50
# ----------
# train Loss: 0.0072, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9983
# val Loss: 0.8608, top-2 Acc 0.8986, top-3 Acc 0.9248, Acc: 0.8424
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 34m 2s
# Epoch 30/50
# ----------
# train Loss: 0.0096, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9978
# val Loss: 0.7873, top-2 Acc 0.9047, top-3 Acc 0.9261, Acc: 0.8496
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 32m 43s
# Epoch 31/50
# ----------
# train Loss: 0.0072, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9978
# val Loss: 0.9865, top-2 Acc 0.8777, top-3 Acc 0.9066, Acc: 0.8226
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 30m 34s
# Epoch 32/50
# ----------
# train Loss: 0.0075, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9985
# val Loss: 0.8929, top-2 Acc 0.8967, top-3 Acc 0.9195, Acc: 0.8435
# Time taken for epoch: 2m 1s
# Estimated Time Remaining: 36m 21s
# Epoch 33/50
# ----------
# train Loss: 0.0067, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9989
# val Loss: 0.8067, top-2 Acc 0.9034, top-3 Acc 0.9280, Acc: 0.8464
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 27m 40s
# Epoch 34/50
# ----------
# train Loss: 0.0087, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9970
# val Loss: 0.8405, top-2 Acc 0.9021, top-3 Acc 0.9296, Acc: 0.8416
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 25m 46s
# Epoch 35/50
# ----------
# train Loss: 0.0088, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9978
# val Loss: 0.8070, top-2 Acc 0.9031, top-3 Acc 0.9302, Acc: 0.8509
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 24m 38s
# Epoch 36/50
# ----------
# train Loss: 0.0077, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9980
# val Loss: 0.8441, top-2 Acc 0.9034, top-3 Acc 0.9315, Acc: 0.8413
# Time taken for epoch: 2m 2s
# Estimated Time Remaining: 28m 29s
# Epoch 37/50
# ----------
# train Loss: 0.0111, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9972
# val Loss: 0.8343, top-2 Acc 0.9034, top-3 Acc 0.9272, Acc: 0.8472
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 20m 16s
# Epoch 38/50
# ----------
# train Loss: 0.0056, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9993
# val Loss: 0.8952, top-2 Acc 0.8980, top-3 Acc 0.9227, Acc: 0.8456
# Time taken for epoch: 1m 29s
# Estimated Time Remaining: 17m 53s
# Epoch 39/50
# ----------
# train Loss: 0.0061, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9989
# val Loss: 0.8958, top-2 Acc 0.8898, top-3 Acc 0.9224, Acc: 0.8410
# Time taken for epoch: 1m 18s
# Estimated Time Remaining: 14m 20s
# Epoch 40/50
# ----------
# train Loss: 0.0098, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9980
# val Loss: 0.8163, top-2 Acc 0.9061, top-3 Acc 0.9323, Acc: 0.8427
# Time taken for epoch: 1m 33s
# Estimated Time Remaining: 15m 29s
# Epoch 41/50
# ----------
# train Loss: 0.0069, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9987
# val Loss: 0.7938, top-2 Acc 0.9109, top-3 Acc 0.9307, Acc: 0.8507
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 14m 9s
# Epoch 42/50
# ----------
# train Loss: 0.0067, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9985
# val Loss: 0.8582, top-2 Acc 0.8994, top-3 Acc 0.9227, Acc: 0.8448
# Time taken for epoch: 1m 35s
# Estimated Time Remaining: 12m 42s
# Epoch 43/50
# ----------
# train Loss: 0.0080, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9978
# val Loss: 0.7475, top-2 Acc 0.9176, top-3 Acc 0.9374, Acc: 0.8566
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 11m 13s
# Epoch 44/50
# ----------
# train Loss: 0.0068, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9987
# val Loss: 0.7629, top-2 Acc 0.9114, top-3 Acc 0.9366, Acc: 0.8496
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 9m 39s
# Epoch 45/50
# ----------
# train Loss: 0.0089, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9974
# val Loss: 0.8027, top-2 Acc 0.9053, top-3 Acc 0.9326, Acc: 0.8501
# Time taken for epoch: 2m 39s
# Estimated Time Remaining: 13m 16s
# Epoch 46/50
# ----------
# train Loss: 0.0103, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9965
# val Loss: 0.9189, top-2 Acc 0.8898, top-3 Acc 0.9117, Acc: 0.8378
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 6m 17s
# Epoch 47/50
# ----------
# train Loss: 0.0078, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9983
# val Loss: 0.9238, top-2 Acc 0.8964, top-3 Acc 0.9286, Acc: 0.8330
# Time taken for epoch: 1m 55s
# Estimated Time Remaining: 5m 46s
# Epoch 48/50
# ----------
# train Loss: 0.0081, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9980
# val Loss: 0.8682, top-2 Acc 0.8994, top-3 Acc 0.9208, Acc: 0.8389
# Time taken for epoch: 2m 24s
# Estimated Time Remaining: 4m 48s
# Epoch 49/50
# ----------
# train Loss: 0.0082, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9976
# val Loss: 0.9286, top-2 Acc 0.8879, top-3 Acc 0.9093, Acc: 0.8360
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 1m 38s
# Epoch 50/50
# ----------
# train Loss: 0.0134, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9967
# val Loss: 0.9969, top-2 Acc 0.8702, top-3 Acc 0.8962, Acc: 0.8295
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 0m 0s
# Training complete in 82m 33s
# Best val Acc: 0.857907, Best top-2 val Acc: 0.900990, Best overall top-2 Acc: 1.000000, Best top-3 val Acc: 0.922130, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftDenseNet201.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_DenseNet201_1.pt')

# %%
model_ftDenseNet201 = train_modelDenseNet201(model_ftDenseNet201, criterionDenseNet201, optimizer_ftDenseNet201, exp_lr_schedulerDenseNet201, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.5407, top-2 Acc 0.9244, top-3 Acc 0.9411, Acc: 0.8766
# val Loss: 0.8591, top-2 Acc 0.8638, top-3 Acc 0.9138, Acc: 0.7784
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 43m 46s
# Epoch 2/50
# ----------
# train Loss: 0.1040, top-2 Acc 0.9861, top-3 Acc 0.9917, Acc: 0.9713
# val Loss: 0.7779, top-2 Acc 0.8691, top-3 Acc 0.9082, Acc: 0.8039
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 42m 32s
# Epoch 3/50
# ----------
# train Loss: 0.0545, top-2 Acc 0.9946, top-3 Acc 0.9980, Acc: 0.9846
# val Loss: 0.7194, top-2 Acc 0.8978, top-3 Acc 0.9253, Acc: 0.8472
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 41m 34s
# Epoch 4/50
# ----------
# train Loss: 0.0451, top-2 Acc 0.9954, top-3 Acc 0.9980, Acc: 0.9883
# val Loss: 0.7822, top-2 Acc 0.8948, top-3 Acc 0.9286, Acc: 0.8432
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 40m 48s
# Epoch 5/50
# ----------
# train Loss: 0.0317, top-2 Acc 0.9972, top-3 Acc 0.9987, Acc: 0.9920
# val Loss: 0.6489, top-2 Acc 0.9245, top-3 Acc 0.9409, Acc: 0.8793
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 40m 20s
# Epoch 6/50
# ----------
# train Loss: 0.0203, top-2 Acc 0.9983, top-3 Acc 0.9993, Acc: 0.9941
# val Loss: 0.6898, top-2 Acc 0.9208, top-3 Acc 0.9414, Acc: 0.8694
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 39m 11s
# Epoch 7/50
# ----------
# train Loss: 0.0115, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9980
# val Loss: 0.6352, top-2 Acc 0.9323, top-3 Acc 0.9465, Acc: 0.8796
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 38m 23s
# Epoch 8/50
# ----------
# train Loss: 0.0168, top-2 Acc 0.9974, top-3 Acc 0.9987, Acc: 0.9965
# val Loss: 0.6990, top-2 Acc 0.9224, top-3 Acc 0.9435, Acc: 0.8659
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 36m 45s
# Epoch 9/50
# ----------
# train Loss: 0.0136, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9965
# val Loss: 0.6170, top-2 Acc 0.9347, top-3 Acc 0.9476, Acc: 0.8855
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 36m 4s
# Epoch 10/50
# ----------
# train Loss: 0.0117, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9961
# val Loss: 0.6507, top-2 Acc 0.9323, top-3 Acc 0.9484, Acc: 0.8812
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 35m 6s
# Epoch 11/50
# ----------
# train Loss: 0.0091, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9980
# val Loss: 0.6293, top-2 Acc 0.9302, top-3 Acc 0.9476, Acc: 0.8873
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 34m 9s
# Epoch 12/50
# ----------
# train Loss: 0.0111, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9972
# val Loss: 0.6878, top-2 Acc 0.9251, top-3 Acc 0.9419, Acc: 0.8764
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 33m 24s
# Epoch 13/50
# ----------
# train Loss: 0.0119, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9980
# val Loss: 0.6608, top-2 Acc 0.9296, top-3 Acc 0.9451, Acc: 0.8772
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 32m 24s
# Epoch 14/50
# ----------
# train Loss: 0.0125, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9959
# val Loss: 0.6890, top-2 Acc 0.9261, top-3 Acc 0.9446, Acc: 0.8761
# Time taken for epoch: 0m 52s
# Estimated Time Remaining: 31m 29s
# Epoch 15/50
# ----------
# train Loss: 0.0110, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9978
# val Loss: 0.6815, top-2 Acc 0.9296, top-3 Acc 0.9470, Acc: 0.8785
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 30m 49s
# Epoch 16/50
# ----------
# train Loss: 0.0109, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9972
# val Loss: 0.6845, top-2 Acc 0.9240, top-3 Acc 0.9438, Acc: 0.8699
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 29m 53s
# Epoch 17/50
# ----------
# train Loss: 0.0133, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9970
# val Loss: 0.6883, top-2 Acc 0.9264, top-3 Acc 0.9476, Acc: 0.8745
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 29m 7s
# Epoch 18/50
# ----------
# train Loss: 0.0129, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9976
# val Loss: 0.5886, top-2 Acc 0.9374, top-3 Acc 0.9473, Acc: 0.8927
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 28m 6s
# Epoch 19/50
# ----------
# train Loss: 0.0149, top-2 Acc 0.9983, top-3 Acc 0.9993, Acc: 0.9959
# val Loss: 0.6651, top-2 Acc 0.9248, top-3 Acc 0.9497, Acc: 0.8726
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 27m 15s
# Epoch 20/50
# ----------
# train Loss: 0.0150, top-2 Acc 0.9978, top-3 Acc 0.9991, Acc: 0.9965
# val Loss: 0.6226, top-2 Acc 0.9334, top-3 Acc 0.9481, Acc: 0.8863
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 26m 17s
# Epoch 21/50
# ----------
# train Loss: 0.0159, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9957
# val Loss: 0.6056, top-2 Acc 0.9310, top-3 Acc 0.9492, Acc: 0.8865
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 25m 25s
# Epoch 22/50
# ----------
# train Loss: 0.0098, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9976
# val Loss: 0.6434, top-2 Acc 0.9294, top-3 Acc 0.9459, Acc: 0.8900
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 24m 35s
# Epoch 23/50
# ----------
# train Loss: 0.0094, top-2 Acc 1.0000, top-3 Acc 1.0000, Acc: 0.9983
# val Loss: 0.5603, top-2 Acc 0.9406, top-3 Acc 0.9513, Acc: 0.8951
# Time taken for epoch: 0m 53s
# Estimated Time Remaining:
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 10m 35s
# Epoch 39/50
# ----------
# train Loss: 0.0126, top-2 Acc 0.9985, top-3 Acc 0.9989, Acc: 0.9978
# val Loss: 0.6256, top-2 Acc 0.9331, top-3 Acc 0.9476, Acc: 0.8908
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 9m 38s
# Epoch 40/50
# ----------
# train Loss: 0.0158, top-2 Acc 0.9985, top-3 Acc 0.9989, Acc: 0.9957
# val Loss: 0.6438, top-2 Acc 0.9310, top-3 Acc 0.9465, Acc: 0.8860
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 8m 48s
# Epoch 41/50
# ----------
# train Loss: 0.0137, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9957
# val Loss: 0.7135, top-2 Acc 0.9224, top-3 Acc 0.9435, Acc: 0.8691
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 7m 55s
# Epoch 42/50
# ----------
# train Loss: 0.0119, top-2 Acc 0.9989, top-3 Acc 0.9993, Acc: 0.9967
# val Loss: 0.6524, top-2 Acc 0.9323, top-3 Acc 0.9473, Acc: 0.8881
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 7m 3s
# Epoch 43/50
# ----------
# train Loss: 0.0123, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9963
# val Loss: 0.6130, top-2 Acc 0.9339, top-3 Acc 0.9505, Acc: 0.8801
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 6m 10s
# Epoch 44/50
# ----------
# train Loss: 0.0127, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9972
# val Loss: 0.6689, top-2 Acc 0.9259, top-3 Acc 0.9473, Acc: 0.8708
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 5m 16s
# Epoch 45/50
# ----------
# train Loss: 0.0133, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9957
# val Loss: 0.6590, top-2 Acc 0.9280, top-3 Acc 0.9470, Acc: 0.8761
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 4m 24s
# Epoch 46/50
# ----------
# train Loss: 0.0114, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9974
# val Loss: 0.6097, top-2 Acc 0.9339, top-3 Acc 0.9505, Acc: 0.8758
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 3m 31s
# Epoch 47/50
# ----------
# train Loss: 0.0102, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9978
# val Loss: 0.6897, top-2 Acc 0.9253, top-3 Acc 0.9476, Acc: 0.8750
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 2m 39s
# Epoch 48/50
# ----------
# train Loss: 0.0145, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9967
# val Loss: 0.6548, top-2 Acc 0.9296, top-3 Acc 0.9443, Acc: 0.8788
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 1m 46s
# Epoch 49/50
# ----------
# train Loss: 0.0109, top-2 Acc 0.9989, top-3 Acc 0.9991, Acc: 0.9976
# val Loss: 0.6612, top-2 Acc 0.9280, top-3 Acc 0.9478, Acc: 0.8756
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 0m 53s
# Epoch 50/50
# ----------
# train Loss: 0.0108, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9976
# val Loss: 0.6339, top-2 Acc 0.9328, top-3 Acc 0.9492, Acc: 0.8828
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 0m 0s
# Training complete in 44m 4s
# Best val Acc: 0.895103, Best top-2 val Acc: 0.940594, Best overall top-2 Acc: 1.000000, Best top-3 val Acc: 0.951298, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftDenseNet201.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_DenseNet201_1_Aug_CB.pt')

# %%
model1 = models.densenet201(pretrained=True)
loaded_model1 = torch.load('/home/dlpc01/Rifat/saved_models/HSPR_DenseNet201_1.pt')
# print(loaded_model.keys())
model1.load_state_dict(loaded_model1, strict=False)
model1.eval().to(device)
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer25): _DenseLayer(
#         (norm1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer26): _DenseLayer(
#         (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer27): _DenseLayer(
#         (norm1): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1088, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer28): _DenseLayer(
#         (norm1): BatchNorm2d(1120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1120, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer29): _DenseLayer(
#         (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer30): _DenseLayer(
#         (norm1): BatchNorm2d(1184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1184, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer31): _DenseLayer(
#         (norm1): BatchNorm2d(1216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1216, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer32): _DenseLayer(
#         (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer33): _DenseLayer(
#         (norm1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1280, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer34): _DenseLayer(
#         (norm1): BatchNorm2d(1312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1312, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer35): _DenseLayer(
#         (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer36): _DenseLayer(
#         (norm1): BatchNorm2d(1376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1376, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer37): _DenseLayer(
#         (norm1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1408, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer38): _DenseLayer(
#         (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer39): _DenseLayer(
#         (norm1): BatchNorm2d(1472, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1472, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer40): _DenseLayer(
#         (norm1): BatchNorm2d(1504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1504, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer41): _DenseLayer(
#         (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer42): _DenseLayer(
#         (norm1): BatchNorm2d(1568, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1568, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer43): _DenseLayer(
#         (norm1): BatchNorm2d(1600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1600, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer44): _DenseLayer(
#         (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer45): _DenseLayer(
#         (norm1): BatchNorm2d(1664, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1664, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer46): _DenseLayer(
#         (norm1): BatchNorm2d(1696, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1696, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer47): _DenseLayer(
#         (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer48): _DenseLayer(
#         (norm1): BatchNorm2d(1760, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1760, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1792, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1088, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(1120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1120, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(1184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1184, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(1216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1216, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1280, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(1312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1312, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(1376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1376, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1408, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(1472, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1472, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(1504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1504, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(1568, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1568, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(1600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1600, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer25): _DenseLayer(
#         (norm1): BatchNorm2d(1664, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1664, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer26): _DenseLayer(
#         (norm1): BatchNorm2d(1696, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1696, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer27): _DenseLayer(
#         (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer28): _DenseLayer(
#         (norm1): BatchNorm2d(1760, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1760, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer29): _DenseLayer(
#         (norm1): BatchNorm2d(1792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1792, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer30): _DenseLayer(
#         (norm1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1824, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer31): _DenseLayer(
#         (norm1): BatchNorm2d(1856, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1856, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer32): _DenseLayer(
#         (norm1): BatchNorm2d(1888, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1888, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=1920, out_features=1000, bias=True)
# )

# %%
def train_modelResNet152(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, topK0preds = torch.topk(outputs, k[0], 1)
                    _, topK1preds = torch.topk(outputs, k[1], 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftResNet152 = models.resnet152(pretrained=True)
num_ftrsResNet152 = model_ftResNet152.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsResNet152, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
# model_ftResNet152.fc = nn.Linear(num_ftrsResNet152, 11)

model_ftResNet152 = model_ftResNet152.to(device)

criterionResNet152 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftResNet152 = optim.SGD(model_ftResNet152.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerResNet152 = lr_scheduler.StepLR(optimizer_ftResNet152, step_size=5, gamma=0.1)

# %%
model_ftResNet152 = train_modelResNet152(model_ftResNet152, criterionResNet152, optimizer_ftResNet152, exp_lr_schedulerResNet152, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.4055, top-2 Acc 0.9320, top-3 Acc 0.9494, Acc: 0.8872
# val Loss: 0.9395, top-2 Acc 0.8459, top-3 Acc 0.8975, Acc: 0.7407
# Time taken for epoch: 1m 44s
# Estimated Time Remaining: 85m 13s
# Epoch 2/50
# ----------
# train Loss: 0.0728, top-2 Acc 0.9939, top-3 Acc 0.9976, Acc: 0.9807
# val Loss: 0.7940, top-2 Acc 0.8777, top-3 Acc 0.9200, Acc: 0.8188
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 77m 57s
# Epoch 3/50
# ----------
# train Loss: 0.0373, top-2 Acc 0.9983, top-3 Acc 0.9989, Acc: 0.9928
# val Loss: 1.0028, top-2 Acc 0.8697, top-3 Acc 0.9162, Acc: 0.7969
# Time taken for epoch: 1m 40s
# Estimated Time Remaining: 78m 42s
# Epoch 4/50
# ----------
# train Loss: 0.0388, top-2 Acc 0.9970, top-3 Acc 0.9985, Acc: 0.9891
# val Loss: 0.6605, top-2 Acc 0.9104, top-3 Acc 0.9374, Acc: 0.8461
# Time taken for epoch: 2m 29s
# Estimated Time Remaining: 113m 58s
# Epoch 5/50
# ----------
# train Loss: 0.0271, top-2 Acc 0.9972, top-3 Acc 0.9983, Acc: 0.9924
# val Loss: 0.6529, top-2 Acc 0.9018, top-3 Acc 0.9291, Acc: 0.8550
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 73m 38s
# Epoch 6/50
# ----------
# train Loss: 0.0138, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9985
# val Loss: 0.6936, top-2 Acc 0.8970, top-3 Acc 0.9283, Acc: 0.8509
# Time taken for epoch: 2m 9s
# Estimated Time Remaining: 94m 32s
# Epoch 7/50
# ----------
# train Loss: 0.0141, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9974
# val Loss: 0.6536, top-2 Acc 0.9125, top-3 Acc 0.9352, Acc: 0.8590
# Time taken for epoch: 2m 1s
# Estimated Time Remaining: 86m 54s
# Epoch 8/50
# ----------
# train Loss: 0.0094, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9985
# val Loss: 0.6325, top-2 Acc 0.9109, top-3 Acc 0.9363, Acc: 0.8630
# Time taken for epoch: 1m 43s
# Estimated Time Remaining: 72m 2s
# Epoch 9/50
# ----------
# train Loss: 0.0094, top-2 Acc 1.0000, top-3 Acc 1.0000, Acc: 0.9987
# val Loss: 0.6491, top-2 Acc 0.9122, top-3 Acc 0.9358, Acc: 0.8584
# Time taken for epoch: 1m 52s
# Estimated Time Remaining: 76m 31s
# Epoch 10/50
# ----------
# train Loss: 0.0107, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9978
# val Loss: 0.6913, top-2 Acc 0.9109, top-3 Acc 0.9411, Acc: 0.8518
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 65m 59s
# Epoch 11/50
# ----------
# train Loss: 0.0070, top-2 Acc 1.0000, top-3 Acc 1.0000, Acc: 0.9987
# val Loss: 0.6662, top-2 Acc 0.9069, top-3 Acc 0.9398, Acc: 0.8555
# Time taken for epoch: 1m 56s
# Estimated Time Remaining: 75m 8s
# Epoch 12/50
# ----------
# train Loss: 0.0117, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9974
# val Loss: 0.8051, top-2 Acc 0.8940, top-3 Acc 0.9187, Acc: 0.8443
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 61m 29s
# Epoch 13/50
# ----------
# train Loss: 0.0106, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9978
# val Loss: 0.6530, top-2 Acc 0.9074, top-3 Acc 0.9406, Acc: 0.8552
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 61m 2s
# Epoch 14/50
# ----------
# train Loss: 0.0107, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9974
# val Loss: 0.6517, top-2 Acc 0.9117, top-3 Acc 0.9401, Acc: 0.8584
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 57m 30s
# Epoch 15/50
# ----------
# train Loss: 0.0092, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9991
# val Loss: 0.6582, top-2 Acc 0.9066, top-3 Acc 0.9339, Acc: 0.8552
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 56m 11s
# Epoch 16/50
# ----------
# train Loss: 0.0107, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9976
# val Loss: 0.7141, top-2 Acc 0.9005, top-3 Acc 0.9339, Acc: 0.8499
# Time taken for epoch: 1m 23s
# Estimated Time Remaining: 47m 12s
# Epoch 17/50
# ----------
# train Loss: 0.0102, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9983
# val Loss: 0.6841, top-2 Acc 0.9112, top-3 Acc 0.9382, Acc: 0.8526
# Time taken for epoch: 1m 54s
# Estimated Time Remaining: 62m 46s
# Epoch 18/50
# ----------
# train Loss: 0.0081, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9989
# val Loss: 0.6905, top-2 Acc 0.9055, top-3 Acc 0.9366, Acc: 0.8550
# Time taken for epoch: 1m 54s
# Estimated Time Remaining: 60m 55s
# Epoch 19/50
# ----------
# train Loss: 0.0088, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9980
# val Loss: 0.8351, top-2 Acc 0.8980, top-3 Acc 0.9229, Acc: 0.8408
# Time taken for epoch: 1m 55s
# Estimated Time Remaining: 59m 37s
# Epoch 20/50
# ----------
# train Loss: 0.0088, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9989
# val Loss: 0.6697, top-2 Acc 0.9026, top-3 Acc 0.9344, Acc: 0.8558
# Time taken for epoch: 1m 40s
# Estimated Time Remaining: 49m 48s
# Epoch 21/50
# ----------
# train Loss: 0.0093, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9980
# val Loss: 0.6661, top-2 Acc 0.9061, top-3 Acc 0.9371, Acc: 0.8555
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 46m 46s
# Epoch 22/50
# ----------
# train Loss: 0.0084, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9993
# val Loss: 0.6840, top-2 Acc 0.9079, top-3 Acc 0.9344, Acc: 0.8566
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 45m 31s
# Epoch 23/50
# ----------
# train Loss: 0.0083, top-2 Acc 1.0000, top-3 Acc 1.0000, Acc: 0.9991
# val Loss: 0.6282, top-2 Acc 0.9133, top-3 Acc 0.9390, Acc: 0.8571
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 43m 26s
# Epoch 24/50
# ----------
# train Loss: 0.0090, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9985
# val Loss: 0.7177, top-2 Acc 0.9088, top-3 Acc 0.9339, Acc: 0.8507
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 42m 32s
# Epoch 25/50
# ----------
# train Loss: 0.0096, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9980
# val Loss: 0.6991, top-2 Acc 0.9114, top-3 Acc 0.9328, Acc: 0.8544
# Time taken for epoch: 2m 10s
# Estimated Time Remaining: 54m 13s
# Epoch 26/50
# ----------
# train Loss: 0.0089, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9983
# val Loss: 0.7048, top-2 Acc 0.9066, top-3 Acc 0.9366, Acc: 0.8491
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 39m 13s
# Epoch 27/50
# ----------
# train Loss: 0.0094, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9976
# val Loss: 0.7046, top-2 Acc 0.9055, top-3 Acc 0.9377, Acc: 0.8501
# Time taken for epoch: 1m 42s
# Estimated Time Remaining: 38m 58s
# Epoch 28/50
# ----------
# train Loss: 0.0091, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9978
# val Loss: 0.6860, top-2 Acc 0.9063, top-3 Acc 0.9366, Acc: 0.8539
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 36m 8s
# Epoch 29/50
# ----------
# train Loss: 0.0076, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9987
# val Loss: 0.6964, top-2 Acc 0.9042, top-3 Acc 0.9358, Acc: 0.8544
# Time taken for epoch: 1m 41s
# Estimated Time Remaining: 35m 21s
# Epoch 30/50
# ----------
# train Loss: 0.0105, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9987
# val Loss: 0.7359, top-2 Acc 0.8980, top-3 Acc 0.9302, Acc: 0.8448
# Time taken for epoch: 1m 43s
# Estimated Time Remaining: 34m 18s
# Epoch 31/50
# ----------
# train Loss: 0.0091, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9976
# val Loss: 0.6696, top-2 Acc 0.9079, top-3 Acc 0.9371, Acc: 0.8526
# Time taken for epoch: 1m 41s
# Estimated Time Remaining: 32m 6s
# Epoch 32/50
# ----------
# train Loss: 0.0076, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9987
# val Loss: 0.6990, top-2 Acc 0.9085, top-3 Acc 0.9331, Acc: 0.8552
# Time taken for epoch: 1m 45s
# Estimated Time Remaining: 31m 25s
# Epoch 33/50
# ----------
# train Loss: 0.0081, top-2 Acc 1.0000, top-3 Acc 1.0000, Acc: 0.9978
# val Loss: 0.7526, top-2 Acc 0.9055, top-3 Acc 0.9299, Acc: 0.8483
# Time taken for epoch: 1m 40s
# Estimated Time Remaining: 28m 26s
# Epoch 34/50
# ----------
# train Loss: 0.0102, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9978
# val Loss: 0.7773, top-2 Acc 0.8935, top-3 Acc 0.9245, Acc: 0.8427
# Time taken for epoch: 1m 30s
# Estimated Time Remaining: 24m 6s
# Epoch 35/50
# ----------
# train Loss: 0.0078, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9989
# val Loss: 0.6867, top-2 Acc 0.9034, top-3 Acc 0.9350, Acc: 0.8552
# Time taken for epoch: 1m 22s
# Estimated Time Remaining: 20m 28s
# Epoch 36/50
# ----------
# train Loss: 0.0099, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9985
# val Loss: 0.6376, top-2 Acc 0.9130, top-3 Acc 0.9414, Acc: 0.8592
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 22m 36s
# Epoch 37/50
# ----------
# train Loss: 0.0079, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9983
# val Loss: 0.7121, top-2 Acc 0.9058, top-3 Acc 0.9331, Acc: 0.8523
# Time taken for epoch: 1m 8s
# Estimated Time Remaining: 14m 44s
# Epoch 38/50
# ----------
# train Loss: 0.0070, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9985
# val Loss: 0.7090, top-2 Acc 0.9055, top-3 Acc 0.9355, Acc: 0.8523
# Time taken for epoch: 1m 27s
# Estimated Time Remaining: 17m 30s
# Epoch 39/50
# ----------
# train Loss: 0.0083, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9989
# val Loss: 0.6866, top-2 Acc 0.9133, top-3 Acc 0.9352, Acc: 0.8512
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 18m 12s
# Epoch 40/50
# ----------
# train Loss: 0.0107, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9983
# val Loss: 0.7229, top-2 Acc 0.9018, top-3 Acc 0.9315, Acc: 0.8501
# Time taken for epoch: 1m 31s
# Estimated Time Remaining: 15m 12s
# Epoch 41/50
# ----------
# train Loss: 0.0112, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9978
# val Loss: 0.7109, top-2 Acc 0.9018, top-3 Acc 0.9302, Acc: 0.8512
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 14m 46s
# Epoch 42/50
# ----------
# train Loss: 0.0072, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9989
# val Loss: 0.7434, top-2 Acc 0.9085, top-3 Acc 0.9334, Acc: 0.8504
# Time taken for epoch: 1m 30s
# Estimated Time Remaining: 11m 56s
# Epoch 43/50
# ----------
# train Loss: 0.0076, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9983
# val Loss: 0.7206, top-2 Acc 0.9047, top-3 Acc 0.9371, Acc: 0.8504
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 10m 57s
# Epoch 44/50
# ----------
# train Loss: 0.0077, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9989
# val Loss: 0.7567, top-2 Acc 0.8994, top-3 Acc 0.9310, Acc: 0.8453
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 9m 26s
# Epoch 45/50
# ----------
# train Loss: 0.0121, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9978
# val Loss: 0.6106, top-2 Acc 0.9146, top-3 Acc 0.9414, Acc: 0.8681
# Time taken for epoch: 1m 29s
# Estimated Time Remaining: 7m 24s
# Epoch 46/50
# ----------
# train Loss: 0.0107, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9980
# val Loss: 0.7057, top-2 Acc 0.9047, top-3 Acc 0.9355, Acc: 0.8550
# Time taken for epoch: 1m 16s
# Estimated Time Remaining: 5m 3s
# Epoch 47/50
# ----------
# train Loss: 0.0094, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9976
# val Loss: 0.6769, top-2 Acc 0.9106, top-3 Acc 0.9347, Acc: 0.8574
# Time taken for epoch: 1m 29s
# Estimated Time Remaining: 4m 28s
# Epoch 48/50
# ----------
# train Loss: 0.0110, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9970
# val Loss: 0.6306, top-2 Acc 0.9104, top-3 Acc 0.9414, Acc: 0.8622
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 3m 12s
# Epoch 49/50
# ----------
# train Loss: 0.0090, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9985
# val Loss: 0.6711, top-2 Acc 0.9122, top-3 Acc 0.9352, Acc: 0.8536
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 1m 36s
# Epoch 50/50
# ----------
# train Loss: 0.0134, top-2 Acc 0.9987, top-3 Acc 0.9989, Acc: 0.9970
# val Loss: 0.6985, top-2 Acc 0.9029, top-3 Acc 0.9355, Acc: 0.8515
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 0m 0s
# Training complete in 83m 25s
# Best val Acc: 0.868076, Best top-2 val Acc: 0.914637, Best overall top-2 Acc: 1.000000, Best top-3 val Acc: 0.941397, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftResNet152.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_ResNet152_1.pt')

# %%
model_ftResNet152 = train_modelResNet152(model_ftResNet152, criterionResNet152, optimizer_ftResNet152, exp_lr_schedulerResNet152, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.5335, top-2 Acc 0.9248, top-3 Acc 0.9411, Acc: 0.8801
# val Loss: 1.1273, top-2 Acc 0.8710, top-3 Acc 0.9294, Acc: 0.7656
# Time taken for epoch: 0m 52s
# Estimated Time Remaining: 42m 40s
# Epoch 2/50
# ----------
# train Loss: 0.1012, top-2 Acc 0.9896, top-3 Acc 0.9928, Acc: 0.9737
# val Loss: 1.0086, top-2 Acc 0.8903, top-3 Acc 0.9157, Acc: 0.7950
# Time taken for epoch: 0m 52s
# Estimated Time Remaining: 41m 54s
# Epoch 3/50
# ----------
# train Loss: 0.0595, top-2 Acc 0.9944, top-3 Acc 0.9978, Acc: 0.9833
# val Loss: 1.1099, top-2 Acc 0.8785, top-3 Acc 0.9162, Acc: 0.8012
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 41m 8s
# Epoch 4/50
# ----------
# train Loss: 0.0472, top-2 Acc 0.9963, top-3 Acc 0.9978, Acc: 0.9878
# val Loss: 0.8052, top-2 Acc 0.9168, top-3 Acc 0.9398, Acc: 0.8451
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 40m 39s
# Epoch 5/50
# ----------
# train Loss: 0.0332, top-2 Acc 0.9985, top-3 Acc 0.9989, Acc: 0.9926
# val Loss: 0.8252, top-2 Acc 0.9037, top-3 Acc 0.9500, Acc: 0.8520
# Time taken for epoch: 0m 53s
# Estimated Time Remaining:
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 0m 0s
# Training complete in 44m 47s
# Best val Acc: 0.883596, Best top-2 val Acc: 0.926679, Best overall top-2 Acc: 0.999783, Best top-3 val Acc: 0.952636, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftResNet152.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_ResNet152_1_Aug_CB.pt')

# %%
model2 = models.resnet152(pretrained=True)
model2.fc = nn.Linear(num_ftrsResNet152, 11)
loaded_model2 = torch.load('/home/dlpc01/Rifat/saved_models/HSPR_ResNet152_1.pt')
# print(loaded_model.keys())
model2.load_state_dict(loaded_model2, strict=False)
model2.eval().to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=11, bias=True)
# )

# %%
def train_modelViTL32(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, topK0preds = torch.topk(outputs, k[0], 1)
                    _, topK1preds = torch.topk(outputs, k[1], 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftViTL32 = models.vit_l_32(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrsViTL32 = model_ftViTL32.heads.head.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsMaxViT, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
# model_ftViTL32.fc = nn.Linear(num_ftrsViTL32, 11)
model_ftMaxViT.fc = classifier_block

model_ftViTL32 = model_ftViTL32.to(device)

criterionViTL32 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftViTL32 = optim.SGD(model_ftViTL32.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerViTL32 = lr_scheduler.StepLR(optimizer_ftViTL32, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_L_32_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_L_32_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ftViTL32 = train_modelViTL32(model_ftViTL32, criterionViTL32, optimizer_ftViTL32, exp_lr_schedulerViTL32, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss:
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 46m 53s
# Epoch 11/50
# ----------
# train Loss: 0.0360, top-2 Acc 0.9970, top-3 Acc 0.9985, Acc: 0.9891
# val Loss: 1.1304, top-2 Acc 0.8103, top-3 Acc 0.8657, Acc: 0.7340
# Time taken for epoch: 1m 11s
# Estimated Time Remaining: 46m 20s
# Epoch 12/50
# ----------
# train Loss: 0.0357, top-2 Acc 0.9974, top-3 Acc 0.9996, Acc: 0.9898
# val Loss: 1.1301, top-2 Acc 0.8100, top-3 Acc 0.8667, Acc: 0.7372
# Time taken for epoch: 1m 11s
# Estimated Time Remaining: 44m 48s
# Epoch 13/50
# ----------
# train Loss: 0.0349, top-2 Acc 0.9961, top-3 Acc 0.9985, Acc: 0.9907
# val Loss: 1.1257, top-2 Acc 0.8119, top-3 Acc 0.8678, Acc: 0.7386
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 42m 55s
# Epoch 14/50
# ----------
# train Loss: 0.0384, top-2 Acc 0.9965, top-3 Acc 0.9987, Acc: 0.9889
# val Loss: 1.1288, top-2 Acc 0.8119, top-3 Acc 0.8670, Acc: 0.7388
# Time taken for epoch: 1m 11s
# Estimated Time Remaining: 42m 49s
# Epoch 15/50
# ----------
# train Loss: 0.0350, top-2 Acc 0.9963, top-3 Acc 0.9993, Acc: 0.9900
# val Loss: 1.1186, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7391
# Time taken for epoch: 1m 12s
# Estimated Time Remaining: 42m 8s
# Epoch 16/50
# ----------
# train Loss: 0.0344, top-2 Acc 0.9976, top-3 Acc 0.9991, Acc: 0.9896
# val Loss: 1.1185, top-2 Acc 0.8140, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 16s
# Estimated Time Remaining: 43m 2s
# Epoch 17/50
# ----------
# train Loss: 0.0374, top-2 Acc 0.9965, top-3 Acc 0.9978, Acc: 0.9896
# val Loss: 1.1184, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 16s
# Estimated Time Remaining: 42m 2s
# Epoch 18/50
# ----------
# train Loss: 0.0392, top-2 Acc 0.9961, top-3 Acc 0.9985, Acc: 0.9883
# val Loss: 1.1186, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 16s
# Estimated Time Remaining: 40m 34s
# Epoch 19/50
# ----------
# train Loss: 0.0354, top-2 Acc 0.9970, top-3 Acc 0.9987, Acc: 0.9904
# val Loss: 1.1182, top-2 Acc 0.8140, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 17s
# Estimated Time Remaining: 39m 45s
# Epoch 20/50
# ----------
# train Loss: 0.0335, top-2 Acc 0.9963, top-3 Acc 0.9974, Acc: 0.9915
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 13s
# Estimated Time Remaining: 36m 29s
# Epoch 21/50
# ----------
# train Loss: 0.0358, top-2 Acc 0.9963, top-3 Acc 0.9972, Acc: 0.9894
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 15s
# Estimated Time Remaining: 36m 22s
# Epoch 22/50
# ----------
# train Loss: 0.0394, top-2 Acc 0.9957, top-3 Acc 0.9978, Acc: 0.9891
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 8s
# Estimated Time Remaining: 31m 30s
# Epoch 23/50
# ----------
# train Loss: 0.0371, top-2 Acc 0.9967, top-3 Acc 0.9980, Acc: 0.9898
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 30m 14s
# Epoch 24/50
# ----------
# train Loss: 0.0328, top-2 Acc 0.9985, top-3 Acc 0.9998, Acc: 0.9911
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 29m 6s
# Epoch 25/50
# ----------
# train Loss: 0.0354, top-2 Acc 0.9967, top-3 Acc 0.9985, Acc: 0.9891
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 29m 9s
# Epoch 26/50
# ----------
# train Loss: 0.0434, top-2 Acc 0.9952, top-3 Acc 0.9974, Acc: 0.9874
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 8s
# Estimated Time Remaining: 27m 9s
# Epoch 27/50
# ----------
# train Loss: 0.0374, top-2 Acc 0.9957, top-3 Acc 0.9978, Acc: 0.9889
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 26m 20s
# Epoch 28/50
# ----------
# train Loss: 0.0354, top-2 Acc 0.9970, top-3 Acc 0.9985, Acc: 0.9900
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 25m 11s
# Epoch 29/50
# ----------
# train Loss: 0.0320, top-2 Acc 0.9970, top-3 Acc 0.9987, Acc: 0.9915
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 8s
# Estimated Time Remaining: 23m 55s
# Epoch 30/50
# ----------
# train Loss: 0.0329, top-2 Acc 0.9972, top-3 Acc 0.9985, Acc: 0.9902
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 22m 50s
# Epoch 31/50
# ----------
# train Loss: 0.0343, top-2 Acc 0.9978, top-3 Acc 0.9987, Acc: 0.9902
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 8s
# Estimated Time Remaining: 21m 38s
# Epoch 32/50
# ----------
# train Loss: 0.0375, top-2 Acc 0.9970, top-3 Acc 0.9983, Acc: 0.9872
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 20m 42s
# Epoch 33/50
# ----------
# train Loss: 0.0388, top-2 Acc 0.9972, top-3 Acc 0.9989, Acc: 0.9878
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 13s
# Estimated Time Remaining: 20m 33s
# Epoch 34/50
# ----------
# train Loss: 0.0376, top-2 Acc 0.9954, top-3 Acc 0.9972, Acc: 0.9900
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 8s
# Estimated Time Remaining: 18m 6s
# Epoch 35/50
# ----------
# train Loss: 0.0366, top-2 Acc 0.9970, top-3 Acc 0.9989, Acc: 0.9889
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 16m 52s
# Epoch 36/50
# ----------
# train Loss: 0.0382, top-2 Acc 0.9961, top-3 Acc 0.9983, Acc: 0.9902
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 12s
# Estimated Time Remaining: 16m 44s
# Epoch 37/50
# ----------
# train Loss: 0.0320, top-2 Acc 0.9963, top-3 Acc 0.9985, Acc: 0.9922
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 12s
# Estimated Time Remaining: 15m 30s
# Epoch 38/50
# ----------
# train Loss: 0.0437, top-2 Acc 0.9941, top-3 Acc 0.9972, Acc: 0.9865
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 13m 29s
# Epoch 39/50
# ----------
# train Loss: 0.0347, top-2 Acc 0.9959, top-3 Acc 0.9985, Acc: 0.9891
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 12m 20s
# Epoch 40/50
# ----------
# train Loss: 0.0395, top-2 Acc 0.9957, top-3 Acc 0.9978, Acc: 0.9900
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 11m 10s
# Epoch 41/50
# ----------
# train Loss: 0.0378, top-2 Acc 0.9959, top-3 Acc 0.9972, Acc: 0.9911
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 10m 5s
# Epoch 42/50
# ----------
# train Loss: 0.0385, top-2 Acc 0.9970, top-3 Acc 0.9983, Acc: 0.9883
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 8m 59s
# Epoch 43/50
# ----------
# train Loss: 0.0387, top-2 Acc 0.9965, top-3 Acc 0.9987, Acc: 0.9889
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 7m 50s
# Epoch 44/50
# ----------
# train Loss: 0.0354, top-2 Acc 0.9963, top-3 Acc 0.9978, Acc: 0.9876
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 8s
# Estimated Time Remaining: 6m 45s
# Epoch 45/50
# ----------
# train Loss: 0.0353, top-2 Acc 0.9974, top-3 Acc 0.9989, Acc: 0.9889
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 5m 36s
# Epoch 46/50
# ----------
# train Loss: 0.0362, top-2 Acc 0.9967, top-3 Acc 0.9987, Acc: 0.9900
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 8s
# Estimated Time Remaining: 4m 30s
# Epoch 47/50
# ----------
# train Loss: 0.0330, top-2 Acc 0.9976, top-3 Acc 0.9993, Acc: 0.9900
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 8s
# Estimated Time Remaining: 3m 23s
# Epoch 48/50
# ----------
# train Loss: 0.0348, top-2 Acc 0.9959, top-3 Acc 0.9983, Acc: 0.9896
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 2m 15s
# Epoch 49/50
# ----------
# train Loss: 0.0371, top-2 Acc 0.9965, top-3 Acc 0.9989, Acc: 0.9894
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 1m 7s
# Epoch 50/50
# ----------
# train Loss: 0.0399, top-2 Acc 0.9959, top-3 Acc 0.9987, Acc: 0.9876
# val Loss: 1.1187, top-2 Acc 0.8138, top-3 Acc 0.8683, Acc: 0.7394
# Time taken for epoch: 1m 7s
# Estimated Time Remaining: 0m 0s
# Training complete in 58m 22s
# Best val Acc: 0.739363, Best top-2 val Acc: 0.814022, Best overall top-2 Acc: 0.998479, Best top-3 val Acc: 0.868344, Best overall top-3 Acc: 0.999783

# %%
torch.save(model_ftViTL32.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_ViTL32_1.pt')

# %%
model_ftViTL32 = train_modelViTL32(model_ftViTL32, criterionViTL32, optimizer_ftViTL32, exp_lr_schedulerViTL32, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 1.1812, top-2 Acc 0.7793, top-3 Acc 0.8399, Acc: 0.6680
# val Loss: 1.7138, top-2 Acc 0.6345, top-3 Acc 0.7281, Acc: 0.4897
# Time taken for epoch: 1m 8s
# Estimated Time Remaining: 55m 19s
# Epoch 2/50
# ----------
# train Loss: 0.4093, top-2 Acc 0.9359, top-3 Acc 0.9633, Acc: 0.8675
# val Loss: 1.5900, top-2 Acc 0.6850, top-3 Acc 0.7592, Acc: 0.5876
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 55m 22s
# Epoch 3/50
# ----------
# train Loss: 0.2626, top-2 Acc 0.9635, top-3 Acc 0.9824, Acc: 0.9124
# val Loss: 1.6060, top-2 Acc 0.7372, top-3 Acc 0.7923, Acc: 0.6358
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 55m 1s
# Epoch 4/50
# ----------
# train Loss: 0.1910, top-2 Acc 0.9772, top-3 Acc 0.9874, Acc: 0.9376
# val Loss: 1.4135, top-2 Acc 0.7412, top-3 Acc 0.8237, Acc: 0.6503
# Time taken for epoch: 1m 15s
# Estimated Time Remaining: 57m 32s
# Epoch 5/50
# ----------
# train Loss: 0.1590, top-2 Acc 0.9811, top-3 Acc 0.9876, Acc: 0.9487
# val Loss: 1.1864, top-2 Acc 0.8071, top-3 Acc 0.8697, Acc: 0.7078
# Time taken for epoch: 1m 10s
# Estimated Time Remaining:
top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7675
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 36m 53s
# Epoch 19/50
# ----------
# train Loss: 0.0379, top-2 Acc 0.9970, top-3 Acc 0.9983, Acc: 0.9904
# val Loss: 0.9794, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 16s
# Estimated Time Remaining: 39m 28s
# Epoch 20/50
# ----------
# train Loss: 0.0334, top-2 Acc 0.9972, top-3 Acc 0.9991, Acc: 0.9898
# val Loss: 0.9796, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 34m 39s
# Epoch 21/50
# ----------
# train Loss: 0.0513, top-2 Acc 0.9946, top-3 Acc 0.9967, Acc: 0.9839
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 12s
# Estimated Time Remaining: 34m 36s
# Epoch 22/50
# ----------
# train Loss: 0.0489, top-2 Acc 0.9959, top-3 Acc 0.9972, Acc: 0.9835
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 32m 42s
# Epoch 23/50
# ----------
# train Loss: 0.0480, top-2 Acc 0.9952, top-3 Acc 0.9978, Acc: 0.9848
# val Loss: 0.9796, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 11s
# Estimated Time Remaining: 31m 59s
# Epoch 24/50
# ----------
# train Loss: 0.0363, top-2 Acc 0.9972, top-3 Acc 0.9991, Acc: 0.9898
# val Loss: 0.9796, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 30m 9s
# Epoch 25/50
# ----------
# train Loss: 0.0467, top-2 Acc 0.9950, top-3 Acc 0.9978, Acc: 0.9846
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 18s
# Estimated Time Remaining: 32m 30s
# Epoch 26/50
# ----------
# train Loss: 0.0370, top-2 Acc 0.9963, top-3 Acc 0.9985, Acc: 0.9874
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 27m 38s
# Epoch 27/50
# ----------
# train Loss: 0.0363, top-2 Acc 0.9983, top-3 Acc 0.9989, Acc: 0.9896
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 11s
# Estimated Time Remaining: 27m 13s
# Epoch 28/50
# ----------
# train Loss: 0.0400, top-2 Acc 0.9961, top-3 Acc 0.9974, Acc: 0.9885
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 25m 41s
# Epoch 29/50
# ----------
# train Loss: 0.0450, top-2 Acc 0.9961, top-3 Acc 0.9987, Acc: 0.9876
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 11s
# Estimated Time Remaining: 24m 41s
# Epoch 30/50
# ----------
# train Loss: 0.0441, top-2 Acc 0.9965, top-3 Acc 0.9980, Acc: 0.9861
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 23m 26s
# Epoch 31/50
# ----------
# train Loss: 0.0467, top-2 Acc 0.9959, top-3 Acc 0.9976, Acc: 0.9854
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 22m 7s
# Epoch 32/50
# ----------
# train Loss: 0.0396, top-2 Acc 0.9963, top-3 Acc 0.9985, Acc: 0.9881
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 11s
# Estimated Time Remaining: 21m 15s
# Epoch 33/50
# ----------
# train Loss: 0.0477, top-2 Acc 0.9944, top-3 Acc 0.9978, Acc: 0.9846
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 16s
# Estimated Time Remaining: 21m 39s
# Epoch 34/50
# ----------
# train Loss: 0.0490, top-2 Acc 0.9939, top-3 Acc 0.9983, Acc: 0.9835
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 18m 27s
# Epoch 35/50
# ----------
# train Loss: 0.0378, top-2 Acc 0.9972, top-3 Acc 0.9987, Acc: 0.9898
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 13s
# Estimated Time Remaining: 18m 11s
# Epoch 36/50
# ----------
# train Loss: 0.0406, top-2 Acc 0.9978, top-3 Acc 0.9987, Acc: 0.9885
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 12s
# Estimated Time Remaining: 16m 52s
# Epoch 37/50
# ----------
# train Loss: 0.0445, top-2 Acc 0.9946, top-3 Acc 0.9983, Acc: 0.9865
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 15m 3s
# Epoch 38/50
# ----------
# train Loss: 0.0423, top-2 Acc 0.9963, top-3 Acc 0.9985, Acc: 0.9872
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 11s
# Estimated Time Remaining: 14m 11s
# Epoch 39/50
# ----------
# train Loss: 0.0461, top-2 Acc 0.9957, top-3 Acc 0.9978, Acc: 0.9848
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 11s
# Estimated Time Remaining: 13m 5s
# Epoch 40/50
# ----------
# train Loss: 0.0424, top-2 Acc 0.9952, top-3 Acc 0.9985, Acc: 0.9883
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 11m 34s
# Epoch 41/50
# ----------
# train Loss: 0.0444, top-2 Acc 0.9954, top-3 Acc 0.9978, Acc: 0.9874
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 10m 33s
# Epoch 42/50
# ----------
# train Loss: 0.0437, top-2 Acc 0.9965, top-3 Acc 0.9976, Acc: 0.9859
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 11s
# Estimated Time Remaining: 9m 25s
# Epoch 43/50
# ----------
# train Loss: 0.0470, top-2 Acc 0.9952, top-3 Acc 0.9980, Acc: 0.9846
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 8m 10s
# Epoch 44/50
# ----------
# train Loss: 0.0534, top-2 Acc 0.9948, top-3 Acc 0.9980, Acc: 0.9831
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 15s
# Estimated Time Remaining: 7m 29s
# Epoch 45/50
# ----------
# train Loss: 0.0394, top-2 Acc 0.9959, top-3 Acc 0.9983, Acc: 0.9891
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 12s
# Estimated Time Remaining: 6m 0s
# Epoch 46/50
# ----------
# train Loss: 0.0422, top-2 Acc 0.9963, top-3 Acc 0.9987, Acc: 0.9874
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 4m 38s
# Epoch 47/50
# ----------
# train Loss: 0.0425, top-2 Acc 0.9950, top-3 Acc 0.9983, Acc: 0.9883
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 11s
# Estimated Time Remaining: 3m 34s
# Epoch 48/50
# ----------
# train Loss: 0.0467, top-2 Acc 0.9954, top-3 Acc 0.9976, Acc: 0.9854
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 2m 21s
# Epoch 49/50
# ----------
# train Loss: 0.0459, top-2 Acc 0.9950, top-3 Acc 0.9976, Acc: 0.9850
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 12s
# Estimated Time Remaining: 1m 12s
# Epoch 50/50
# ----------
# train Loss: 0.0416, top-2 Acc 0.9957, top-3 Acc 0.9972, Acc: 0.9876
# val Loss: 0.9797, top-2 Acc 0.8357, top-3 Acc 0.9096, Acc: 0.7677
# Time taken for epoch: 1m 10s
# Estimated Time Remaining: 0m 0s
# Training complete in 59m 16s
# Best val Acc: 0.767728, Best top-2 val Acc: 0.835697, Best overall top-2 Acc: 0.998262, Best top-3 val Acc: 0.909553, Best overall top-3 Acc: 0.999131

# %%
torch.save(model_ftViTL32.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_ViTL32_1_Aug_CB.pt')

# %%
def train_modelInceptionV3(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(299,299), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    if len(outputs) == 2:
                        _, preds = torch.max(outputs[0], 1)
                        _, topK0preds = torch.topk(outputs[0], k[0], 1)
                        _, topK1preds = torch.topk(outputs[0], k[1], 1)
                        loss = criterion(outputs[0], labels)
                    else:
                        _, preds = torch.max(outputs, 1)
                        _, topK0preds = torch.topk(outputs, k[0], 1)
                        _, topK1preds = torch.topk(outputs, k[1], 1)
                        loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftInceptionV3 = models.inception_v3(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrsInceptionV3 = model_ftInceptionV3.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsInceptionV3, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
# model_ftInceptionV3.fc = nn.Linear(num_ftrsInceptionV3, 11)
model_ftInceptionV3.fc = classifier_block

model_ftInceptionV3 = model_ftInceptionV3.to(device)

criterionInceptionV3 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftInceptionV3 = optim.SGD(model_ftInceptionV3.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerInceptionV3 = lr_scheduler.StepLR(optimizer_ftInceptionV3, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ftInceptionV3 = train_modelInceptionV3(model_ftInceptionV3, criterionInceptionV3, optimizer_ftInceptionV3, exp_lr_schedulerInceptionV3, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.6556, top-2 Acc 0.8849, top-3 Acc 0.9116, Acc: 0.8201
# val Loss: 0.8849, top-2 Acc 0.8400, top-3 Acc 0.8895, Acc: 0.7287
# Time taken for epoch: 0m 55s
# Estimated Time Remaining: 44m 35s
# Epoch 2/50
# ----------
# train Loss: 0.1138, top-2 Acc 0.9887, top-3 Acc 0.9930, Acc: 0.9737
# val Loss: 0.8962, top-2 Acc 0.8582, top-3 Acc 0.8978, Acc: 0.7931
# Time taken for epoch: 0m 52s
# Estimated Time Remaining: 41m 44s
# Epoch 3/50
# ----------
# train Loss: 0.0617, top-2 Acc 0.9954, top-3 Acc 0.9980, Acc: 0.9839
# val Loss: 0.6377, top-2 Acc 0.8991, top-3 Acc 0.9227, Acc: 0.8558
# Time taken for epoch: 0m 53s
# Estimated Time Remaining:
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 9m 4s
# Epoch 41/50
# ----------
# train Loss: 0.0110, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9991
# val Loss: 0.6372, top-2 Acc 0.9294, top-3 Acc 0.9500, Acc: 0.8734
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 8m 4s
# Epoch 42/50
# ----------
# train Loss: 0.0130, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9980
# val Loss: 0.7177, top-2 Acc 0.9173, top-3 Acc 0.9417, Acc: 0.8609
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 7m 16s
# Epoch 43/50
# ----------
# train Loss: 0.0105, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9991
# val Loss: 0.6868, top-2 Acc 0.9229, top-3 Acc 0.9486, Acc: 0.8635
# Time taken for epoch: 0m 55s
# Estimated Time Remaining: 6m 25s
# Epoch 44/50
# ----------
# train Loss: 0.0107, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9989
# val Loss: 0.7239, top-2 Acc 0.9096, top-3 Acc 0.9336, Acc: 0.8555
# Time taken for epoch: 0m 55s
# Estimated Time Remaining: 5m 31s
# Epoch 45/50
# ----------
# train Loss: 0.0189, top-2 Acc 0.9987, top-3 Acc 0.9991, Acc: 0.9954
# val Loss: 0.6670, top-2 Acc 0.9208, top-3 Acc 0.9411, Acc: 0.8673
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 4m 32s
# Epoch 46/50
# ----------
# train Loss: 0.0144, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9976
# val Loss: 0.6854, top-2 Acc 0.9251, top-3 Acc 0.9486, Acc: 0.8649
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 3m 37s
# Epoch 47/50
# ----------
# train Loss: 0.0145, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9967
# val Loss: 0.7274, top-2 Acc 0.9104, top-3 Acc 0.9374, Acc: 0.8592
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 2m 42s
# Epoch 48/50
# ----------
# train Loss: 0.0135, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9980
# val Loss: 0.6596, top-2 Acc 0.9245, top-3 Acc 0.9427, Acc: 0.8689
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 1m 47s
# Epoch 49/50
# ----------
# train Loss: 0.0120, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9980
# val Loss: 0.7200, top-2 Acc 0.9146, top-3 Acc 0.9414, Acc: 0.8600
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 0m 53s
# Epoch 50/50
# ----------
# train Loss: 0.0109, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9989
# val Loss: 0.6546, top-2 Acc 0.9243, top-3 Acc 0.9486, Acc: 0.8683
# Time taken for epoch: 0m 55s
# Estimated Time Remaining: 0m 0s
# Training complete in 44m 9s
# Best val Acc: 0.882794, Best top-2 val Acc: 0.936580, Best overall top-2 Acc: 1.000000, Best top-3 val Acc: 0.954241, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftInceptionV3.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_InceptionV3.pt')

# %%
model_ftInceptionV3 = train_modelInceptionV3(model_ftInceptionV3, criterionInceptionV3, optimizer_ftInceptionV3, exp_lr_schedulerInceptionV3, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 1.2840, top-2 Acc 0.7224, top-3 Acc 0.7860, Acc: 0.5977
# val Loss: 0.9206, top-2 Acc 0.8469, top-3 Acc 0.8975, Acc: 0.7177
# Time taken for epoch: 0m 42s
# Estimated Time Remaining: 34m 10s
# Epoch 2/50
# ----------
# train Loss: 0.4198, top-2 Acc 0.9448, top-3 Acc 0.9668, Acc: 0.8877
# val Loss: 1.0576, top-2 Acc 0.8424, top-3 Acc 0.8972, Acc: 0.7220
# Time taken for epoch: 0m 43s
# Estimated Time Remaining: 34m 15s
# Epoch 3/50
# ----------
# train Loss: 0.2889, top-2 Acc 0.9670, top-3 Acc 0.9770, Acc: 0.9268
# val Loss: 0.8404, top-2 Acc 0.9133, top-3 Acc 0.9435, Acc: 0.7862
# Time taken for epoch: 0m 42s
# Estimated Time Remaining:
# Time taken for epoch: 0m 41s
# Estimated Time Remaining: 6m 11s
# Epoch 42/50
# ----------
# train Loss: 0.0743, top-2 Acc 0.9939, top-3 Acc 0.9957, Acc: 0.9846
# val Loss: 0.4292, top-2 Acc 0.9427, top-3 Acc 0.9607, Acc: 0.8922
# Time taken for epoch: 0m 41s
# Estimated Time Remaining: 5m 31s
# Epoch 43/50
# ----------
# train Loss: 0.0760, top-2 Acc 0.9937, top-3 Acc 0.9954, Acc: 0.9857
# val Loss: 0.4347, top-2 Acc 0.9409, top-3 Acc 0.9580, Acc: 0.9010
# Time taken for epoch: 0m 42s
# Estimated Time Remaining: 4m 51s
# Epoch 44/50
# ----------
# train Loss: 0.0740, top-2 Acc 0.9933, top-3 Acc 0.9970, Acc: 0.9854
# val Loss: 0.5251, top-2 Acc 0.9334, top-3 Acc 0.9553, Acc: 0.8812
# Time taken for epoch: 0m 42s
# Estimated Time Remaining: 4m 10s
# Epoch 45/50
# ----------
# train Loss: 0.0744, top-2 Acc 0.9946, top-3 Acc 0.9967, Acc: 0.9867
# val Loss: 0.5548, top-2 Acc 0.9294, top-3 Acc 0.9534, Acc: 0.8721
# Time taken for epoch: 0m 42s
# Estimated Time Remaining: 3m 28s
# Epoch 46/50
# ----------
# train Loss: 0.0800, top-2 Acc 0.9928, top-3 Acc 0.9954, Acc: 0.9846
# val Loss: 0.4625, top-2 Acc 0.9433, top-3 Acc 0.9596, Acc: 0.8930
# Time taken for epoch: 0m 41s
# Estimated Time Remaining: 2m 45s
# Epoch 47/50
# ----------
# train Loss: 0.0848, top-2 Acc 0.9915, top-3 Acc 0.9941, Acc: 0.9822
# val Loss: 0.5427, top-2 Acc 0.9347, top-3 Acc 0.9566, Acc: 0.8841
# Time taken for epoch: 0m 42s
# Estimated Time Remaining: 2m 5s
# Epoch 48/50
# ----------
# train Loss: 0.0747, top-2 Acc 0.9954, top-3 Acc 0.9983, Acc: 0.9854
# val Loss: 0.4513, top-2 Acc 0.9467, top-3 Acc 0.9585, Acc: 0.8986
# Time taken for epoch: 0m 41s
# Estimated Time Remaining: 1m 23s
# Epoch 49/50
# ----------
# train Loss: 0.0753, top-2 Acc 0.9937, top-3 Acc 0.9954, Acc: 0.9835
# val Loss: 0.4669, top-2 Acc 0.9398, top-3 Acc 0.9591, Acc: 0.8935
# Time taken for epoch: 0m 41s
# Estimated Time Remaining: 0m 41s
# Epoch 50/50
# ----------
# train Loss: 0.0733, top-2 Acc 0.9948, top-3 Acc 0.9967, Acc: 0.9854
# val Loss: 0.4841, top-2 Acc 0.9377, top-3 Acc 0.9575, Acc: 0.8855
# Time taken for epoch: 0m 41s
# Estimated Time Remaining: 0m 0s
# Training complete in 34m 33s
# Best val Acc: 0.905272, Best top-2 val Acc: 0.945411, Best overall top-2 Acc: 0.996741, Best top-3 val Acc: 0.959593, Best overall top-3 Acc: 0.998262

# %%
torch.save(model_ftInceptionV3.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_InceptionV3_Aug_CB.pt')

# %%
model_ftInceptionV3 = train_modelInceptionV3(model_ftInceptionV3, criterionInceptionV3, optimizer_ftInceptionV3, exp_lr_schedulerInceptionV3, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 1.2659, top-2 Acc 0.7276, top-3 Acc 0.7910, Acc: 0.6059
# val Loss: 1.4077, top-2 Acc 0.6476, top-3 Acc 0.7324, Acc: 0.5397
# Time taken for epoch: 0m 44s
# Estimated Time Remaining: 36m 7s
# Epoch 2/50
# ----------
# train Loss: 0.5039, top-2 Acc 0.9220, top-3 Acc 0.9485, Acc: 0.8649
# val Loss: 1.1748, top-2 Acc 0.7412, top-3 Acc 0.7870, Acc: 0.6492
# Time taken for epoch: 0m 42s
# Estimated Time Remaining:
# Time taken for epoch: 0m 42s
# Estimated Time Remaining: 0m 42s
# Epoch 50/50
# ----------
# train Loss: 0.1708, top-2 Acc 0.9739, top-3 Acc 0.9811, Acc: 0.9546
# val Loss: 0.8864, top-2 Acc 0.8285, top-3 Acc 0.8665, Acc: 0.7653
# Time taken for epoch: 0m 42s
# Estimated Time Remaining: 0m 0s
# Training complete in 35m 23s
# Best val Acc: 0.784854, Best top-2 val Acc: 0.843725, Best overall top-2 Acc: 0.980230, Best top-3 val Acc: 0.877977, Best overall top-3 Acc: 0.985662

# %%
torch.save(model_ftInceptionV3.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_InceptionV3_Aug_CB_Dil.pt')

# %%
def train_modelMobileNetV3Large(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, topK0preds = torch.topk(outputs, k[0], 1)
                    _, topK1preds = torch.topk(outputs, k[1], 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftMobileNetV3Large = models.mobilenet_v3_large(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrsMobileNetV3Large = model_ftMobileNetV3Large.classifier[3].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsMobileNetV3Large, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
model_ftMobileNetV3Large.fc = classifier_block
# model_ftMobileNetV3Large.fc = nn.Linear(num_ftrsMobileNetV3Large, 11)

model_ftMobileNetV3Large = model_ftMobileNetV3Large.to(device)

criterionMobileNetV3Large = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftMobileNetV3Large = optim.SGD(model_ftMobileNetV3Large.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerMobileNetV3Large = lr_scheduler.StepLR(optimizer_ftMobileNetV3Large, step_size=5, gamma=0.1)

# %%
model_ftMobileNetV3Large = train_modelMobileNetV3Large(model_ftMobileNetV3Large, criterionMobileNetV3Large, optimizer_ftMobileNetV3Large, exp_lr_schedulerMobileNetV3Large, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0
# Time taken for epoch: 0m 47s
# Estimated Time Remaining: 7m 2s
# Epoch 42/50
# ----------
# train Loss: 0.0191, top-2 Acc 0.9980, top-3 Acc 0.9993, Acc: 0.9944
# val Loss: 0.7396, top-2 Acc 0.8959, top-3 Acc 0.9323, Acc: 0.8544
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 7m 15s
# Epoch 43/50
# ----------
# train Loss: 0.0193, top-2 Acc 0.9987, top-3 Acc 0.9998, Acc: 0.9941
# val Loss: 0.7173, top-2 Acc 0.8997, top-3 Acc 0.9336, Acc: 0.8552
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 6m 11s
# Epoch 44/50
# ----------
# train Loss: 0.0227, top-2 Acc 0.9972, top-3 Acc 0.9996, Acc: 0.9937
# val Loss: 0.7259, top-2 Acc 0.9005, top-3 Acc 0.9328, Acc: 0.8563
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 5m 16s
# Epoch 45/50
# ----------
# train Loss: 0.0216, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9950
# val Loss: 0.7139, top-2 Acc 0.9013, top-3 Acc 0.9347, Acc: 0.8579
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 4m 32s
# Epoch 46/50
# ----------
# train Loss: 0.0194, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9963
# val Loss: 0.7267, top-2 Acc 0.8994, top-3 Acc 0.9328, Acc: 0.8555
# Time taken for epoch: 0m 55s
# Estimated Time Remaining: 3m 39s
# Epoch 47/50
# ----------
# train Loss: 0.0183, top-2 Acc 0.9983, top-3 Acc 0.9993, Acc: 0.9948
# val Loss: 0.7304, top-2 Acc 0.8978, top-3 Acc 0.9331, Acc: 0.8563
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 2m 40s
# Epoch 48/50
# ----------
# train Loss: 0.0214, top-2 Acc 0.9989, top-3 Acc 0.9991, Acc: 0.9944
# val Loss: 0.7193, top-2 Acc 0.8986, top-3 Acc 0.9328, Acc: 0.8568
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 1m 46s
# Epoch 49/50
# ----------
# train Loss: 0.0249, top-2 Acc 0.9980, top-3 Acc 0.9991, Acc: 0.9928
# val Loss: 0.7211, top-2 Acc 0.8994, top-3 Acc 0.9323, Acc: 0.8566
# Time taken for epoch: 0m 53s
# Estimated Time Remaining: 0m 53s
# Epoch 50/50
# ----------
# train Loss: 0.0231, top-2 Acc 0.9980, top-3 Acc 0.9991, Acc: 0.9939
# val Loss: 0.7198, top-2 Acc 0.8997, top-3 Acc 0.9323, Acc: 0.8558
# Time taken for epoch: 0m 54s
# Estimated Time Remaining: 0m 0s
# Training complete in 34m 28s
# Best val Acc: 0.861119, Best top-2 val Acc: 0.902596, Best overall top-2 Acc: 0.999566, Best top-3 val Acc: 0.935242, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftMobileNetV3Large.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_MobileNetV3Large.pt')

# %%
model_ftMobileNetV3Large = train_modelMobileNetV3Large(model_ftMobileNetV3Large, criterionMobileNetV3Large, optimizer_ftMobileNetV3Large, exp_lr_schedulerMobileNetV3Large, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.8587, top-2 Acc 0.8675, top-3 Acc 0.8985, Acc: 0.8017
# val Loss: 1.0592, top-2 Acc 0.8159, top-3 Acc 0.8903, Acc: 0.6784
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 30m 16s
# Epoch 2/50
# ----------
# train Loss: 0.1501, top-2 Acc 0.9831, top-3 Acc 0.9904, Acc: 0.9546
# val Loss: 1.0004, top-2 Acc 0.8397, top-3 Acc 0.9130, Acc: 0.7511
# Time taken for epoch: 0m 37s
# Estimated Time Remaining:
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 5m 30s
# Epoch 42/50
# ----------
# train Loss: 0.0278, top-2 Acc 0.9974, top-3 Acc 0.9989, Acc: 0.9920
# val Loss: 0.6428, top-2 Acc 0.9096, top-3 Acc 0.9572, Acc: 0.8576
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 4m 54s
# Epoch 43/50
# ----------
# train Loss: 0.0315, top-2 Acc 0.9967, top-3 Acc 0.9987, Acc: 0.9904
# val Loss: 0.6601, top-2 Acc 0.9079, top-3 Acc 0.9596, Acc: 0.8568
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 4m 17s
# Epoch 44/50
# ----------
# train Loss: 0.0304, top-2 Acc 0.9970, top-3 Acc 0.9989, Acc: 0.9900
# val Loss: 0.6320, top-2 Acc 0.9125, top-3 Acc 0.9585, Acc: 0.8595
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 3m 40s
# Epoch 45/50
# ----------
# train Loss: 0.0344, top-2 Acc 0.9972, top-3 Acc 0.9991, Acc: 0.9894
# val Loss: 0.6449, top-2 Acc 0.9082, top-3 Acc 0.9572, Acc: 0.8579
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 3m 5s
# Epoch 46/50
# ----------
# train Loss: 0.0338, top-2 Acc 0.9963, top-3 Acc 0.9976, Acc: 0.9911
# val Loss: 0.6327, top-2 Acc 0.9125, top-3 Acc 0.9593, Acc: 0.8584
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 2m 27s
# Epoch 47/50
# ----------
# train Loss: 0.0288, top-2 Acc 0.9978, top-3 Acc 0.9987, Acc: 0.9915
# val Loss: 0.6477, top-2 Acc 0.9090, top-3 Acc 0.9575, Acc: 0.8576
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 1m 50s
# Epoch 48/50
# ----------
# train Loss: 0.0305, top-2 Acc 0.9974, top-3 Acc 0.9993, Acc: 0.9902
# val Loss: 0.6349, top-2 Acc 0.9093, top-3 Acc 0.9591, Acc: 0.8592
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 1m 13s
# Epoch 49/50
# ----------
# train Loss: 0.0321, top-2 Acc 0.9974, top-3 Acc 0.9983, Acc: 0.9900
# val Loss: 0.6585, top-2 Acc 0.9061, top-3 Acc 0.9577, Acc: 0.8552
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 0m 37s
# Epoch 50/50
# ----------
# train Loss: 0.0304, top-2 Acc 0.9978, top-3 Acc 0.9985, Acc: 0.9917
# val Loss: 0.6572, top-2 Acc 0.9053, top-3 Acc 0.9566, Acc: 0.8576
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 0m 0s
# Training complete in 30m 42s
# Best val Acc: 0.863527, Best top-2 val Acc: 0.914905, Best overall top-2 Acc: 0.998479, Best top-3 val Acc: 0.960931, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftMobileNetV3Large.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_MobileNetV3Large_Aug_CB.pt')

# %%
def train_modelRegNetX32GF(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, topK0preds = torch.topk(outputs, k[0], 1)
                    _, topK1preds = torch.topk(outputs, k[1], 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftRegNetX32GF = models.regnet_x_32gf(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrsRegNetX32GF = model_ftRegNetX32GF.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsRegNetX32GF, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
# model_ftRegNetX32GF.fc = nn.Linear(num_ftrsRegNetX32GF, 11)
model_ftRegNetX32GF.fc = classifier_block

model_ftRegNetX32GF = model_ftRegNetX32GF.to(device)

criterionRegNetX32GF = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftRegNetX32GF = optim.SGD(model_ftRegNetX32GF.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerRegNetX32GF = lr_scheduler.StepLR(optimizer_ftRegNetX32GF, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=RegNet_X_32GF_Weights.IMAGENET1K_V1`. You can also use `weights=RegNet_X_32GF_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ftRegNetX32GF = train_modelRegNetX32GF(model_ftRegNetX32GF, criterionRegNetX32GF, optimizer_ftRegNetX32GF, exp_lr_schedulerRegNetX32GF, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.8045, top-2 Acc 0.8603, top-3 Acc 0.8957, Acc: 0.7797
# val Loss: 0.7781, top-2 Acc 0.8804, top-3 Acc 0.9294, Acc: 0.7477
# Time taken for epoch: 2m 1s
# Estimated Time Remaining: 98m 56s
# Epoch 2/50
# ----------
# train Loss: 0.1861, top-2 Acc 0.9835, top-3 Acc 0.9909, Acc: 0.9589
# val Loss: 0.8767, top-2 Acc 0.8475, top-3 Acc 0.8857, Acc: 0.7725
# Time taken for epoch: 2m 6s
# Estimated Time Remaining: 100m 60s
# Epoch 3/50
# ----------
# train Loss: 0.1338, top-2 Acc 0.9883, top-3 Acc 0.9937, Acc: 0.9681
# val Loss: 0.7051, top-2 Acc 0.8793, top-3 Acc 0.9106, Acc: 0.8172
# Time taken for epoch: 2m 10s
# Estimated Time Remaining: 101m 38s
# Epoch 4/50
# ----------
# train Loss: 0.0978, top-2 Acc 0.9922, top-3 Acc 0.9954, Acc: 0.9794
# val Loss: 0.7001, top-2 Acc 0.8705, top-3 Acc 0.9093, Acc: 0.8242
# Time taken for epoch: 2m 14s
# Estimated Time Remaining: 26m 49s
# Epoch 39/50
# ----------
# train Loss: 0.0378, top-2 Acc 0.9978, top-3 Acc 0.9989, Acc: 0.9944
# val Loss: 0.6017, top-2 Acc 0.9114, top-3 Acc 0.9363, Acc: 0.8713
# Time taken for epoch: 2m 15s
# Estimated Time Remaining: 24m 41s
# Epoch 40/50
# ----------
# train Loss: 0.0378, top-2 Acc 0.9972, top-3 Acc 0.9983, Acc: 0.9928
# val Loss: 0.5721, top-2 Acc 0.9109, top-3 Acc 0.9382, Acc: 0.8734
# Time taken for epoch: 2m 14s
# Estimated Time Remaining: 22m 23s
# Epoch 41/50
# ----------
# train Loss: 0.0355, top-2 Acc 0.9983, top-3 Acc 0.9989, Acc: 0.9946
# val Loss: 0.6463, top-2 Acc 0.9112, top-3 Acc 0.9417, Acc: 0.8630
# Time taken for epoch: 2m 15s
# Estimated Time Remaining: 20m 11s
# Epoch 42/50
# ----------
# train Loss: 0.0352, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9939
# val Loss: 0.6197, top-2 Acc 0.9031, top-3 Acc 0.9334, Acc: 0.8657
# Time taken for epoch: 2m 15s
# Estimated Time Remaining: 17m 58s
# Epoch 43/50
# ----------
# train Loss: 0.0314, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9944
# val Loss: 0.6235, top-2 Acc 0.9079, top-3 Acc 0.9360, Acc: 0.8627
# Time taken for epoch: 2m 14s
# Estimated Time Remaining: 15m 41s
# Epoch 44/50
# ----------
# train Loss: 0.0397, top-2 Acc 0.9978, top-3 Acc 0.9985, Acc: 0.9948
# val Loss: 0.6128, top-2 Acc 0.9005, top-3 Acc 0.9358, Acc: 0.8708
# Time taken for epoch: 2m 15s
# Estimated Time Remaining: 13m 29s
# Epoch 45/50
# ----------
# train Loss: 0.0338, top-2 Acc 0.9987, top-3 Acc 0.9991, Acc: 0.9952
# val Loss: 0.6679, top-2 Acc 0.9005, top-3 Acc 0.9342, Acc: 0.8574
# Time taken for epoch: 2m 15s
# Estimated Time Remaining: 11m 15s
# Epoch 46/50
# ----------
# train Loss: 0.0436, top-2 Acc 0.9974, top-3 Acc 0.9987, Acc: 0.9913
# val Loss: 0.6375, top-2 Acc 0.9037, top-3 Acc 0.9320, Acc: 0.8691
# Time taken for epoch: 2m 15s
# Estimated Time Remaining: 8m 58s
# Epoch 47/50
# ----------
# train Loss: 0.0374, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9946
# val Loss: 0.6122, top-2 Acc 0.9101, top-3 Acc 0.9401, Acc: 0.8587
# Time taken for epoch: 2m 15s
# Estimated Time Remaining: 6m 45s
# Epoch 48/50
# ----------
# train Loss: 0.0377, top-2 Acc 0.9983, top-3 Acc 0.9983, Acc: 0.9950
# val Loss: 0.6006, top-2 Acc 0.9195, top-3 Acc 0.9419, Acc: 0.8718
# Time taken for epoch: 2m 15s
# Estimated Time Remaining: 4m 30s
# Epoch 49/50
# ----------
# train Loss: 0.0410, top-2 Acc 0.9972, top-3 Acc 0.9980, Acc: 0.9937
# val Loss: 0.6790, top-2 Acc 0.9039, top-3 Acc 0.9377, Acc: 0.8590
# Time taken for epoch: 2m 15s
# Estimated Time Remaining: 2m 15s
# Epoch 50/50
# ----------
# train Loss: 0.0380, top-2 Acc 0.9985, top-3 Acc 0.9996, Acc: 0.9944
# val Loss: 0.5635, top-2 Acc 0.9195, top-3 Acc 0.9425, Acc: 0.8705
# Time taken for epoch: 2m 15s
# Estimated Time Remaining: 0m 0s
# Training complete in 111m 25s
# Best val Acc: 0.876907, Best top-2 val Acc: 0.919454, Best overall top-2 Acc: 0.999348, Best top-3 val Acc: 0.943002, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftRegNetX32GF.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_RegNetX32GF.pt')

# %%
model_ftRegNetX32GF = train_modelRegNetX32GF(model_ftRegNetX32GF, criterionRegNetX32GF, optimizer_ftRegNetX32GF, exp_lr_schedulerRegNetX32GF, num_epochs=50)

# %%
torch.save(model_ftRegNetX32GF.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_RegNetX32GF_Aug_CB.pt')

# %%
def train_modelConvNextLarge(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, topK0preds = torch.topk(outputs, k[0], 1)
                    _, topK1preds = torch.topk(outputs, k[1], 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftConvNextLarge = models.convnext_large(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrsConvNextLarge = model_ftConvNextLarge.classifier[2].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsConvNextLarge, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
# model_ftConvNextLarge.fc = nn.Linear(num_ftrsConvNextLarge, 11)
model_ftConvNextLarge.fc = classifier_block

model_ftConvNextLarge = model_ftConvNextLarge.to(device)

criterionConvNextLarge = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftConvNextLarge = optim.SGD(model_ftConvNextLarge.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerConvNextLarge = lr_scheduler.StepLR(optimizer_ftConvNextLarge, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ConvNeXt_Large_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Large_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ftConvNextLarge = train_modelConvNextLarge(model_ftConvNextLarge, criterionConvNextLarge, optimizer_ftConvNextLarge, exp_lr_schedulerConvNextLarge, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 2.3352, top-2 Acc 0.3541, top-3 Acc 0.4454, Acc: 0.2307
# val Loss: 2.0799, top-2 Acc 0.4956, top-3 Acc 0.5617, Acc: 0.3776
# Time taken for epoch: 3m 42s
# Estimated Time Remaining: 181m 6s
# Epoch 2/50
# ----------
# train Loss: 0.3934, top-2 Acc 0.9457, top-3 Acc 0.9665, Acc: 0.8883
# val Loss: 1.1686, top-2 Acc 0.8113, top-3 Acc 0.8713, Acc: 0.6615
# Time taken for epoch: 3m 43s
# Estimated Time Remaining: 178m 2s
# Epoch 3/50
# ----------
# train Loss: 0.1083, top-2 Acc 0.9883, top-3 Acc 0.9941, Acc: 0.9702
# val Loss: 1.0423, top-2 Acc 0.8571, top-3 Acc 0.9189, Acc: 0.7474
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 176m 12s
# Epoch 4/50
# ----------
# train Loss: 0.0557, top-2 Acc 0.9957, top-3 Acc 0.9983, Acc: 0.9844
# val Loss: 1.0434, top-2 Acc 0.8646, top-3 Acc 0.9023, Acc: 0.7835
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 172m 27s
# Epoch 5/50
# ----------
# train Loss: 0.0396, top-2 Acc 0.9970, top-3 Acc 0.9989, Acc: 0.9887
# val Loss: 0.7890, top-2 Acc 0.8825, top-3 Acc 0.9208, Acc: 0.8274
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 168m 42s
# Epoch 6/50
# ----------
# train Loss: 0.0239, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9937
# val Loss: 0.8489, top-2 Acc 0.8812, top-3 Acc 0.9211, Acc: 0.8336
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 165m 0s
# Epoch 7/50
# ----------
# train Loss: 0.0187, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9965
# val Loss: 0.9103, top-2 Acc 0.8761, top-3 Acc 0.9154, Acc: 0.8261
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 161m 19s
# Epoch 8/50
# ----------
# train Loss: 0.0199, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9963
# val Loss: 0.9059, top-2 Acc 0.8734, top-3 Acc 0.9168, Acc: 0.8226
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 157m 36s
# Epoch 9/50
# ----------
# train Loss: 0.0187, top-2 Acc 0.9989, top-3 Acc 0.9989, Acc: 0.9961
# val Loss: 0.9427, top-2 Acc 0.8753, top-3 Acc 0.9157, Acc: 0.8274
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 153m 45s
# Epoch 10/50
# ----------
# train Loss: 0.0180, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9961
# val Loss: 0.9395, top-2 Acc 0.8766, top-3 Acc 0.9168, Acc: 0.8255
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 150m 5s
# Epoch 11/50
# ----------
# train Loss: 0.0162, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9965
# val Loss: 0.9316, top-2 Acc 0.8766, top-3 Acc 0.9170, Acc: 0.8261
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 146m 16s
# Epoch 12/50
# ----------
# train Loss: 0.0147, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9976
# val Loss: 0.9393, top-2 Acc 0.8750, top-3 Acc 0.9165, Acc: 0.8250
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 142m 38s
# Epoch 13/50
# ----------
# train Loss: 0.0171, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9963
# val Loss: 0.9342, top-2 Acc 0.8753, top-3 Acc 0.9170, Acc: 0.8250
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 138m 43s
# Epoch 14/50
# ----------
# train Loss: 0.0157, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9959
# val Loss: 0.9280, top-2 Acc 0.8756, top-3 Acc 0.9176, Acc: 0.8261
# Time taken for epoch: 3m 46s
# Estimated Time Remaining: 135m 26s
# Epoch 15/50
# ----------
# train Loss: 0.0156, top-2 Acc 0.9991, top-3 Acc 1.0000, Acc: 0.9961
# val Loss: 0.9188, top-2 Acc 0.8753, top-3 Acc 0.9178, Acc: 0.8271
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 134m 3s
# Epoch 16/50
# ----------
# train Loss: 0.0141, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9978
# val Loss: 0.9184, top-2 Acc 0.8753, top-3 Acc 0.9178, Acc: 0.8274
# Time taken for epoch: 3m 49s
# Estimated Time Remaining: 130m 2s
# Epoch 17/50
# ----------
# train Loss: 0.0168, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9965
# val Loss: 0.9182, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 126m 18s
# Epoch 18/50
# ----------
# train Loss: 0.0184, top-2 Acc 0.9983, top-3 Acc 0.9996, Acc: 0.9950
# val Loss: 0.9181, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 122m 32s
# Epoch 19/50
# ----------
# train Loss: 0.0147, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9976
# val Loss: 0.9182, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8279
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 118m 44s
# Epoch 20/50
# ----------
# train Loss: 0.0171, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9954
# val Loss: 0.9176, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 115m 4s
# Epoch 21/50
# ----------
# train Loss: 0.0138, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9974
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9184, Acc: 0.8277
# Time taken for epoch: 4m 4s
# Estimated Time Remaining: 118m 9s
# Epoch 22/50
# ----------
# train Loss: 0.0150, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9967
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9184, Acc: 0.8277
# Time taken for epoch: 4m 7s
# Estimated Time Remaining: 115m 14s
# Epoch 23/50
# ----------
# train Loss: 0.0172, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9963
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 4m 2s
# Estimated Time Remaining: 108m 56s
# Epoch 24/50
# ----------
# train Loss: 0.0175, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9954
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 99m 32s
# Epoch 25/50
# ----------
# train Loss: 0.0159, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9961
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 95m 45s
# Epoch 26/50
# ----------
# train Loss: 0.0182, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9957
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 49s
# Estimated Time Remaining: 91m 48s
# Epoch 27/50
# ----------
# train Loss: 0.0145, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9972
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 88m 9s
# Epoch 28/50
# ----------
# train Loss: 0.0157, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9974
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 84m 18s
# Epoch 29/50
# ----------
# train Loss: 0.0165, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9965
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 80m 20s
# Epoch 30/50
# ----------
# train Loss: 0.0153, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9970
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 76m 35s
# Epoch 31/50
# ----------
# train Loss: 0.0121, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9980
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 72m 48s
# Epoch 32/50
# ----------
# train Loss: 0.0189, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9950
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 48s
# Estimated Time Remaining: 68m 26s
# Epoch 33/50
# ----------
# train Loss: 0.0177, top-2 Acc 0.9993, top-3 Acc 1.0000, Acc: 0.9948
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 45s
# Estimated Time Remaining: 63m 47s
# Epoch 34/50
# ----------
# train Loss: 0.0165, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9961
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 46s
# Estimated Time Remaining: 60m 11s
# Epoch 35/50
# ----------
# train Loss: 0.0168, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9967
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 46s
# Estimated Time Remaining: 56m 26s
# Epoch 36/50
# ----------
# train Loss: 0.0150, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9972
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 47s
# Estimated Time Remaining: 52m 54s
# Epoch 37/50
# ----------
# train Loss: 0.0166, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9963
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 46s
# Estimated Time Remaining: 48m 57s
# Epoch 38/50
# ----------
# train Loss: 0.0154, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9970
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 47s
# Estimated Time Remaining: 45m 23s
# Epoch 39/50
# ----------
# train Loss: 0.0152, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9967
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 46s
# Estimated Time Remaining: 41m 27s
# Epoch 40/50
# ----------
# train Loss: 0.0144, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9970
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 49s
# Estimated Time Remaining: 38m 9s
# Epoch 41/50
# ----------
# train Loss: 0.0161, top-2 Acc 0.9991, top-3 Acc 1.0000, Acc: 0.9963
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 34m 33s
# Epoch 42/50
# ----------
# train Loss: 0.0153, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9974
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 30m 39s
# Epoch 43/50
# ----------
# train Loss: 0.0143, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9978
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 50s
# Estimated Time Remaining: 26m 52s
# Epoch 44/50
# ----------
# train Loss: 0.0143, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9970
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 48s
# Estimated Time Remaining: 22m 50s
# Epoch 45/50
# ----------
# train Loss: 0.0171, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9970
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 42s
# Estimated Time Remaining: 18m 30s
# Epoch 46/50
# ----------
# train Loss: 0.0150, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9976
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 5m 14s
# Estimated Time Remaining: 20m 55s
# Epoch 47/50
# ----------
# train Loss: 0.0167, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9963
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 5m 37s
# Estimated Time Remaining: 16m 52s
# Epoch 48/50
# ----------
# train Loss: 0.0169, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9954
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 5m 5s
# Estimated Time Remaining: 10m 10s
# Epoch 49/50
# ----------
# train Loss: 0.0170, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9967
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 49s
# Estimated Time Remaining: 3m 49s
# Epoch 50/50
# ----------
# train Loss: 0.0143, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9970
# val Loss: 0.9177, top-2 Acc 0.8753, top-3 Acc 0.9181, Acc: 0.8277
# Time taken for epoch: 3m 49s
# Estimated Time Remaining: 0m 0s
# Training complete in 194m 49s
# Best val Acc: 0.833556, Best top-2 val Acc: 0.881188, Best overall top-2 Acc: 0.999783, Best top-3 val Acc: 0.921060, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftConvNextLarge.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_ConvNextLarge.pt')

# %%
model_ftConvNextLarge = train_modelConvNextLarge(model_ftConvNextLarge, criterionConvNextLarge, optimizer_ftConvNextLarge, exp_lr_schedulerConvNextLarge, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 2.5138, top-2 Acc 0.2674, top-3 Acc 0.3717, Acc: 0.1514
# val Loss: 2.4606, top-2 Acc 0.3754, top-3 Acc 0.4571, Acc: 0.2066
# Time taken for epoch: 4m 4s
# Estimated Time Remaining: 198m 56s
# Epoch 2/50
# ----------
# train Loss: 1.1695, top-2 Acc 0.7619, top-3 Acc 0.8238, Acc: 0.6274
# val Loss: 1.5841, top-2 Acc 0.6420, top-3 Acc 0.7332, Acc: 0.5213
# Time taken for epoch: 3m 54s
# Estimated Time Remaining: 186m 59s
# Epoch 3/50
# ----------
# train Loss: 0.2753, top-2 Acc 0.9635, top-3 Acc 0.9781, Acc: 0.9205
# val Loss: 1.1006, top-2 Acc 0.7982, top-3 Acc 0.8539, Acc: 0.6848
# Time taken for epoch: 4m 7s
# Estimated Time Remaining: 193m 18s
# Epoch 4/50
# ----------
# train Loss: 0.1241, top-2 Acc 0.9852, top-3 Acc 0.9909, Acc: 0.9648
# val Loss: 0.9409, top-2 Acc 0.8726, top-3 Acc 0.9162, Acc: 0.7704
# Time taken for epoch: 3m 56s
# Estimated Time Remaining: 181m 13s
# Epoch 5/50
# ----------
# train Loss: 0.0752, top-2 Acc 0.9924, top-3 Acc 0.9959, Acc: 0.9794
# val Loss: 0.8345, top-2 Acc 0.8903, top-3 Acc 0.9411, Acc: 0.7774
# Time taken for epoch: 4m 2s
# Estimated Time Remaining: 181m 32s
# Epoch 6/50
# ----------
# train Loss: 0.0479, top-2 Acc 0.9965, top-3 Acc 0.9980, Acc: 0.9885
# val Loss: 0.7076, top-2 Acc 0.8895, top-3 Acc 0.9425, Acc: 0.8253
# Time taken for epoch: 3m 57s
# Estimated Time Remaining: 173m 35s
# Epoch 7/50
# ----------
# train Loss: 0.0358, top-2 Acc 0.9965, top-3 Acc 0.9980, Acc: 0.9920
# val Loss: 0.7103, top-2 Acc 0.8903, top-3 Acc 0.9417, Acc: 0.8269
# Time taken for epoch: 3m 55s
# Estimated Time Remaining: 168m 41s
# Epoch 8/50
# ----------
# train Loss: 0.0329, top-2 Acc 0.9980, top-3 Acc 0.9989, Acc: 0.9920
# val Loss: 0.6815, top-2 Acc 0.8962, top-3 Acc 0.9451, Acc: 0.8317
# Time taken for epoch: 4m 5s
# Estimated Time Remaining: 171m 11s
# Epoch 9/50
# ----------
# train Loss: 0.0312, top-2 Acc 0.9976, top-3 Acc 0.9991, Acc: 0.9930
# val Loss: 0.6872, top-2 Acc 0.8994, top-3 Acc 0.9422, Acc: 0.8394
# Time taken for epoch: 3m 54s
# Estimated Time Remaining: 159m 53s
# Epoch 10/50
# ----------
# train Loss: 0.0299, top-2 Acc 0.9985, top-3 Acc 0.9996, Acc: 0.9917
# val Loss: 0.7269, top-2 Acc 0.8884, top-3 Acc 0.9446, Acc: 0.8336
# Time taken for epoch: 4m 4s
# Estimated Time Remaining: 162m 32s
# Epoch 11/50
# ----------
# train Loss: 0.0284, top-2 Acc 0.9985, top-3 Acc 0.9996, Acc: 0.9937
# val Loss: 0.7200, top-2 Acc 0.8900, top-3 Acc 0.9459, Acc: 0.8354
# Time taken for epoch: 4m 2s
# Estimated Time Remaining: 157m 36s
# Epoch 12/50
# ----------
# train Loss: 0.0267, top-2 Acc 0.9976, top-3 Acc 0.9989, Acc: 0.9939
# val Loss: 0.7177, top-2 Acc 0.8903, top-3 Acc 0.9462, Acc: 0.8354
# Time taken for epoch: 3m 54s
# Estimated Time Remaining: 148m 11s
# Epoch 13/50
# ----------
# train Loss: 0.0265, top-2 Acc 0.9980, top-3 Acc 0.9989, Acc: 0.9948
# val Loss: 0.7145, top-2 Acc 0.8914, top-3 Acc 0.9457, Acc: 0.8362
# Time taken for epoch: 4m 3s
# Estimated Time Remaining: 149m 45s
# Epoch 14/50
# ----------
# train Loss: 0.0267, top-2 Acc 0.9980, top-3 Acc 0.9993, Acc: 0.9928
# val Loss: 0.7089, top-2 Acc 0.8930, top-3 Acc 0.9457, Acc: 0.8365
# Time taken for epoch: 3m 54s
# Estimated Time Remaining: 140m 38s
# Epoch 15/50
# ----------
# train Loss: 0.0283, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9930
# val Loss: 0.7025, top-2 Acc 0.8946, top-3 Acc 0.9449, Acc: 0.8386
# Time taken for epoch: 4m 5s
# Estimated Time Remaining: 142m 56s
# Epoch 16/50
# ----------
# train Loss: 0.0277, top-2 Acc 0.9983, top-3 Acc 0.9993, Acc: 0.9926
# val Loss: 0.7023, top-2 Acc 0.8948, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 54s
# Estimated Time Remaining: 132m 22s
# Epoch 17/50
# ----------
# train Loss: 0.0282, top-2 Acc 0.9980, top-3 Acc 0.9989, Acc: 0.9917
# val Loss: 0.7021, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 5s
# Estimated Time Remaining: 134m 30s
# Epoch 18/50
# ----------
# train Loss: 0.0252, top-2 Acc 0.9978, top-3 Acc 0.9987, Acc: 0.9928
# val Loss: 0.7021, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 0s
# Estimated Time Remaining: 128m 14s
# Epoch 19/50
# ----------
# train Loss: 0.0320, top-2 Acc 0.9961, top-3 Acc 0.9987, Acc: 0.9930
# val Loss: 0.7016, top-2 Acc 0.8951, top-3 Acc 0.9454, Acc: 0.8392
# Time taken for epoch: 3m 56s
# Estimated Time Remaining: 122m 3s
# Epoch 20/50
# ----------
# train Loss: 0.0278, top-2 Acc 0.9987, top-3 Acc 0.9996, Acc: 0.9933
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9454, Acc: 0.8392
# Time taken for epoch: 3m 56s
# Estimated Time Remaining: 117m 45s
# Epoch 21/50
# ----------
# train Loss: 0.0234, top-2 Acc 0.9983, top-3 Acc 1.0000, Acc: 0.9937
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 4s
# Estimated Time Remaining: 117m 60s
# Epoch 22/50
# ----------
# train Loss: 0.0240, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9952
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9449, Acc: 0.8392
# Time taken for epoch: 3m 54s
# Estimated Time Remaining: 109m 26s
# Epoch 23/50
# ----------
# train Loss: 0.0268, top-2 Acc 0.9989, top-3 Acc 0.9991, Acc: 0.9933
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9449, Acc: 0.8392
# Time taken for epoch: 4m 4s
# Estimated Time Remaining: 109m 42s
# Epoch 24/50
# ----------
# train Loss: 0.0271, top-2 Acc 0.9983, top-3 Acc 0.9996, Acc: 0.9930
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 60s
# Estimated Time Remaining: 103m 55s
# Epoch 25/50
# ----------
# train Loss: 0.0262, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9928
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 56s
# Estimated Time Remaining: 98m 28s
# Epoch 26/50
# ----------
# train Loss: 0.0275, top-2 Acc 0.9985, top-3 Acc 0.9993, Acc: 0.9930
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 56s
# Estimated Time Remaining: 94m 29s
# Epoch 27/50
# ----------
# train Loss: 0.0288, top-2 Acc 0.9978, top-3 Acc 0.9996, Acc: 0.9930
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 4s
# Estimated Time Remaining: 93m 30s
# Epoch 28/50
# ----------
# train Loss: 0.0283, top-2 Acc 0.9980, top-3 Acc 0.9996, Acc: 0.9926
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 1s
# Estimated Time Remaining: 88m 13s
# Epoch 29/50
# ----------
# train Loss: 0.0287, top-2 Acc 0.9985, top-3 Acc 0.9993, Acc: 0.9935
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 54s
# Estimated Time Remaining: 81m 46s
# Epoch 30/50
# ----------
# train Loss: 0.0285, top-2 Acc 0.9978, top-3 Acc 0.9989, Acc: 0.9937
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 3s
# Estimated Time Remaining: 80m 58s
# Epoch 31/50
# ----------
# train Loss: 0.0294, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9920
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 1s
# Estimated Time Remaining: 76m 28s
# Epoch 32/50
# ----------
# train Loss: 0.0271, top-2 Acc 0.9987, top-3 Acc 0.9998, Acc: 0.9933
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 1s
# Estimated Time Remaining: 72m 13s
# Epoch 33/50
# ----------
# train Loss: 0.0250, top-2 Acc 0.9987, top-3 Acc 1.0000, Acc: 0.9950
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 56s
# Estimated Time Remaining: 66m 53s
# Epoch 34/50
# ----------
# train Loss: 0.0294, top-2 Acc 0.9983, top-3 Acc 0.9993, Acc: 0.9937
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 2s
# Estimated Time Remaining: 64m 33s
# Epoch 35/50
# ----------
# train Loss: 0.0268, top-2 Acc 0.9987, top-3 Acc 0.9998, Acc: 0.9930
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 55s
# Estimated Time Remaining: 58m 49s
# Epoch 36/50
# ----------
# train Loss: 0.0273, top-2 Acc 0.9983, top-3 Acc 0.9993, Acc: 0.9922
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 55s
# Estimated Time Remaining: 54m 52s
# Epoch 37/50
# ----------
# train Loss: 0.0263, top-2 Acc 0.9978, top-3 Acc 0.9993, Acc: 0.9935
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 4s
# Estimated Time Remaining: 52m 47s
# Epoch 38/50
# ----------
# train Loss: 0.0268, top-2 Acc 0.9978, top-3 Acc 0.9991, Acc: 0.9928
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 54s
# Estimated Time Remaining: 46m 47s
# Epoch 39/50
# ----------
# train Loss: 0.0251, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9941
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 1s
# Estimated Time Remaining: 44m 16s
# Epoch 40/50
# ----------
# train Loss: 0.0252, top-2 Acc 0.9991, top-3 Acc 1.0000, Acc: 0.9939
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 0s
# Estimated Time Remaining: 40m 2s
# Epoch 41/50
# ----------
# train Loss: 0.0305, top-2 Acc 0.9963, top-3 Acc 0.9987, Acc: 0.9917
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 0s
# Estimated Time Remaining: 36m 0s
# Epoch 42/50
# ----------
# train Loss: 0.0331, top-2 Acc 0.9972, top-3 Acc 0.9983, Acc: 0.9924
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 55s
# Estimated Time Remaining: 31m 18s
# Epoch 43/50
# ----------
# train Loss: 0.0288, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9924
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 3s
# Estimated Time Remaining: 28m 23s
# Epoch 44/50
# ----------
# train Loss: 0.0269, top-2 Acc 0.9985, top-3 Acc 0.9993, Acc: 0.9933
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 0s
# Estimated Time Remaining: 24m 0s
# Epoch 45/50
# ----------
# train Loss: 0.0280, top-2 Acc 0.9985, top-3 Acc 0.9996, Acc: 0.9939
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 56s
# Estimated Time Remaining: 19m 38s
# Epoch 46/50
# ----------
# train Loss: 0.0279, top-2 Acc 0.9974, top-3 Acc 0.9987, Acc: 0.9933
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 56s
# Estimated Time Remaining: 15m 44s
# Epoch 47/50
# ----------
# train Loss: 0.0301, top-2 Acc 0.9978, top-3 Acc 0.9991, Acc: 0.9926
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 56s
# Estimated Time Remaining: 11m 48s
# Epoch 48/50
# ----------
# train Loss: 0.0274, top-2 Acc 0.9980, top-3 Acc 0.9993, Acc: 0.9937
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 4m 0s
# Estimated Time Remaining: 8m 1s
# Epoch 49/50
# ----------
# train Loss: 0.0317, top-2 Acc 0.9972, top-3 Acc 0.9996, Acc: 0.9920
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 59s
# Estimated Time Remaining: 3m 59s
# Epoch 50/50
# ----------
# train Loss: 0.0264, top-2 Acc 0.9976, top-3 Acc 0.9993, Acc: 0.9928
# val Loss: 0.7015, top-2 Acc 0.8951, top-3 Acc 0.9451, Acc: 0.8392
# Time taken for epoch: 3m 54s
# Estimated Time Remaining: 0m 0s
# Training complete in 199m 11s
# Best val Acc: 0.839443, Best top-2 val Acc: 0.899385, Best overall top-2 Acc: 0.999131, Best top-3 val Acc: 0.942200, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftConvNextLarge.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_ConvNextLarge_Aug_CB.pt')

# %%
def train_modelGoogLeNet(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, topK0preds = torch.topk(outputs, k[0], 1)
                    _, topK1preds = torch.topk(outputs, k[1], 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftGoogLeNet = models.googlenet(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrsGoogLeNet = model_ftGoogLeNet.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsGoogLeNet, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
model_ftGoogLeNet.fc = classifier_block
# model_ftGoogLeNet.fc = nn.Linear(num_ftrsGoogLeNet, 11)

model_ftGoogLeNet = model_ftGoogLeNet.to(device)

criterionGoogLeNet = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftGoogLeNet = optim.SGD(model_ftGoogLeNet.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerGoogLeNet = lr_scheduler.StepLR(optimizer_ftGoogLeNet, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=GoogLeNet_Weights.IMAGENET1K_V1`. You can also use `weights=GoogLeNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ftGoogLeNet = train_modelGoogLeNet(model_ftGoogLeNet, criterionGoogLeNet, optimizer_ftGoogLeNet, exp_lr_schedulerGoogLeNet, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.9529, top-2 Acc 0.8488, top-3 Acc 0.8846, Acc: 0.7608
# val Loss: 1.1290, top-2 Acc 0.7717, top-3 Acc 0.8352, Acc: 0.6286
# Time taken for epoch: 0m 46s
# Estimated Time Remaining: 37m 28s
# Epoch 2/50
# ----------
# train Loss: 0.1827, top-2 Acc 0.9831, top-3 Acc 0.9920, Acc: 0.9615
# val Loss: 0.9523, top-2 Acc 0.8212, top-3 Acc 0.8702, Acc: 0.7281
# Time taken for epoch: 0m 47s
# Estimated Time Remaining: 37m 15s
# Epoch 3/50
# ----------
# train Loss: 0.0929, top-2 Acc 0.9928, top-3 Acc 0.9972, Acc: 0.9822
# val Loss: 0.6489, top-2 Acc 0.8959, top-3 Acc 0.9227, Acc: 0.8092
# Time taken for epoch: 0m 47s
# Estimated Time Remaining: 36m 50s
# Epoch 4/50
# ----------
# train Loss: 0.0623, top-2 Acc 0.9965, top-3 Acc 0.9980, Acc: 0.9887
# val Loss: 1.0553, top-2 Acc 0.8370, top-3 Acc 0.8911, Acc: 0.7626
# Time taken for epoch: 0m 47s
# Estimated Time Remaining: 35m 57s
# Epoch 5/50
# ----------
# train Loss: 0.0494, top-2 Acc 0.9972, top-3 Acc 0.9983, Acc: 0.9896
# val Loss: 0.8396, top-2 Acc 0.8590, top-3 Acc 0.8951, Acc: 0.8057
# Time taken for epoch: 0m 46s
# Estimated Time Remaining: 34m 46s
# Epoch 6/50
# ----------
# train Loss: 0.0423, top-2 Acc 0.9978, top-3 Acc 0.9985, Acc: 0.9920
# val Loss: 0.7869, top-2 Acc 0.8600, top-3 Acc 0.9061, Acc: 0.8159
# Time taken for epoch: 0m 47s
# Estimated Time Remaining:
top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9963
# val Loss: 0.8278, top-2 Acc 0.8758, top-3 Acc 0.9106, Acc: 0.8180
# Time taken for epoch: 0m 47s
# Estimated Time Remaining: 5m 27s
# Epoch 44/50
# ----------
# train Loss: 0.0299, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9935
# val Loss: 0.6649, top-2 Acc 0.8959, top-3 Acc 0.9272, Acc: 0.8328
# Time taken for epoch: 0m 47s
# Estimated Time Remaining: 4m 43s
# Epoch 45/50
# ----------
# train Loss: 0.0280, top-2 Acc 0.9983, top-3 Acc 0.9996, Acc: 0.9957
# val Loss: 0.7767, top-2 Acc 0.8785, top-3 Acc 0.9208, Acc: 0.8204
# Time taken for epoch: 0m 47s
# Estimated Time Remaining: 3m 54s
# Epoch 46/50
# ----------
# train Loss: 0.0315, top-2 Acc 0.9980, top-3 Acc 0.9989, Acc: 0.9937
# val Loss: 0.7201, top-2 Acc 0.8817, top-3 Acc 0.9261, Acc: 0.8220
# Time taken for epoch: 0m 47s
# Estimated Time Remaining: 3m 7s
# Epoch 47/50
# ----------
# train Loss: 0.0270, top-2 Acc 0.9985, top-3 Acc 0.9996, Acc: 0.9957
# val Loss: 0.7936, top-2 Acc 0.8820, top-3 Acc 0.9189, Acc: 0.8210
# Time taken for epoch: 0m 46s
# Estimated Time Remaining: 2m 19s
# Epoch 48/50
# ----------
# train Loss: 0.0270, top-2 Acc 0.9987, top-3 Acc 0.9991, Acc: 0.9965
# val Loss: 0.7797, top-2 Acc 0.8686, top-3 Acc 0.9149, Acc: 0.8148
# Time taken for epoch: 0m 47s
# Estimated Time Remaining: 1m 34s
# Epoch 49/50
# ----------
# train Loss: 0.0335, top-2 Acc 0.9976, top-3 Acc 0.9991, Acc: 0.9924
# val Loss: 0.6859, top-2 Acc 0.8860, top-3 Acc 0.9269, Acc: 0.8295
# Time taken for epoch: 0m 47s
# Estimated Time Remaining: 0m 47s
# Epoch 50/50
# ----------
# train Loss: 0.0246, top-2 Acc 0.9991, top-3 Acc 0.9991, Acc: 0.9959
# val Loss: 0.7970, top-2 Acc 0.8694, top-3 Acc 0.9112, Acc: 0.8178
# Time taken for epoch: 0m 48s
# Estimated Time Remaining: 0m 0s
# Training complete in 39m 5s
# Best val Acc: 0.833824, Best top-2 val Acc: 0.885470, Best overall top-2 Acc: 0.999783, Best top-3 val Acc: 0.930425, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftGoogLeNet.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_GoogLeNet.pt')

# %%
model_ftGoogLeNet = train_modelGoogLeNet(model_ftGoogLeNet, criterionGoogLeNet, optimizer_ftGoogLeNet, exp_lr_schedulerGoogLeNet, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 1.2279, top-2 Acc 0.7415, top-3 Acc 0.8047, Acc: 0.6153
# val Loss: 1.0509, top-2 Acc 0.8004, top-3 Acc 0.8657, Acc: 0.6687
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 29m 59s
# Epoch 2/50
# ----------
# train Loss: 0.3786, top-2 Acc 0.9542, top-3 Acc 0.9759, Acc: 0.8938
# val Loss: 0.6463, top-2 Acc 0.8825, top-3 Acc 0.9197, Acc: 0.7875
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 29m 13s
# Epoch 3/50
# ----------
# train Loss: 0.2542, top-2 Acc 0.9692, top-3 Acc 0.9839, Acc: 0.9335
# val Loss: 0.7654, top-2 Acc 0.8563, top-3 Acc 0.8873, Acc: 0.7875
# Time taken for epoch: 0m 37s
# Estimated Time Remaining:
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 4m 53s
# Epoch 43/50
# ----------
# train Loss: 0.0867, top-2 Acc 0.9904, top-3 Acc 0.9941, Acc: 0.9807
# val Loss: 0.5420, top-2 Acc 0.9146, top-3 Acc 0.9419, Acc: 0.8408
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 4m 16s
# Epoch 44/50
# ----------
# train Loss: 0.0893, top-2 Acc 0.9911, top-3 Acc 0.9957, Acc: 0.9798
# val Loss: 0.5489, top-2 Acc 0.9253, top-3 Acc 0.9494, Acc: 0.8346
# Time taken for epoch: 0m 36s
# Estimated Time Remaining: 3m 39s
# Epoch 45/50
# ----------
# train Loss: 0.0914, top-2 Acc 0.9913, top-3 Acc 0.9961, Acc: 0.9763
# val Loss: 0.5151, top-2 Acc 0.9288, top-3 Acc 0.9516, Acc: 0.8485
# Time taken for epoch: 0m 36s
# Estimated Time Remaining: 3m 2s
# Epoch 46/50
# ----------
# train Loss: 0.0939, top-2 Acc 0.9913, top-3 Acc 0.9950, Acc: 0.9789
# val Loss: 0.5657, top-2 Acc 0.9055, top-3 Acc 0.9438, Acc: 0.8461
# Time taken for epoch: 0m 36s
# Estimated Time Remaining: 2m 26s
# Epoch 47/50
# ----------
# train Loss: 0.0800, top-2 Acc 0.9937, top-3 Acc 0.9974, Acc: 0.9822
# val Loss: 0.5403, top-2 Acc 0.9096, top-3 Acc 0.9411, Acc: 0.8472
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 1m 50s
# Epoch 48/50
# ----------
# train Loss: 0.0910, top-2 Acc 0.9909, top-3 Acc 0.9946, Acc: 0.9785
# val Loss: 0.5571, top-2 Acc 0.9039, top-3 Acc 0.9414, Acc: 0.8461
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 1m 13s
# Epoch 49/50
# ----------
# train Loss: 0.0839, top-2 Acc 0.9917, top-3 Acc 0.9963, Acc: 0.9791
# val Loss: 0.5822, top-2 Acc 0.9141, top-3 Acc 0.9459, Acc: 0.8352
# Time taken for epoch: 0m 36s
# Estimated Time Remaining: 0m 36s
# Epoch 50/50
# ----------
# train Loss: 0.0932, top-2 Acc 0.9915, top-3 Acc 0.9950, Acc: 0.9791
# val Loss: 0.5986, top-2 Acc 0.9058, top-3 Acc 0.9422, Acc: 0.8448
# Time taken for epoch: 0m 36s
# Estimated Time Remaining: 0m 0s
# Training complete in 30m 26s
# Best val Acc: 0.854429, Best top-2 val Acc: 0.921595, Best overall top-2 Acc: 0.994569, Best top-3 val Acc: 0.947016, Best overall top-3 Acc: 0.997393

# %%
torch.save(model_ftGoogLeNet.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_GoogLeNet_Aug_CB.pt')

# %%
def train_modelSwinV2B(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, topK0preds = torch.topk(outputs, k[0], 1)
                    _, topK1preds = torch.topk(outputs, k[1], 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftSwinV2B = models.swin_v2_b(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrsSwinV2B = model_ftSwinV2B.head.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsSwinV2B, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
# model_ftSwinV2B.fc = nn.Linear(num_ftrsSwinV2B, 11)
model_ftSwinV2B.fc = classifier_block

model_ftSwinV2B = model_ftSwinV2B.to(device)

criterionSwinV2B = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftSwinV2B = optim.SGD(model_ftSwinV2B.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerSwinV2B = lr_scheduler.StepLR(optimizer_ftSwinV2B, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Swin_V2_B_Weights.IMAGENET1K_V1`. You can also use `weights=Swin_V2_B_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ftSwinV2B = train_modelSwinV2B(model_ftSwinV2B, criterionSwinV2B, optimizer_ftSwinV2B, exp_lr_schedulerSwinV2B, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 1.6503, top-2 Acc 0.6170, top-3 Acc 0.6902, Acc: 0.4982
# val Loss: 1.4730, top-2 Acc 0.7527, top-3 Acc 0.8587, Acc: 0.5662
# Time taken for epoch: 2m 41s
# Estimated Time Remaining: 131m 27s
# Epoch 2/50
# ----------
# train Loss: 0.1951, top-2 Acc 0.9768, top-3 Acc 0.9896, Acc: 0.9413
# val Loss: 1.0729, top-2 Acc 0.8330, top-3 Acc 0.8734, Acc: 0.7172
# Time taken for epoch: 2m 37s
# Estimated Time Remaining: 125m 38s
# Epoch 3/50
# ----------
# train Loss: 0.0922, top-2 Acc 0.9917, top-3 Acc 0.9946, Acc: 0.9707
# val Loss: 1.0995, top-2 Acc 0.8600, top-3 Acc 0.9256, Acc: 0.7487
# Time taken for epoch: 2m 37s
# Estimated Time Remaining: 123m 7s
# Epoch 4/50
# ----------
# train Loss: 0.0582, top-2 Acc 0.9933, top-3 Acc 0.9972, Acc: 0.9820
# val Loss: 0.8121, top-2 Acc 0.8804, top-3 Acc 0.9219, Acc: 0.8017
# Time taken for epoch: 2m 36s
# Estimated Time Remaining: 119m 57s
# Epoch 5/50
# ----------
# train Loss: 0.0358, top-2 Acc 0.9967, top-3 Acc 0.9985, Acc: 0.9887
# val Loss: 1.3051, top-2 Acc 0.8673, top-3 Acc 0.9336, Acc: 0.7736
# Time taken for epoch: 2m 34s
# Estimated Time Remaining: 115m 41s
# Epoch 6/50
# ----------
# train Loss: 0.0239, top-2 Acc 0.9976, top-3 Acc 0.9996, Acc: 0.9909
# val Loss: 1.0453, top-2 Acc 0.8796, top-3 Acc 0.9221, Acc: 0.8159
# Time taken for epoch: 2m 30s
# Estimated Time Remaining: 109m 51s
# Epoch 7/50
# ----------
# train Loss: 0.0150, top-2 Acc 0.9991, top-3 Acc 1.0000, Acc: 0.9957
# val Loss: 1.0151, top-2 Acc 0.8801, top-3 Acc 0.9205, Acc: 0.8226
# Time taken for epoch: 2m 34s
# Estimated Time Remaining: 110m 2s
# Epoch 8/50
# ----------
# train Loss: 0.0137, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9954
# val Loss: 1.0048, top-2 Acc 0.8817, top-3 Acc 0.9264, Acc: 0.8287
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 105m 36s
# Epoch 9/50
# ----------
# train Loss: 0.0152, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9952
# val Loss: 1.0495, top-2 Acc 0.8780, top-3 Acc 0.9272, Acc: 0.8282
# Time taken for epoch: 2m 33s
# Estimated Time Remaining: 104m 41s
# Epoch 10/50
# ----------
# train Loss: 0.0143, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9961
# val Loss: 1.0291, top-2 Acc 0.8823, top-3 Acc 0.9280, Acc: 0.8293
# Time taken for epoch: 2m 34s
# Estimated Time Remaining: 102m 33s
# Epoch 11/50
# ----------
# train Loss: 0.0146, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9963
# val Loss: 1.0264, top-2 Acc 0.8823, top-3 Acc 0.9277, Acc: 0.8285
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 98m 9s
# Epoch 12/50
# ----------
# train Loss: 0.0124, top-2 Acc 0.9983, top-3 Acc 0.9989, Acc: 0.9959
# val Loss: 1.0304, top-2 Acc 0.8820, top-3 Acc 0.9280, Acc: 0.8290
# Time taken for epoch: 2m 30s
# Estimated Time Remaining: 95m 6s
# Epoch 13/50
# ----------
# train Loss: 0.0117, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9963
# val Loss: 1.0262, top-2 Acc 0.8823, top-3 Acc 0.9283, Acc: 0.8290
# Time taken for epoch: 2m 33s
# Estimated Time Remaining: 94m 8s
# Epoch 14/50
# ----------
# train Loss: 0.0163, top-2 Acc 0.9985, top-3 Acc 0.9993, Acc: 0.9950
# val Loss: 1.0248, top-2 Acc 0.8817, top-3 Acc 0.9286, Acc: 0.8298
# Time taken for epoch: 2m 35s
# Estimated Time Remaining: 92m 50s
# Epoch 15/50
# ----------
# train Loss: 0.0148, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9950
# val Loss: 1.0228, top-2 Acc 0.8820, top-3 Acc 0.9288, Acc: 0.8303
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 87m 51s
# Epoch 16/50
# ----------
# train Loss: 0.0133, top-2 Acc 0.9989, top-3 Acc 0.9993, Acc: 0.9963
# val Loss: 1.0226, top-2 Acc 0.8820, top-3 Acc 0.9288, Acc: 0.8303
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 85m 25s
# Epoch 17/50
# ----------
# train Loss: 0.0116, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9963
# val Loss: 1.0220, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 82m 55s
# Epoch 18/50
# ----------
# train Loss: 0.0149, top-2 Acc 0.9989, top-3 Acc 0.9989, Acc: 0.9952
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9288, Acc: 0.8306
# Time taken for epoch: 2m 33s
# Estimated Time Remaining: 81m 22s
# Epoch 19/50
# ----------
# train Loss: 0.0148, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9948
# val Loss: 1.0208, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 78m 10s
# Epoch 20/50
# ----------
# train Loss: 0.0157, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9950
# val Loss: 1.0205, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 75m 22s
# Epoch 21/50
# ----------
# train Loss: 0.0149, top-2 Acc 0.9989, top-3 Acc 1.0000, Acc: 0.9946
# val Loss: 1.0205, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 33s
# Estimated Time Remaining: 73m 58s
# Epoch 22/50
# ----------
# train Loss: 0.0123, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9959
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 32s
# Estimated Time Remaining: 70m 45s
# Epoch 23/50
# ----------
# train Loss: 0.0125, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9954
# val Loss: 1.0205, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 32s
# Estimated Time Remaining: 68m 36s
# Epoch 24/50
# ----------
# train Loss: 0.0172, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9944
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 65m 38s
# Epoch 25/50
# ----------
# train Loss: 0.0128, top-2 Acc 1.0000, top-3 Acc 1.0000, Acc: 0.9954
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 62m 52s
# Epoch 26/50
# ----------
# train Loss: 0.0153, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9948
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 35s
# Estimated Time Remaining: 61m 51s
# Epoch 27/50
# ----------
# train Loss: 0.0117, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9967
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 33s
# Estimated Time Remaining: 58m 38s
# Epoch 28/50
# ----------
# train Loss: 0.0111, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9970
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 55m 24s
# Epoch 29/50
# ----------
# train Loss: 0.0124, top-2 Acc 0.9989, top-3 Acc 0.9993, Acc: 0.9970
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 32s
# Estimated Time Remaining: 53m 7s
# Epoch 30/50
# ----------
# train Loss: 0.0141, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9952
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 29s
# Estimated Time Remaining: 49m 42s
# Epoch 31/50
# ----------
# train Loss: 0.0101, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9959
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 32s
# Estimated Time Remaining: 48m 13s
# Epoch 32/50
# ----------
# train Loss: 0.0129, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9963
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 34s
# Estimated Time Remaining: 46m 15s
# Epoch 33/50
# ----------
# train Loss: 0.0153, top-2 Acc 0.9985, top-3 Acc 0.9993, Acc: 0.9941
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 37s
# Estimated Time Remaining: 44m 30s
# Epoch 34/50
# ----------
# train Loss: 0.0130, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9957
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 43s
# Estimated Time Remaining: 43m 22s
# Epoch 35/50
# ----------
# train Loss: 0.0132, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9967
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 43s
# Estimated Time Remaining: 40m 47s
# Epoch 36/50
# ----------
# train Loss: 0.0119, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9974
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 41s
# Estimated Time Remaining: 37m 30s
# Epoch 37/50
# ----------
# train Loss: 0.0112, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9972
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 45s
# Estimated Time Remaining: 35m 40s
# Epoch 38/50
# ----------
# train Loss: 0.0165, top-2 Acc 0.9989, top-3 Acc 0.9991, Acc: 0.9944
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 42s
# Estimated Time Remaining: 32m 29s
# Epoch 39/50
# ----------
# train Loss: 0.0135, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9957
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 42s
# Estimated Time Remaining: 29m 46s
# Epoch 40/50
# ----------
# train Loss: 0.0139, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9952
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 25m 15s
# Epoch 41/50
# ----------
# train Loss: 0.0098, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9967
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 32s
# Estimated Time Remaining: 22m 47s
# Epoch 42/50
# ----------
# train Loss: 0.0111, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9957
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 31s
# Estimated Time Remaining: 20m 8s
# Epoch 43/50
# ----------
# train Loss: 0.0124, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9965
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 2m 33s
# Estimated Time Remaining: 17m 48s
# Epoch 44/50
# ----------
# train Loss: 0.0126, top-2 Acc 0.9985, top-3 Acc 0.9996, Acc: 0.9963
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 9m 54s
# Epoch 45/50
# ----------
# train Loss: 0.0149, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9957
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 1m 37s
# Estimated Time Remaining: 8m 7s
# Epoch 46/50
# ----------
# train Loss: 0.0116, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9972
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 6m 35s
# Epoch 47/50
# ----------
# train Loss: 0.0204, top-2 Acc 0.9983, top-3 Acc 0.9996, Acc: 0.9933
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 4m 57s
# Epoch 48/50
# ----------
# train Loss: 0.0122, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9970
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 3m 16s
# Epoch 49/50
# ----------
# train Loss: 0.0104, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9963
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 1m 39s
# Epoch 50/50
# ----------
# train Loss: 0.0105, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9963
# val Loss: 1.0204, top-2 Acc 0.8825, top-3 Acc 0.9286, Acc: 0.8306
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 0m 0s
# Training complete in 121m 57s
# Best val Acc: 0.830613, Best top-2 val Acc: 0.882526, Best overall top-2 Acc: 1.000000, Best top-3 val Acc: 0.928552, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftSwinV2B.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_SwinV2B.pt')

# %%
model_ftSwinV2B = train_modelSwinV2B(model_ftSwinV2B, criterionSwinV2B, optimizer_ftSwinV2B, exp_lr_schedulerSwinV2B, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 1.6113, top-2 Acc 0.6309, top-3 Acc 0.7074, Acc: 0.5205
# val Loss: 1.1609, top-2 Acc 0.7913, top-3 Acc 0.8887, Acc: 0.6465
# Time taken for epoch: 1m 26s
# Estimated Time Remaining: 70m 0s
# Epoch 2/50
# ----------
# train Loss: 0.2373, top-2 Acc 0.9718, top-3 Acc 0.9863, Acc: 0.9231
# val Loss: 0.9517, top-2 Acc 0.8440, top-3 Acc 0.9162, Acc: 0.7313
# Time taken for epoch: 1m 29s
# Estimated Time Remaining: 71m 15s
# Epoch 3/50
# ----------
# train Loss: 0.1278, top-2 Acc 0.9846, top-3 Acc 0.9920, Acc: 0.9594
# val Loss: 1.2168, top-2 Acc 0.8464, top-3 Acc 0.8898, Acc: 0.7287
# Time taken for epoch: 1m 31s
# Estimated Time Remaining: 70m 58s
# Epoch 4/50
# ----------
# train Loss: 0.0788, top-2 Acc 0.9913, top-3 Acc 0.9970, Acc: 0.9746
# val Loss: 1.0584, top-2 Acc 0.8584, top-3 Acc 0.8938, Acc: 0.7849
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 72m 15s
# Epoch 5/50
# ----------
# train Loss: 0.0789, top-2 Acc 0.9928, top-3 Acc 0.9974, Acc: 0.9724
# val Loss: 1.1224, top-2 Acc 0.8488, top-3 Acc 0.8863, Acc: 0.7832
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 69m 11s
# Epoch 6/50
# ----------
# train Loss: 0.0420, top-2 Acc 0.9963, top-3 Acc 0.9985, Acc: 0.9865
# val Loss: 0.8984, top-2 Acc 0.8815, top-3 Acc 0.9205, Acc: 0.8138
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 67m 22s
# Epoch 7/50
# ----------
# train Loss: 0.0353, top-2 Acc 0.9967, top-3 Acc 0.9980, Acc: 0.9881
# val Loss: 0.8522, top-2 Acc 0.8922, top-3 Acc 0.9211, Acc: 0.8261
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 68m 37s
# Epoch 8/50
# ----------
# train Loss: 0.0333, top-2 Acc 0.9972, top-3 Acc 0.9989, Acc: 0.9902
# val Loss: 0.8099, top-2 Acc 0.8948, top-3 Acc 0.9277, Acc: 0.8346
# Time taken for epoch: 1m 33s
# Estimated Time Remaining: 65m 3s
# Epoch 9/50
# ----------
# train Loss: 0.0258, top-2 Acc 0.9987, top-3 Acc 0.9996, Acc: 0.9930
# val Loss: 0.8514, top-2 Acc 0.8919, top-3 Acc 0.9219, Acc: 0.8320
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 62m 32s
# Epoch 10/50
# ----------
# train Loss: 0.0280, top-2 Acc 0.9967, top-3 Acc 0.9985, Acc: 0.9917
# val Loss: 0.8168, top-2 Acc 0.8970, top-3 Acc 0.9253, Acc: 0.8416
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 63m 55s
# Epoch 11/50
# ----------
# train Loss: 0.0283, top-2 Acc 0.9978, top-3 Acc 0.9993, Acc: 0.9896
# val Loss: 0.8184, top-2 Acc 0.8972, top-3 Acc 0.9264, Acc: 0.8416
# Time taken for epoch: 1m 35s
# Estimated Time Remaining: 61m 32s
# Epoch 12/50
# ----------
# train Loss: 0.0259, top-2 Acc 0.9972, top-3 Acc 0.9983, Acc: 0.9926
# val Loss: 0.8103, top-2 Acc 0.8986, top-3 Acc 0.9277, Acc: 0.8427
# Time taken for epoch: 1m 30s
# Estimated Time Remaining: 56m 49s
# Epoch 13/50
# ----------
# train Loss: 0.0221, top-2 Acc 0.9987, top-3 Acc 0.9996, Acc: 0.9924
# val Loss: 0.8129, top-2 Acc 0.8994, top-3 Acc 0.9267, Acc: 0.8429
# Time taken for epoch: 1m 35s
# Estimated Time Remaining: 58m 29s
# Epoch 14/50
# ----------
# train Loss: 0.0253, top-2 Acc 0.9985, top-3 Acc 0.9993, Acc: 0.9915
# val Loss: 0.8130, top-2 Acc 0.8991, top-3 Acc 0.9277, Acc: 0.8435
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 56m 6s
# Epoch 15/50
# ----------
# train Loss: 0.0220, top-2 Acc 0.9983, top-3 Acc 0.9996, Acc: 0.9933
# val Loss: 0.8193, top-2 Acc 0.8980, top-3 Acc 0.9261, Acc: 0.8424
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 53m 29s
# Epoch 16/50
# ----------
# train Loss: 0.0260, top-2 Acc 0.9978, top-3 Acc 1.0000, Acc: 0.9909
# val Loss: 0.8192, top-2 Acc 0.8980, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 54m 33s
# Epoch 17/50
# ----------
# train Loss: 0.0283, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9911
# val Loss: 0.8198, top-2 Acc 0.8980, top-3 Acc 0.9259, Acc: 0.8427
# Time taken for epoch: 1m 30s
# Estimated Time Remaining: 49m 41s
# Epoch 18/50
# ----------
# train Loss: 0.0250, top-2 Acc 0.9985, top-3 Acc 0.9996, Acc: 0.9928
# val Loss: 0.8197, top-2 Acc 0.8980, top-3 Acc 0.9261, Acc: 0.8427
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 49m 53s
# Epoch 19/50
# ----------
# train Loss: 0.0219, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9915
# val Loss: 0.8199, top-2 Acc 0.8980, top-3 Acc 0.9261, Acc: 0.8427
# Time taken for epoch: 1m 33s
# Estimated Time Remaining: 48m 9s
# Epoch 20/50
# ----------
# train Loss: 0.0218, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9924
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 46m 1s
# Epoch 21/50
# ----------
# train Loss: 0.0259, top-2 Acc 0.9978, top-3 Acc 0.9993, Acc: 0.9915
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 39s
# Estimated Time Remaining: 47m 46s
# Epoch 22/50
# ----------
# train Loss: 0.0209, top-2 Acc 0.9980, top-3 Acc 0.9993, Acc: 0.9939
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 30s
# Estimated Time Remaining: 42m 13s
# Epoch 23/50
# ----------
# train Loss: 0.0246, top-2 Acc 0.9983, top-3 Acc 0.9991, Acc: 0.9928
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 35s
# Estimated Time Remaining: 42m 43s
# Epoch 24/50
# ----------
# train Loss: 0.0219, top-2 Acc 0.9980, top-3 Acc 0.9993, Acc: 0.9941
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 33s
# Estimated Time Remaining: 40m 26s
# Epoch 25/50
# ----------
# train Loss: 0.0222, top-2 Acc 0.9980, top-3 Acc 0.9993, Acc: 0.9937
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 38m 14s
# Epoch 26/50
# ----------
# train Loss: 0.0217, top-2 Acc 0.9985, top-3 Acc 0.9998, Acc: 0.9937
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 36s
# Estimated Time Remaining: 38m 34s
# Epoch 27/50
# ----------
# train Loss: 0.0234, top-2 Acc 0.9983, top-3 Acc 0.9996, Acc: 0.9930
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 35m 55s
# Epoch 28/50
# ----------
# train Loss: 0.0235, top-2 Acc 0.9978, top-3 Acc 0.9991, Acc: 0.9926
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 31s
# Estimated Time Remaining: 33m 18s
# Epoch 29/50
# ----------
# train Loss: 0.0243, top-2 Acc 0.9972, top-3 Acc 0.9989, Acc: 0.9911
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 32m 44s
# Epoch 30/50
# ----------
# train Loss: 0.0279, top-2 Acc 0.9978, top-3 Acc 0.9989, Acc: 0.9911
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 31m 29s
# Epoch 31/50
# ----------
# train Loss: 0.0280, top-2 Acc 0.9978, top-3 Acc 0.9996, Acc: 0.9915
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 29m 13s
# Epoch 32/50
# ----------
# train Loss: 0.0261, top-2 Acc 0.9978, top-3 Acc 0.9993, Acc: 0.9902
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 27m 33s
# Epoch 33/50
# ----------
# train Loss: 0.0250, top-2 Acc 0.9987, top-3 Acc 0.9991, Acc: 0.9922
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 33s
# Estimated Time Remaining: 26m 20s
# Epoch 34/50
# ----------
# train Loss: 0.0214, top-2 Acc 0.9987, top-3 Acc 0.9996, Acc: 0.9935
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 25m 1s
# Epoch 35/50
# ----------
# train Loss: 0.0198, top-2 Acc 0.9985, top-3 Acc 0.9998, Acc: 0.9928
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 33s
# Estimated Time Remaining: 23m 13s
# Epoch 36/50
# ----------
# train Loss: 0.0293, top-2 Acc 0.9976, top-3 Acc 0.9991, Acc: 0.9917
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 21m 26s
# Epoch 37/50
# ----------
# train Loss: 0.0188, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9937
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 20m 24s
# Epoch 38/50
# ----------
# train Loss: 0.0253, top-2 Acc 0.9987, top-3 Acc 0.9996, Acc: 0.9924
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 18m 46s
# Epoch 39/50
# ----------
# train Loss: 0.0234, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9915
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 31s
# Estimated Time Remaining: 16m 41s
# Epoch 40/50
# ----------
# train Loss: 0.0275, top-2 Acc 0.9983, top-3 Acc 0.9996, Acc: 0.9917
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 38s
# Estimated Time Remaining: 16m 15s
# Epoch 41/50
# ----------
# train Loss: 0.0259, top-2 Acc 0.9989, top-3 Acc 0.9993, Acc: 0.9926
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 31s
# Estimated Time Remaining: 13m 40s
# Epoch 42/50
# ----------
# train Loss: 0.0290, top-2 Acc 0.9980, top-3 Acc 0.9991, Acc: 0.9917
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 33s
# Estimated Time Remaining: 12m 25s
# Epoch 43/50
# ----------
# train Loss: 0.0242, top-2 Acc 0.9978, top-3 Acc 0.9985, Acc: 0.9926
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 10m 57s
# Epoch 44/50
# ----------
# train Loss: 0.0257, top-2 Acc 0.9976, top-3 Acc 0.9991, Acc: 0.9915
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 9m 10s
# Epoch 45/50
# ----------
# train Loss: 0.0301, top-2 Acc 0.9974, top-3 Acc 0.9989, Acc: 0.9913
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 7m 42s
# Epoch 46/50
# ----------
# train Loss: 0.0197, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9944
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 6m 10s
# Epoch 47/50
# ----------
# train Loss: 0.0236, top-2 Acc 0.9980, top-3 Acc 0.9993, Acc: 0.9915
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 4m 42s
# Epoch 48/50
# ----------
# train Loss: 0.0201, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9930
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 34s
# Estimated Time Remaining: 3m 9s
# Epoch 49/50
# ----------
# train Loss: 0.0250, top-2 Acc 0.9980, top-3 Acc 0.9998, Acc: 0.9915
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 1m 32s
# Epoch 50/50
# ----------
# train Loss: 0.0241, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9915
# val Loss: 0.8195, top-2 Acc 0.8986, top-3 Acc 0.9261, Acc: 0.8429
# Time taken for epoch: 1m 32s
# Estimated Time Remaining: 0m 0s
# Training complete in 77m 26s
# Best val Acc: 0.843457, Best top-2 val Acc: 0.899117, Best overall top-2 Acc: 0.999348, Best top-3 val Acc: 0.927750, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftSwinV2B.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_SwinV2B_Aug_CB.pt')

# %%
def train_modelMNasNet13(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, topK0preds = torch.topk(outputs, k[0], 1)
                    _, topK1preds = torch.topk(outputs, k[1], 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftMNasNet13 = models.mnasnet1_3(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrsMNasNet13 = model_ftMNasNet13.classifier[1].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsMNasNet13, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
# model_ftMNasNet13.fc = nn.Linear(num_ftrsMNasNet13, 11)
model_ftMNasNet13.fc = classifier_block
model_ftMNasNet13 = model_ftMNasNet13.to(device)

criterionMNasNet13 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftMNasNet13 = optim.SGD(model_ftMNasNet13.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerMNasNet13 = lr_scheduler.StepLR(optimizer_ftMNasNet13, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MNASNet1_3_Weights.IMAGENET1K_V1`. You can also use `weights=MNASNet1_3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ftMNasNet13 = train_modelMNasNet13(model_ftMNasNet13, criterionMNasNet13, optimizer_ftMNasNet13, exp_lr_schedulerMNasNet13, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss:
# val Loss: 0.8341, top-2 Acc 0.8774, top-3 Acc 0.9069, Acc: 0.8338
# Time taken for epoch: 0m 39s
# Estimated Time Remaining: 0m 0s
# Training complete in 32m 35s
# Best val Acc: 0.835429, Best top-2 val Acc: 0.877709, Best overall top-2 Acc: 0.998914, Best top-3 val Acc: 0.907948, Best overall top-3 Acc: 0.999566

# %%
torch.save(model_ftMNasNet13.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_MNasNet13.pt')

# %%
model_ftMNasNet13 = train_modelMNasNet13(model_ftMNasNet13, criterionMNasNet13, optimizer_ftMNasNet13, exp_lr_schedulerMNasNet13, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 1.3190, top-2 Acc 0.8071, top-3 Acc 0.8414, Acc: 0.7267
# val Loss: 4.3326, top-2 Acc 0.3728, top-3 Acc 0.4327, Acc: 0.2721
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 29m 57s
# Epoch 2/50
# ----------
# train Loss: 0.2005, top-2 Acc 0.9718, top-3 Acc 0.9848, Acc: 0.9461
# val Loss: 3.3829, top-2 Acc 0.4158, top-3 Acc 0.5274, Acc: 0.2863
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 29m 32s
# Epoch 3/50
# ----------
# train Loss: 0.1201, top-2 Acc 0.9852, top-3 Acc 0.9933, Acc: 0.9681
# val Loss: 2.8903, top-2 Acc 0.5866, top-3 Acc 0.6615, Acc: 0.4472
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 28m 50s
# Epoch 4/50
# ----------
# train Loss: 0.0812, top-2 Acc 0.9928, top-3 Acc 0.9965, Acc: 0.9765
# val Loss: 2.2731, top-2 Acc 0.6701, top-3 Acc 0.7410, Acc: 0.5239
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 28m 6s
# Epoch 5/50
# ----------
# train Loss: 0.0625, top-2 Acc 0.9946, top-3 Acc 0.9980, Acc: 0.9820
# val Loss: 1.7555, top-2 Acc 0.7303, top-3 Acc 0.7937, Acc: 0.6077
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 27m 28s
# Epoch 6/50
# ----------
# train Loss: 0.0466, top-2 Acc 0.9961, top-3 Acc 0.9974, Acc: 0.9881
# val Loss: 1.2730, top-2 Acc 0.7929, top-3 Acc 0.8373, Acc: 0.7056
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 26m 57s
# Epoch 7/50
# ----------
# train Loss: 0.0449, top-2 Acc 0.9970, top-3 Acc 0.9987, Acc: 0.9872
# val Loss: 1.1119, top-2 Acc 0.8089, top-3 Acc 0.8563, Acc: 0.7420
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 26m 15s
# Epoch 8/50
# ----------
# train Loss: 0.0431, top-2 Acc 0.9972, top-3 Acc 0.9985, Acc: 0.9874
# val Loss: 1.0574, top-2 Acc 0.8191, top-3 Acc 0.8635, Acc: 0.7688
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 25m 42s
# Epoch 9/50
# ----------
# train Loss: 0.0425, top-2 Acc 0.9957, top-3 Acc 0.9978, Acc: 0.9876
# val Loss: 1.0031, top-2 Acc 0.8293, top-3 Acc 0.8796, Acc: 0.7816
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 25m 7s
# Epoch 10/50
# ----------
# train Loss: 0.0418, top-2 Acc 0.9970, top-3 Acc 0.9980, Acc: 0.9885
# val Loss: 0.9554, top-2 Acc 0.8381, top-3 Acc 0.8895, Acc: 0.7905
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 24m 28s
# Epoch 11/50
# ----------
# train Loss: 0.0279, top-2 Acc 0.9985, top-3 Acc 0.9993, Acc: 0.9917
# val Loss: 0.9228, top-2 Acc 0.8435, top-3 Acc 0.8962, Acc: 0.7985
# Time taken for epoch: 0m 37s
# Estimated Time Remaining:
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 16m 30s
# Epoch 24/50
# ----------
# train Loss: 0.0356, top-2 Acc 0.9980, top-3 Acc 0.9996, Acc: 0.9909
# val Loss: 0.8603, top-2 Acc 0.8673, top-3 Acc 0.9112, Acc: 0.8146
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 15m 52s
# Epoch 25/50
# ----------
# train Loss: 0.0339, top-2 Acc 0.9972, top-3 Acc 0.9991, Acc: 0.9915
# val Loss: 0.8612, top-2 Acc 0.8673, top-3 Acc 0.9106, Acc: 0.8143
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 15m 15s
# Epoch 26/50
# ----------
# train Loss: 0.0416, top-2 Acc 0.9972, top-3 Acc 0.9987, Acc: 0.9883
# val Loss: 0.8612, top-2 Acc 0.8675, top-3 Acc 0.9114, Acc: 0.8143
# Time taken for epoch: 0m 36s
# Estimated Time Remaining: 14m 35s
# Epoch 27/50
# ----------
# train Loss: 0.0333, top-2 Acc 0.9974, top-3 Acc 0.9985, Acc: 0.9911
# val Loss: 0.8625, top-2 Acc 0.8675, top-3 Acc 0.9114, Acc: 0.8138
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 14m 2s
# Epoch 28/50
# ----------
# train Loss: 0.0380, top-2 Acc 0.9970, top-3 Acc 0.9987, Acc: 0.9898
# val Loss: 0.8630, top-2 Acc 0.8678, top-3 Acc 0.9122, Acc: 0.8138
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 13m 23s
# Epoch 29/50
# ----------
# train Loss: 0.0401, top-2 Acc 0.9961, top-3 Acc 0.9987, Acc: 0.9883
# val Loss: 0.8648, top-2 Acc 0.8675, top-3 Acc 0.9114, Acc: 0.8135
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 12m 50s
# Epoch 30/50
# ----------
# train Loss: 0.0343, top-2 Acc 0.9965, top-3 Acc 0.9980, Acc: 0.9926
# val Loss: 0.8661, top-2 Acc 0.8675, top-3 Acc 0.9120, Acc: 0.8138
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 12m 10s
# Epoch 31/50
# ----------
# train Loss: 0.0352, top-2 Acc 0.9970, top-3 Acc 0.9989, Acc: 0.9911
# val Loss: 0.8652, top-2 Acc 0.8675, top-3 Acc 0.9114, Acc: 0.8143
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 11m 36s
# Epoch 32/50
# ----------
# train Loss: 0.0360, top-2 Acc 0.9980, top-3 Acc 0.9991, Acc: 0.9902
# val Loss: 0.8654, top-2 Acc 0.8678, top-3 Acc 0.9120, Acc: 0.8140
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 10m 59s
# Epoch 33/50
# ----------
# train Loss: 0.0445, top-2 Acc 0.9952, top-3 Acc 0.9967, Acc: 0.9872
# val Loss: 0.8650, top-2 Acc 0.8681, top-3 Acc 0.9120, Acc: 0.8143
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 10m 25s
# Epoch 34/50
# ----------
# train Loss: 0.0364, top-2 Acc 0.9967, top-3 Acc 0.9987, Acc: 0.9904
# val Loss: 0.8662, top-2 Acc 0.8678, top-3 Acc 0.9120, Acc: 0.8146
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 9m 47s
# Epoch 35/50
# ----------
# train Loss: 0.0405, top-2 Acc 0.9959, top-3 Acc 0.9980, Acc: 0.9896
# val Loss: 0.8662, top-2 Acc 0.8675, top-3 Acc 0.9125, Acc: 0.8146
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 9m 11s
# Epoch 36/50
# ----------
# train Loss: 0.0346, top-2 Acc 0.9972, top-3 Acc 0.9991, Acc: 0.9900
# val Loss: 0.8677, top-2 Acc 0.8673, top-3 Acc 0.9125, Acc: 0.8146
# Time taken for epoch: 0m 37s
# Estimated Time Remaining:
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 0m 37s
# Epoch 50/50
# ----------
# train Loss: 0.0412, top-2 Acc 0.9972, top-3 Acc 0.9985, Acc: 0.9883
# val Loss: 0.8644, top-2 Acc 0.8691, top-3 Acc 0.9128, Acc: 0.8146
# Time taken for epoch: 0m 37s
# Estimated Time Remaining: 0m 0s
# Training complete in 30m 32s
# Best val Acc: 0.814825, Best top-2 val Acc: 0.866470, Best overall top-2 Acc: 0.998479, Best top-3 val Acc: 0.911694, Best overall top-3 Acc: 0.999783

# %%
torch.save(model_ftMNasNet13.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_MNasNet13_Aug_CB.pt')

# %%
def train_modelVGG16(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_topK0acc = 0.0
    best_topK0accOverall = 0.0
    best_topK1acc = 0.0
    best_topK1accOverall = 0.0
    k = [2, 3]

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_topK0corrects = 0
            running_topK1corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 inputs = F.interpolate(inputs, size=(224,224), antialias=True, mode='bilinear')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, topK0preds = torch.topk(outputs, k[0], 1)
                    _, topK1preds = torch.topk(outputs, k[1], 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                #top-k accuracy calculation
#                 print(labels.data)
#                 print('----------------------')
#                 print(preds)
#                 print('----------------------')
#                 print(topKpreds)
                running_topK0corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK0preds)]))
                running_topK1corrects += torch.sum(torch.tensor([ld in tkp for ld, tkp in zip(labels.data, topK1preds)]))
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_topK0acc = running_topK0corrects.double() / dataset_sizes[phase]
            epoch_topK1acc = running_topK1corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f}, top-2 Acc {:.4f}, top-3 Acc {:.4f}, Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_topK0acc, epoch_topK1acc, epoch_acc))
            best_topK0accOverall = max(best_topK0accOverall, epoch_topK0acc)
            best_topK1accOverall = max(best_topK1accOverall, epoch_topK1acc)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_topK0acc = epoch_topK0acc
                best_topK1acc = epoch_topK1acc
                best_model_wts = copy.deepcopy(model.state_dict())
        time_taken = time.time() - start
        start = time.time()
        ETA = time_taken * (num_epochs - epoch - 1)
        print('Time taken for epoch: {:.0f}m {:.0f}s'.format(time_taken // 60, time_taken % 60))
        print('Estimated Time Remaining: {:.0f}m {:.0f}s'.format(ETA // 60, ETA % 60))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}, Best top-2 val Acc: {:4f}, Best overall top-2 Acc: {:4f}, Best top-3 val Acc: {:4f}, Best overall top-3 Acc: {:4f}'.format(best_acc, best_topK0acc, best_topK0accOverall, best_topK1acc, best_topK1accOverall))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ftVGG16 = models.vgg16(pretrained=True)
# print(num_ftrs, model_ft, model_ft2)
num_ftrsVGG16 = model_ftVGG16.classifier[6].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#--------------------------------------------------
# Classifier Block
classifier_block = nn.Sequential(
                                    nn.Linear(num_ftrsVGG16, 512),
                                    nn.BatchNorm1d(512),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(512, 256),
                                    nn.BatchNorm1d(256),
                                    nn.ReLU(inplace=True),
                                    nn.Dropout(0.5),
                                    nn.Linear(256, 11))
#--------------------------------------------------
# model_ftVGG16.fc = nn.Linear(num_ftrsVGG16, 11)
model_ftVGG16.fc = classifier_block

model_ftVGG16 = model_ftVGG16.to(device)

criterionVGG16 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ftVGG16 = optim.SGD(model_ftVGG16.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 5 epochs
exp_lr_schedulerVGG16 = lr_scheduler.StepLR(optimizer_ftVGG16, step_size=5, gamma=0.1)
# Out:
# /home/dlpc01/anaconda3/envs/rifat/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_ftVGG16 = train_modelVGG16(model_ftVGG16, criterionVGG16, optimizer_ftVGG16, exp_lr_schedulerVGG16, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.6365, top-2 Acc 0.8981, top-3 Acc 0.9248, Acc: 0.8318
# val Loss: 1.1087, top-2 Acc 0.7899, top-3 Acc 0.8467, Acc: 0.6733
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 47m 43s
# Epoch 2/50
# ----------
# train Loss: 0.1167, top-2 Acc 0.9898, top-3 Acc 0.9933, Acc: 0.9646
# val Loss: 1.0821, top-2 Acc 0.8207, top-3 Acc 0.8972, Acc: 0.7549
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 46m 38s
# Epoch 3/50
# ----------
# train Loss: 0.0673, top-2 Acc 0.9941, top-3 Acc 0.9967, Acc: 0.9820
# val Loss: 1.0644, top-2 Acc 0.8675, top-3 Acc 0.9013, Acc: 0.7824
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 45m 43s
# Epoch 4/50
# ----------
# train Loss: 0.0476, top-2 Acc 0.9946, top-3 Acc 0.9983, Acc: 0.9863
# val Loss: 1.0165, top-2 Acc 0.8651, top-3 Acc 0.9007, Acc: 0.7883
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 44m 50s
# Epoch 5/50
# ----------
# train Loss: 0.0310, top-2 Acc 0.9967, top-3 Acc 0.9985, Acc: 0.9907
# val Loss: 1.0741, top-2 Acc 0.8523, top-3 Acc 0.8964, Acc: 0.8052
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 44m 1s
# Epoch 6/50
# ----------
# train Loss: 0.0123, top-2 Acc 0.9989, top-3 Acc 0.9993, Acc: 0.9959
# val Loss: 1.0456, top-2 Acc 0.8526, top-3 Acc 0.8994, Acc: 0.8089
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 42m 44s
# Epoch 7/50
# ----------
# train Loss: 0.0085, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9978
# val Loss: 1.0466, top-2 Acc 0.8555, top-3 Acc 0.9026, Acc: 0.8108
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 42m 0s
# Epoch 8/50
# ----------
# train Loss: 0.0096, top-2 Acc 0.9985, top-3 Acc 0.9993, Acc: 0.9976
# val Loss: 1.0448, top-2 Acc 0.8587, top-3 Acc 0.9037, Acc: 0.8164
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 41m 6s
# Epoch 9/50
# ----------
# train Loss: 0.0087, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9970
# val Loss: 1.0291, top-2 Acc 0.8606, top-3 Acc 0.9069, Acc: 0.8196
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 40m 7s
# Epoch 10/50
# ----------
# train Loss: 0.0111, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9970
# val Loss: 0.9359, top-2 Acc 0.8790, top-3 Acc 0.9162, Acc: 0.8344
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 39m 33s
# Epoch 11/50
# ----------
# train Loss: 0.0044, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9987
# val Loss: 0.9312, top-2 Acc 0.8790, top-3 Acc 0.9162, Acc: 0.8346
# Time taken for epoch: 1m 0s
# Estimated Time Remaining: 39m 17s
# Epoch 12/50
# ----------
# train Loss: 0.0071, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9976
# val Loss: 0.9325, top-2 Acc 0.8782, top-3 Acc 0.9170, Acc: 0.8349
# Time taken for epoch: 1m 0s
# Estimated Time Remaining: 38m 6s
# Epoch 13/50
# ----------
# train Loss: 0.0085, top-2 Acc 0.9993, top-3 Acc 0.9993, Acc: 0.9972
# val Loss: 0.9264, top-2 Acc 0.8799, top-3 Acc 0.9181, Acc: 0.8346
# Time taken for epoch: 0m 60s
# Estimated Time Remaining: 36m 49s
# Epoch 14/50
# ----------
# train Loss: 0.0033, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9989
# val Loss: 0.9236, top-2 Acc 0.8801, top-3 Acc 0.9170, Acc: 0.8349
# Time taken for epoch: 0m 60s
# Estimated Time Remaining: 35m 59s
# Epoch 15/50
# ----------
# train Loss: 0.0088, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9970
# val Loss: 0.9226, top-2 Acc 0.8796, top-3 Acc 0.9173, Acc: 0.8354
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 34m 42s
# Epoch 16/50
# ----------
# train Loss: 0.0050, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9983
# val Loss: 0.9221, top-2 Acc 0.8799, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 33m 23s
# Epoch 17/50
# ----------
# train Loss: 0.0059, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9980
# val Loss: 0.9218, top-2 Acc 0.8799, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 0m 60s
# Estimated Time Remaining: 32m 46s
# Epoch 18/50
# ----------
# train Loss: 0.0059, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9983
# val Loss: 0.9220, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 16s
# Estimated Time Remaining: 40m 17s
# Epoch 19/50
# ----------
# train Loss: 0.0048, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9991
# val Loss: 0.9220, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 27s
# Estimated Time Remaining: 45m 9s
# Epoch 20/50
# ----------
# train Loss: 0.0049, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9985
# val Loss: 0.9220, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 27s
# Estimated Time Remaining: 43m 36s
# Epoch 21/50
# ----------
# train Loss: 0.0066, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9978
# val Loss: 0.9219, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 26s
# Estimated Time Remaining: 41m 24s
# Epoch 22/50
# ----------
# train Loss: 0.0062, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9976
# val Loss: 0.9219, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 27s
# Estimated Time Remaining: 40m 28s
# Epoch 23/50
# ----------
# train Loss: 0.0048, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9989
# val Loss: 0.9219, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 27s
# Estimated Time Remaining: 39m 17s
# Epoch 24/50
# ----------
# train Loss: 0.0088, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9972
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 26s
# Estimated Time Remaining: 37m 8s
# Epoch 25/50
# ----------
# train Loss: 0.0049, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9989
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 26s
# Estimated Time Remaining: 35m 59s
# Epoch 26/50
# ----------
# train Loss: 0.0068, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9974
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 27s
# Estimated Time Remaining: 34m 41s
# Epoch 27/50
# ----------
# train Loss: 0.0090, top-2 Acc 0.9989, top-3 Acc 0.9991, Acc: 0.9972
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 26s
# Estimated Time Remaining: 32m 48s
# Epoch 28/50
# ----------
# train Loss: 0.0080, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9978
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 0m 59s
# Estimated Time Remaining: 21m 38s
# Epoch 29/50
# ----------
# train Loss: 0.0066, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9983
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 0s
# Estimated Time Remaining: 21m 5s
# Epoch 30/50
# ----------
# train Loss: 0.0055, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9983
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 19s
# Estimated Time Remaining: 26m 24s
# Epoch 31/50
# ----------
# train Loss: 0.0038, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9991
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 20s
# Estimated Time Remaining: 25m 26s
# Epoch 32/50
# ----------
# train Loss: 0.0054, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9976
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 21s
# Estimated Time Remaining: 24m 17s
# Epoch 33/50
# ----------
# train Loss: 0.0055, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9970
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 21s
# Estimated Time Remaining: 23m 2s
# Epoch 34/50
# ----------
# train Loss: 0.0036, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9989
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 21s
# Estimated Time Remaining: 21m 35s
# Epoch 35/50
# ----------
# train Loss: 0.0066, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9978
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 21s
# Estimated Time Remaining: 20m 9s
# Epoch 36/50
# ----------
# train Loss: 0.0087, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9967
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 21s
# Estimated Time Remaining: 18m 56s
# Epoch 37/50
# ----------
# train Loss: 0.0077, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9970
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 21s
# Estimated Time Remaining: 17m 33s
# Epoch 38/50
# ----------
# train Loss: 0.0065, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9980
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 21s
# Estimated Time Remaining: 16m 12s
# Epoch 39/50
# ----------
# train Loss: 0.0060, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9980
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 9s
# Estimated Time Remaining: 12m 42s
# Epoch 40/50
# ----------
# train Loss: 0.0057, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9985
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 1s
# Estimated Time Remaining: 10m 6s
# Epoch 41/50
# ----------
# train Loss: 0.0055, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9985
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 23s
# Estimated Time Remaining: 12m 26s
# Epoch 42/50
# ----------
# train Loss: 0.0037, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9987
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 23s
# Estimated Time Remaining: 11m 6s
# Epoch 43/50
# ----------
# train Loss: 0.0037, top-2 Acc 1.0000, top-3 Acc 1.0000, Acc: 0.9987
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 23s
# Estimated Time Remaining: 9m 41s
# Epoch 44/50
# ----------
# train Loss: 0.0047, top-2 Acc 1.0000, top-3 Acc 1.0000, Acc: 0.9985
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 22s
# Estimated Time Remaining: 8m 11s
# Epoch 45/50
# ----------
# train Loss: 0.0074, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9983
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 23s
# Estimated Time Remaining: 6m 54s
# Epoch 46/50
# ----------
# train Loss: 0.0061, top-2 Acc 0.9998, top-3 Acc 0.9998, Acc: 0.9980
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 23s
# Estimated Time Remaining: 5m 32s
# Epoch 47/50
# ----------
# train Loss: 0.0069, top-2 Acc 0.9989, top-3 Acc 0.9996, Acc: 0.9985
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 22s
# Estimated Time Remaining: 4m 7s
# Epoch 48/50
# ----------
# train Loss: 0.0086, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9976
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 23s
# Estimated Time Remaining: 2m 45s
# Epoch 49/50
# ----------
# train Loss: 0.0088, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9970
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 23s
# Estimated Time Remaining: 1m 23s
# Epoch 50/50
# ----------
# train Loss: 0.0073, top-2 Acc 0.9993, top-3 Acc 0.9996, Acc: 0.9983
# val Loss: 0.9218, top-2 Acc 0.8801, top-3 Acc 0.9173, Acc: 0.8352
# Time taken for epoch: 1m 23s
# Estimated Time Remaining: 0m 0s
# Training complete in 61m 1s
# Best val Acc: 0.835429, Best top-2 val Acc: 0.879583, Best overall top-2 Acc: 1.000000, Best top-3 val Acc: 0.917313, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftVGG16.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_VGG16.pt')

# %%
model_ftVGG16 = train_modelVGG16(model_ftVGG16, criterionVGG16, optimizer_ftVGG16, exp_lr_schedulerVGG16, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 34m 54s
# Epoch 15/50
# ----------
# train Loss: 0.0151, top-2 Acc 0.9996, top-3 Acc 1.0000, Acc: 0.9944
# val Loss: 0.7631, top-2 Acc 0.8938, top-3 Acc 0.9272, Acc: 0.8501
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 34m 1s
# Epoch 16/50
# ----------
# train Loss: 0.0195, top-2 Acc 0.9989, top-3 Acc 0.9993, Acc: 0.9937
# val Loss: 0.7634, top-2 Acc 0.8932, top-3 Acc 0.9272, Acc: 0.8499
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 32m 57s
# Epoch 17/50
# ----------
# train Loss: 0.0176, top-2 Acc 0.9980, top-3 Acc 0.9989, Acc: 0.9941
# val Loss: 0.7635, top-2 Acc 0.8932, top-3 Acc 0.9272, Acc: 0.8501
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 32m 2s
# Epoch 18/50
# ----------
# train Loss: 0.0162, top-2 Acc 0.9983, top-3 Acc 0.9985, Acc: 0.9963
# val Loss: 0.7637, top-2 Acc 0.8932, top-3 Acc 0.9269, Acc: 0.8499
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 31m 4s
# Epoch 19/50
# ----------
# train Loss: 0.0177, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9939
# val Loss: 0.7633, top-2 Acc 0.8932, top-3 Acc 0.9267, Acc: 0.8504
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 30m 3s
# Epoch 20/50
# ----------
# train Loss: 0.0180, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9933
# val Loss: 0.7629, top-2 Acc 0.8930, top-3 Acc 0.9267, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 29m 7s
# Epoch 21/50
# ----------
# train Loss: 0.0176, top-2 Acc 0.9983, top-3 Acc 0.9993, Acc: 0.9941
# val Loss: 0.7629, top-2 Acc 0.8930, top-3 Acc 0.9267, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 28m 6s
# Epoch 22/50
# ----------
# train Loss: 0.0180, top-2 Acc 0.9991, top-3 Acc 0.9993, Acc: 0.9944
# val Loss: 0.7629, top-2 Acc 0.8930, top-3 Acc 0.9267, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 27m 10s
# Epoch 23/50
# ----------
# train Loss: 0.0162, top-2 Acc 0.9985, top-3 Acc 0.9991, Acc: 0.9948
# val Loss: 0.7629, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 26m 14s
# Epoch 24/50
# ----------
# train Loss: 0.0202, top-2 Acc 0.9978, top-3 Acc 0.9985, Acc: 0.9946
# val Loss: 0.7629, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 25m 11s
# Epoch 25/50
# ----------
# train Loss: 0.0147, top-2 Acc 0.9987, top-3 Acc 0.9991, Acc: 0.9948
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 24m 18s
# Epoch 26/50
# ----------
# train Loss: 0.0141, top-2 Acc 0.9987, top-3 Acc 0.9996, Acc: 0.9952
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 23m 15s
# Epoch 27/50
# ----------
# train Loss: 0.0138, top-2 Acc 0.9989, top-3 Acc 0.9991, Acc: 0.9961
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 22m 20s
# Epoch 28/50
# ----------
# train Loss: 0.0185, top-2 Acc 0.9983, top-3 Acc 0.9993, Acc: 0.9939
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 21m 22s
# Epoch 29/50
# ----------
# train Loss: 0.0170, top-2 Acc 0.9989, top-3 Acc 0.9991, Acc: 0.9944
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 20m 23s
# Epoch 30/50
# ----------
# train Loss: 0.0123, top-2 Acc 0.9987, top-3 Acc 0.9998, Acc: 0.9963
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 19m 24s
# Epoch 31/50
# ----------
# train Loss: 0.0118, top-2 Acc 0.9996, top-3 Acc 0.9998, Acc: 0.9961
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 18m 29s
# Epoch 32/50
# ----------
# train Loss: 0.0154, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9944
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 17m 29s
# Epoch 33/50
# ----------
# train Loss: 0.0152, top-2 Acc 0.9991, top-3 Acc 0.9998, Acc: 0.9944
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 16m 30s
# Epoch 34/50
# ----------
# train Loss: 0.0180, top-2 Acc 0.9985, top-3 Acc 0.9993, Acc: 0.9957
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 15m 32s
# Epoch 35/50
# ----------
# train Loss: 0.0149, top-2 Acc 0.9991, top-3 Acc 0.9996, Acc: 0.9948
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 14m 34s
# Epoch 36/50
# ----------
# train Loss: 0.0155, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9954
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 13m 35s
# Epoch 37/50
# ----------
# train Loss: 0.0129, top-2 Acc 0.9987, top-3 Acc 0.9993, Acc: 0.9954
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 12m 37s
# Epoch 38/50
# ----------
# train Loss: 0.0216, top-2 Acc 0.9983, top-3 Acc 0.9993, Acc: 0.9948
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 11m 38s
# Epoch 39/50
# ----------
# train Loss: 0.0181, top-2 Acc 0.9985, top-3 Acc 0.9993, Acc: 0.9948
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 10m 39s
# Epoch 40/50
# ----------
# train Loss: 0.0109, top-2 Acc 0.9998, top-3 Acc 1.0000, Acc: 0.9965
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 9m 41s
# Epoch 41/50
# ----------
# train Loss: 0.0149, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9952
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 8m 45s
# Epoch 42/50
# ----------
# train Loss: 0.0152, top-2 Acc 0.9993, top-3 Acc 0.9998, Acc: 0.9950
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 7m 46s
# Epoch 43/50
# ----------
# train Loss: 0.0145, top-2 Acc 0.9983, top-3 Acc 0.9998, Acc: 0.9957
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 6m 47s
# Epoch 44/50
# ----------
# train Loss: 0.0155, top-2 Acc 0.9985, top-3 Acc 0.9996, Acc: 0.9946
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 5m 50s
# Epoch 45/50
# ----------
# train Loss: 0.0120, top-2 Acc 0.9989, top-3 Acc 0.9993, Acc: 0.9957
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 4m 51s
# Epoch 46/50
# ----------
# train Loss: 0.0156, top-2 Acc 0.9985, top-3 Acc 0.9993, Acc: 0.9952
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 3m 53s
# Epoch 47/50
# ----------
# train Loss: 0.0132, top-2 Acc 0.9989, top-3 Acc 0.9998, Acc: 0.9950
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 2m 55s
# Epoch 48/50
# ----------
# train Loss: 0.0203, top-2 Acc 0.9976, top-3 Acc 0.9987, Acc: 0.9946
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 1m 57s
# Epoch 49/50
# ----------
# train Loss: 0.0125, top-2 Acc 0.9996, top-3 Acc 0.9996, Acc: 0.9965
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 0m 58s
# Epoch 50/50
# ----------
# train Loss: 0.0143, top-2 Acc 0.9989, top-3 Acc 0.9993, Acc: 0.9948
# val Loss: 0.7630, top-2 Acc 0.8930, top-3 Acc 0.9269, Acc: 0.8507
# Time taken for epoch: 0m 58s
# Estimated Time Remaining: 0m 0s
# Training complete in 48m 26s
# Best val Acc: 0.853893, Best top-2 val Acc: 0.898314, Best overall top-2 Acc: 0.999783, Best top-3 val Acc: 0.931228, Best overall top-3 Acc: 1.000000

# %%
torch.save(model_ftVGG16.state_dict(), '/home/dlpc01/Rifat/saved_models/HSPR_VGG16_Aug_CB.pt')
